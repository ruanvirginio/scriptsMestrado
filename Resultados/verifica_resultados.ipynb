# %%
import os
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', '{:.6f}'.format)

arquivos_csv = [f for f in os.listdir() if f.endswith('.csv')]

dataframes = []

for arquivo in arquivos_csv:
    df = pd.read_csv(arquivo, sep=';') 
    df['Arquivo'] = arquivo 
    df = df[['Trafo', 'RMSE', 'MAE', 'Arquivo']]
    dataframes.append(df)

df_concatenado = pd.concat(dataframes, ignore_index=True)

# Encontrando o arquivo com menor RMSE para cada trafo
min_rmse_files = df_concatenado.loc[df_concatenado.groupby("Trafo")["RMSE"].idxmin(), "Arquivo"]

# Contando quantas vezes cada arquivo aparece como menor RMSE
arquivo_counts = min_rmse_files.value_counts()

print('Qtd melhor resultado:')
print(arquivo_counts)

# Encontrando os dois menores RMSE para cada trafo
df_sorted = df_concatenado.sort_values(["Trafo", "RMSE"])
second_min_files = df_sorted.groupby("Trafo").nth(1)["Arquivo"]

# Contando quantas vezes cada arquivo aparece como segundo menor RMSE
second_min_counts = second_min_files.value_counts()

print('\nQtd segundo melhor resultado:')
print(second_min_counts)

# Encontrando os tres menores RMSE para cada trafo
third_min_files = df_sorted.groupby("Trafo").nth(2)["Arquivo"]

# Contando quantas vezes cada arquivo aparece como terceiro menor RMSE
third_min_counts = third_min_files.value_counts()

print('\nQtd terceiro melhor resultado:')
print(third_min_counts)

# Pega os 3 melhores RMSE para cada trafo
top3_files = df_sorted.groupby("Trafo").head(3)

top3_pivot = top3_files.assign(Rank=top3_files.groupby("Trafo").cumcount()+1).pivot(index="Trafo", columns="Rank", values="Arquivo")
top3_pivot.columns = ["Melhor", "Segundo Melhor", "Terceiro Melhor"]

top3_pivot = top3_pivot.reset_index()  # Transforma o índice em coluna
top3_pivot.columns = ['Trafo', 'Melhor', 'Segundo Melhor', 'Terceiro Melhor']  # Renomeia as colunas

top3_pivot
# Out:
# Qtd melhor resultado:
# Arquivo
# SVR_S.csv                 32
# LSTM_S-GD.csv             19
# LSTM_S-Clientes.csv       18
# LSTM_S.csv                11
# LSTM_S-Clientes-GD.csv     4
# RFR_S-GD.csv               2
# RFR_S-Clientes.csv         2
# SVR_S-GD.csv               1
# RFR_S.csv                  1
# Name: count, dtype: int64
#
# Qtd segundo melhor resultado:
# Arquivo
# LSTM_S-GD.csv             20
# LSTM_S.csv                17
# LSTM_S-Clientes.csv       16
# LSTM_S-Clientes-GD.csv    16
# SVR_S.csv                 10
# SVR_S-GD.csv               5
# RFR_S-GD.csv               3
# RFR_S.csv                  2
# RFR_S-Clientes-GD.csv      1
# Name: count, dtype: int64
#
# Qtd terceiro melhor resultado:
# Arquivo
# LSTM_S-Clientes-GD.csv    28
# LSTM_S-GD.csv             22
# LSTM_S-Clientes.csv       18
# RFR_S.csv                  7
# LSTM_S.csv                 6
# SVR_S-GD.csv               3
# RFR_S-Clientes.csv         2
# SVR_S.csv                  1
# RFR_S-GD.csv               1
# SVR_S-Clientes.csv         1
# RFR_S-Clientes-GD.csv      1
# Name: count, dtype: int64
#               Trafo                  Melhor          Segundo Melhor  \
# 0       ABR_DJ_12B1           LSTM_S-GD.csv     LSTM_S-Clientes.csv
# 1       AER_DJ_12B1            RFR_S-GD.csv            SVR_S-GD.csv
# 2       APL_DJ_12B1     LSTM_S-Clientes.csv           LSTM_S-GD.csv
# 3       ARA_DJ_12B1     LSTM_S-Clientes.csv           LSTM_S-GD.csv
# 4       ARN_DJ_12B1     LSTM_S-Clientes.csv           LSTM_S-GD.csv
# 5       ARR_DJ_12B1           LSTM_S-GD.csv     LSTM_S-Clientes.csv
# 6       BBR_DJ_12B1      RFR_S-Clientes.csv     LSTM_S-Clientes.csv
# 7       BBR_DJ_12B2  LSTM_S-Clientes-GD.csv           LSTM_S-GD.csv
# 8       BJC_DJ_12B1           LSTM_S-GD.csv     LSTM_S-Clientes.csv
# 9       BNR_DJ_12B1  LSTM_S-Clientes-GD.csv     LSTM_S-Clientes.csv
# 10      BQR_DJ_12B1  LSTM_S-Clientes-GD.csv     LSTM_S-Clientes.csv
# 11      BSA_DJ_12B1               SVR_S.csv              LSTM_S.csv
# 12      BSA_DJ_12B2               SVR_S.csv     LSTM_S-Clientes.csv
# 13      BVA_DJ_12T1               SVR_S.csv              LSTM_S.csv
# 14      BVT_DJ_12B1           LSTM_S-GD.csv     LSTM_S-Clientes.csv
# 15      BVT_DJ_12B2  LSTM_S-Clientes-GD.csv           LSTM_S-GD.csv
# 16      BYX_DJ_12B1               SVR_S.csv               RFR_S.csv
# 17      CAA_DJ_12B1     LSTM_S-Clientes.csv  LSTM_S-Clientes-GD.csv
# 18      CBD_DJ_12B1               SVR_S.csv              LSTM_S.csv
# 19      CBD_DJ_12B2           LSTM_S-GD.csv               SVR_S.csv
# 20      CDE_DJ_12B1     LSTM_S-Clientes.csv  LSTM_S-Clientes-GD.csv
# 21      CGD_DJ_11T7               SVR_S.csv              LSTM_S.csv
# 22      CGU_DJ_12B1     LSTM_S-Clientes.csv           LSTM_S-GD.csv
# 23      CGU_DJ_12B2           LSTM_S-GD.csv     LSTM_S-Clientes.csv
# 24      CJZ_DJ_12B1               SVR_S.csv  LSTM_S-Clientes-GD.csv
# 25      CJZ_DJ_12B2               SVR_S.csv              LSTM_S.csv
# 26      CPX_DJ_12B1           LSTM_S-GD.csv     LSTM_S-Clientes.csv
# 27      CPX_DJ_12B2     LSTM_S-Clientes.csv  LSTM_S-Clientes-GD.csv
# 28      CRI_DJ_12B1               SVR_S.csv            SVR_S-GD.csv
# 29      CRI_DJ_12B2     LSTM_S-Clientes.csv           LSTM_S-GD.csv
# 30      CRM_DJ_12T1              LSTM_S.csv               SVR_S.csv
# 31      CTE_DJ_12B1     LSTM_S-Clientes.csv           LSTM_S-GD.csv
# 32      CTL_DJ_12B1            SVR_S-GD.csv            RFR_S-GD.csv
# 33      CTR_DJ_12B1               SVR_S.csv            SVR_S-GD.csv
# 34      DIN_DJ_12B1               SVR_S.csv           LSTM_S-GD.csv
# 35      DST_DJ_12B1               SVR_S.csv            SVR_S-GD.csv
# 36      DST_DJ_12B2            RFR_S-GD.csv   RFR_S-Clientes-GD.csv
# 37      ESP_DJ_12B1           LSTM_S-GD.csv  LSTM_S-Clientes-GD.csv
# 38      GBA_DJ_12B1               SVR_S.csv              LSTM_S.csv
# 39      GBA_DJ_12B2           LSTM_S-GD.csv  LSTM_S-Clientes-GD.csv
# 40      IBR_DJ_12B1     LSTM_S-Clientes.csv           LSTM_S-GD.csv
# 41      ILB_DJ_12B1     LSTM_S-Clientes.csv           LSTM_S-GD.csv
# 42      ITA_DJ_12B1               SVR_S.csv           LSTM_S-GD.csv
# 43      ITO_DJ_12B1           LSTM_S-GD.csv  LSTM_S-Clientes-GD.csv
# 44      JCU_DJ_12B1           LSTM_S-GD.csv               SVR_S.csv
# 45      JPS_DJ_12B1              LSTM_S.csv               SVR_S.csv
# 46      JPS_DJ_12B2               SVR_S.csv              LSTM_S.csv
# 47      JRC_DJ_12B1              LSTM_S.csv           LSTM_S-GD.csv
# 48      JTB_DJ_12B1               SVR_S.csv           LSTM_S-GD.csv
# 49      JZR_DJ_12B1           LSTM_S-GD.csv     LSTM_S-Clientes.csv
# 50      LCN_DJ_12B1               SVR_S.csv              LSTM_S.csv
# 51      MAA_DJ_12B1              LSTM_S.csv            RFR_S-GD.csv
# 52      MGB_DJ_12B1              LSTM_S.csv  LSTM_S-Clientes-GD.csv
# 53      MGB_DJ_12B2              LSTM_S.csv               SVR_S.csv
# 54      MLT_DJ_12B1              LSTM_S.csv               SVR_S.csv
# 55      MNT_DJ_12T1     LSTM_S-Clientes.csv  LSTM_S-Clientes-GD.csv
# 56      MRO_DJ_12B1           LSTM_S-GD.csv     LSTM_S-Clientes.csv
# 57      MRU_DJ_12B1               SVR_S.csv              LSTM_S.csv
# 58      MRU_DJ_12B2              LSTM_S.csv               SVR_S.csv
# 59      ORT_DJ_12B1           LSTM_S-GD.csv  LSTM_S-Clientes-GD.csv
# 60      PBL_DJ_12B1              LSTM_S.csv               SVR_S.csv
# 61      PCI_DJ_12B1     LSTM_S-Clientes.csv           LSTM_S-GD.csv
# 62      PCO_DJ_12B1               SVR_S.csv              LSTM_S.csv
# 63      PLT_DJ_12B1               SVR_S.csv              LSTM_S.csv
# 64      PLU_DJ_12B1               SVR_S.csv              LSTM_S.csv
# 65  PLU_DJ_12B1_D_P               RFR_S.csv               SVR_S.csv
# 66      PLV_DJ_12B1     LSTM_S-Clientes.csv           LSTM_S-GD.csv
# 67      POC_DJ_12B1     LSTM_S-Clientes.csv           LSTM_S-GD.csv
# 68      PRI_DJ_12B1     LSTM_S-Clientes.csv           LSTM_S-GD.csv
# 69      PRT_DJ_12B1      RFR_S-Clientes.csv            RFR_S-GD.csv
# 70      PTS_DJ_12B1           LSTM_S-GD.csv  LSTM_S-Clientes-GD.csv
# 71      QMD_DJ_12B1               SVR_S.csv            SVR_S-GD.csv
# 72      RIC_DJ_12B1               SVR_S.csv               RFR_S.csv
# 73      RTT_DJ_12B1           LSTM_S-GD.csv  LSTM_S-Clientes-GD.csv
# 74      RTT_DJ_12B2               SVR_S.csv              LSTM_S.csv
# 75      SBT_DJ_12B1               SVR_S.csv  LSTM_S-Clientes-GD.csv
# 76      SGL_DJ_12T1               SVR_S.csv              LSTM_S.csv
# 77      SJC_DJ_12T1           LSTM_S-GD.csv     LSTM_S-Clientes.csv
# 78      SLD_DJ_12B1           LSTM_S-GD.csv  LSTM_S-Clientes-GD.csv
# 79      SLZ_DJ_12B1               SVR_S.csv     LSTM_S-Clientes.csv
# 80      SPE_DJ_12B2              LSTM_S.csv               SVR_S.csv
# 81      SPX_DJ_12B1               SVR_S.csv              LSTM_S.csv
# 82      STR_DJ_12B1               SVR_S.csv              LSTM_S.csv
# 83      STR_DJ_12B2               SVR_S.csv     LSTM_S-Clientes.csv
# 84      SZA_DJ_12B1               SVR_S.csv              LSTM_S.csv
# 85      SZA_DJ_12B2              LSTM_S.csv           LSTM_S-GD.csv
# 86      TBU_DJ_12B1     LSTM_S-Clientes.csv  LSTM_S-Clientes-GD.csv
# 87      TBU_DJ_12B2           LSTM_S-GD.csv     LSTM_S-Clientes.csv
# 88      TXR_DJ_12B1               SVR_S.csv           LSTM_S-GD.csv
# 89      URN_DJ_12B1     LSTM_S-Clientes.csv  LSTM_S-Clientes-GD.csv
#
#            Terceiro Melhor
# 0   LSTM_S-Clientes-GD.csv
# 1       RFR_S-Clientes.csv
# 2   LSTM_S-Clientes-GD.csv
# 3                SVR_S.csv
# 4   LSTM_S-Clientes-GD.csv
# 5   LSTM_S-Clientes-GD.csv
# 6   LSTM_S-Clientes-GD.csv
# 7      LSTM_S-Clientes.csv
# 8   LSTM_S-Clientes-GD.csv
# 9            LSTM_S-GD.csv
# 10           LSTM_S-GD.csv
# 11            SVR_S-GD.csv
# 12           LSTM_S-GD.csv
# 13               RFR_S.csv
# 14  LSTM_S-Clientes-GD.csv
# 15     LSTM_S-Clientes.csv
# 16     LSTM_S-Clientes.csv
# 17              LSTM_S.csv
# 18     LSTM_S-Clientes.csv
# 19              LSTM_S.csv
# 20           LSTM_S-GD.csv
# 21               RFR_S.csv
# 22  LSTM_S-Clientes-GD.csv
# 23  LSTM_S-Clientes-GD.csv
# 24           LSTM_S-GD.csv
# 25           LSTM_S-GD.csv
# 26  LSTM_S-Clientes-GD.csv
# 27           LSTM_S-GD.csv
# 28           LSTM_S-GD.csv
# 29  LSTM_S-Clientes-GD.csv
# 30           LSTM_S-GD.csv
# 31  LSTM_S-Clientes-GD.csv
# 32           LSTM_S-GD.csv
# 33     LSTM_S-Clientes.csv
# 34            SVR_S-GD.csv
# 35            RFR_S-GD.csv
# 36      RFR_S-Clientes.csv
# 37     LSTM_S-Clientes.csv
# 38  LSTM_S-Clientes-GD.csv
# 39     LSTM_S-Clientes.csv
# 40  LSTM_S-Clientes-GD.csv
# 41  LSTM_S-Clientes-GD.csv
# 42     LSTM_S-Clientes.csv
# 43     LSTM_S-Clientes.csv
# 44     LSTM_S-Clientes.csv
# 45               RFR_S.csv
# 46               RFR_S.csv
# 47  LSTM_S-Clientes-GD.csv
# 48               RFR_S.csv
# 49  LSTM_S-Clientes-GD.csv
# 50           LSTM_S-GD.csv
# 51  LSTM_S-Clientes-GD.csv
# 52     LSTM_S-Clientes.csv
# 53     LSTM_S-Clientes.csv
# 54  LSTM_S-Clientes-GD.csv
# 55           LSTM_S-GD.csv
# 56  LSTM_S-Clientes-GD.csv
# 57           LSTM_S-GD.csv
# 58           LSTM_S-GD.csv
# 59     LSTM_S-Clientes.csv
# 60           LSTM_S-GD.csv
# 61  LSTM_S-Clientes-GD.csv
# 62           LSTM_S-GD.csv
# 63      SVR_S-Clientes.csv
# 64               RFR_S.csv
# 65              LSTM_S.csv
# 66  LSTM_S-Clientes-GD.csv
# 67  LSTM_S-Clientes-GD.csv
# 68  LSTM_S-Clientes-GD.csv
# 69   RFR_S-Clientes-GD.csv
# 70     LSTM_S-Clientes.csv
# 71              LSTM_S.csv
# 72            SVR_S-GD.csv
# 73     LSTM_S-Clientes.csv
# 74           LSTM_S-GD.csv
# 75              LSTM_S.csv
# 76           LSTM_S-GD.csv
# 77  LSTM_S-Clientes-GD.csv
# 78     LSTM_S-Clientes.csv
# 79  LSTM_S-Clientes-GD.csv
# 80           LSTM_S-GD.csv
# 81  LSTM_S-Clientes-GD.csv
# 82     LSTM_S-Clientes.csv
# 83           LSTM_S-GD.csv
# 84               RFR_S.csv
# 85  LSTM_S-Clientes-GD.csv
# 86           LSTM_S-GD.csv
# 87              LSTM_S.csv
# 88     LSTM_S-Clientes.csv
# 89           LSTM_S-GD.csv

# %%
df_concatenado.to_csv('Resumo_Resultados', sep=';', index=False)
# Out:
#                 Trafo     RMSE      MAE                 Arquivo
# 0         ABR_DJ_12B1 0.429187 0.337620  LSTM_S-Clientes-GD.csv
# 1         AER_DJ_12B1 0.645391 0.491105  LSTM_S-Clientes-GD.csv
# 2         APL_DJ_12B1 0.412543 0.286140  LSTM_S-Clientes-GD.csv
# 3         ARA_DJ_12B1 0.583582 0.450687  LSTM_S-Clientes-GD.csv
# 4         ARN_DJ_12B1 0.092119 0.061694  LSTM_S-Clientes-GD.csv
# 5         ARR_DJ_12B1 0.183175 0.135512  LSTM_S-Clientes-GD.csv
# 6         BBR_DJ_12B1 0.417507 0.324567  LSTM_S-Clientes-GD.csv
# 7         BBR_DJ_12B2 0.406673 0.303042  LSTM_S-Clientes-GD.csv
# 8         BJC_DJ_12B1 0.270269 0.205604  LSTM_S-Clientes-GD.csv
# 9         BNR_DJ_12B1 0.530806 0.385135  LSTM_S-Clientes-GD.csv
# 10        BQR_DJ_12B1 0.321010 0.246805  LSTM_S-Clientes-GD.csv
# 11        BSA_DJ_12B1 1.397205 1.008843  LSTM_S-Clientes-GD.csv
# 12        BSA_DJ_12B2 0.725014 0.538301  LSTM_S-Clientes-GD.csv
# 13        BVA_DJ_12T1 0.437615 0.382705  LSTM_S-Clientes-GD.csv
# 14        BVT_DJ_12B1 0.596324 0.444766  LSTM_S-Clientes-GD.csv
# 15        BVT_DJ_12B2 0.230831 0.180272  LSTM_S-Clientes-GD.csv
# 16        BYX_DJ_12B1 0.797993 0.583300  LSTM_S-Clientes-GD.csv
# 17        CAA_DJ_12B1 0.443713 0.347201  LSTM_S-Clientes-GD.csv
# 18        CBD_DJ_12B1 1.141173 0.854346  LSTM_S-Clientes-GD.csv
# 19        CBD_DJ_12B2 0.744935 0.566133  LSTM_S-Clientes-GD.csv
# 20        CDE_DJ_12B1 0.860029 0.632824  LSTM_S-Clientes-GD.csv
# 21        CGU_DJ_12B1 0.350458 0.284419  LSTM_S-Clientes-GD.csv
# 22        CGU_DJ_12B2 0.285512 0.226110  LSTM_S-Clientes-GD.csv
# 23        CJZ_DJ_12B1 1.052893 0.827390  LSTM_S-Clientes-GD.csv
# 24        CJZ_DJ_12B2 1.132815 0.872757  LSTM_S-Clientes-GD.csv
# 25        CPX_DJ_12B1 0.239953 0.183941  LSTM_S-Clientes-GD.csv
# 26        CPX_DJ_12B2 0.896760 0.645305  LSTM_S-Clientes-GD.csv
# 27        CRI_DJ_12B1 0.879337 0.658695  LSTM_S-Clientes-GD.csv
# 28        CRI_DJ_12B2 0.439053 0.345479  LSTM_S-Clientes-GD.csv
# 29        CRM_DJ_12T1 0.320911 0.238179  LSTM_S-Clientes-GD.csv
# 30        CTE_DJ_12B1 0.200764 0.154076  LSTM_S-Clientes-GD.csv
# 31        CTL_DJ_12B1 1.395028 1.201132  LSTM_S-Clientes-GD.csv
# 32        CTR_DJ_12B1 0.692208 0.526113  LSTM_S-Clientes-GD.csv
# 33        DIN_DJ_12B1 0.173899 0.131205  LSTM_S-Clientes-GD.csv
# 34        DST_DJ_12B1 1.116007 0.915022  LSTM_S-Clientes-GD.csv
# 35        DST_DJ_12B2 0.421610 0.309071  LSTM_S-Clientes-GD.csv
# 36        ESP_DJ_12B1 0.295505 0.215901  LSTM_S-Clientes-GD.csv
# 37        GBA_DJ_12B1 0.357284 0.265167  LSTM_S-Clientes-GD.csv
# 38        GBA_DJ_12B2 0.942008 0.730848  LSTM_S-Clientes-GD.csv
# 39        IBR_DJ_12B1 0.109428 0.089473  LSTM_S-Clientes-GD.csv
# 40        ILB_DJ_12B1 0.537338 0.408561  LSTM_S-Clientes-GD.csv
# 41        ITA_DJ_12B1 0.741893 0.528036  LSTM_S-Clientes-GD.csv
# 42        ITO_DJ_12B1 0.546654 0.407732  LSTM_S-Clientes-GD.csv
# 43        JCU_DJ_12B1 0.220122 0.163455  LSTM_S-Clientes-GD.csv
# 44        JRC_DJ_12B1 0.237660 0.189179  LSTM_S-Clientes-GD.csv
# 45        JTB_DJ_12B1 1.200789 1.045383  LSTM_S-Clientes-GD.csv
# 46        JZR_DJ_12B1 0.353795 0.264979  LSTM_S-Clientes-GD.csv
# 47        LCN_DJ_12B1 0.654139 0.500131  LSTM_S-Clientes-GD.csv
# 48        MAA_DJ_12B1 0.649827 0.498427  LSTM_S-Clientes-GD.csv
# 49        MGB_DJ_12B1 1.170966 0.885964  LSTM_S-Clientes-GD.csv
# 50        MGB_DJ_12B2 0.792419 0.576349  LSTM_S-Clientes-GD.csv
# 51        MLT_DJ_12B1 0.386662 0.275940  LSTM_S-Clientes-GD.csv
# 52        MNT_DJ_12T1 0.409833 0.302390  LSTM_S-Clientes-GD.csv
# 53        MRO_DJ_12B1 0.537772 0.411465  LSTM_S-Clientes-GD.csv
# 54        MRU_DJ_12B1 0.496499 0.398213  LSTM_S-Clientes-GD.csv
# 55        MRU_DJ_12B2 1.046375 0.736676  LSTM_S-Clientes-GD.csv
# 56        ORT_DJ_12B1 0.452249 0.358593  LSTM_S-Clientes-GD.csv
# 57        PBL_DJ_12B1 0.682046 0.537606  LSTM_S-Clientes-GD.csv
# 58        PCI_DJ_12B1 0.181986 0.144765  LSTM_S-Clientes-GD.csv
# 59        PCO_DJ_12B1 0.471311 0.321189  LSTM_S-Clientes-GD.csv
# 60        PLT_DJ_12B1 0.369786 0.307632  LSTM_S-Clientes-GD.csv
# 61        PLV_DJ_12B1 0.138275 0.104757  LSTM_S-Clientes-GD.csv
# 62        POC_DJ_12B1 0.197682 0.156336  LSTM_S-Clientes-GD.csv
# 63        PRI_DJ_12B1 0.405625 0.300951  LSTM_S-Clientes-GD.csv
# 64        PRT_DJ_12B1 1.482459 1.373006  LSTM_S-Clientes-GD.csv
# 65        PTS_DJ_12B1 0.968303 0.747428  LSTM_S-Clientes-GD.csv
# 66        QMD_DJ_12B1 0.548953 0.463912  LSTM_S-Clientes-GD.csv
# 67        RIC_DJ_12B1 0.758872 0.622611  LSTM_S-Clientes-GD.csv
# 68        RTT_DJ_12B1 0.899264 0.650254  LSTM_S-Clientes-GD.csv
# 69        RTT_DJ_12B2 0.601614 0.456929  LSTM_S-Clientes-GD.csv
# 70        SBT_DJ_12B1 1.021883 0.786366  LSTM_S-Clientes-GD.csv
# 71        SGL_DJ_12T1 0.483016 0.384324  LSTM_S-Clientes-GD.csv
# 72        SJC_DJ_12T1 0.236821 0.174954  LSTM_S-Clientes-GD.csv
# 73        SLD_DJ_12B1 0.132656 0.106948  LSTM_S-Clientes-GD.csv
# 74        SLZ_DJ_12B1 0.314974 0.246821  LSTM_S-Clientes-GD.csv
# 75        SPE_DJ_12B2 1.063516 0.816471  LSTM_S-Clientes-GD.csv
# 76        SPX_DJ_12B1 0.386688 0.259997  LSTM_S-Clientes-GD.csv
# 77        STR_DJ_12B1 0.714642 0.511329  LSTM_S-Clientes-GD.csv
# 78        STR_DJ_12B2 0.933762 0.766592  LSTM_S-Clientes-GD.csv
# 79        SZA_DJ_12B1 0.764623 0.613349  LSTM_S-Clientes-GD.csv
# 80        SZA_DJ_12B2 0.713964 0.525597  LSTM_S-Clientes-GD.csv
# 81        TBU_DJ_12B1 0.891110 0.644189  LSTM_S-Clientes-GD.csv
# 82        TBU_DJ_12B2 1.044265 0.761721  LSTM_S-Clientes-GD.csv
# 83        TXR_DJ_12B1 0.269624 0.205322  LSTM_S-Clientes-GD.csv
# 84        URN_DJ_12B1 0.015833 0.015133  LSTM_S-Clientes-GD.csv
# 85        ABR_DJ_12B1 0.422110 0.332588     LSTM_S-Clientes.csv
# 86        AER_DJ_12B1 0.665284 0.473551     LSTM_S-Clientes.csv
# 87        APL_DJ_12B1 0.396902 0.273929     LSTM_S-Clientes.csv
# 88        ARA_DJ_12B1 0.549810 0.423593     LSTM_S-Clientes.csv
# 89        ARN_DJ_12B1 0.087163 0.054570     LSTM_S-Clientes.csv
# 90        ARR_DJ_12B1 0.174967 0.133208     LSTM_S-Clientes.csv
# 91        BBR_DJ_12B1 0.415296 0.323064     LSTM_S-Clientes.csv
# 92        BBR_DJ_12B2 0.411023 0.301392     LSTM_S-Clientes.csv
# 93        BJC_DJ_12B1 0.242397 0.179152     LSTM_S-Clientes.csv
# 94        BNR_DJ_12B1 0.540127 0.402184     LSTM_S-Clientes.csv
# 95        BQR_DJ_12B1 0.321522 0.246932     LSTM_S-Clientes.csv
# 96        BSA_DJ_12B1 1.316641 0.934003     LSTM_S-Clientes.csv
# 97        BSA_DJ_12B2 0.697560 0.503392     LSTM_S-Clientes.csv
# 98        BVA_DJ_12T1 0.423156 0.366481     LSTM_S-Clientes.csv
# 99        BVT_DJ_12B1 0.563285 0.402236     LSTM_S-Clientes.csv
# 100       BVT_DJ_12B2 0.233895 0.183231     LSTM_S-Clientes.csv
# 101       BYX_DJ_12B1 0.731034 0.557340     LSTM_S-Clientes.csv
# 102       CAA_DJ_12B1 0.405243 0.305749     LSTM_S-Clientes.csv
# 103       CBD_DJ_12B1 1.110196 0.824312     LSTM_S-Clientes.csv
# 104       CBD_DJ_12B2 0.778036 0.584956     LSTM_S-Clientes.csv
# 105       CDE_DJ_12B1 0.854176 0.626317     LSTM_S-Clientes.csv
# 106       CGU_DJ_12B1 0.349323 0.282284     LSTM_S-Clientes.csv
# 107       CGU_DJ_12B2 0.283405 0.227962     LSTM_S-Clientes.csv
# 108       CJZ_DJ_12B1 1.061465 0.834558     LSTM_S-Clientes.csv
# 109       CJZ_DJ_12B2 1.142394 0.893535     LSTM_S-Clientes.csv
# 110       CPX_DJ_12B1 0.222104 0.166894     LSTM_S-Clientes.csv
# 111       CPX_DJ_12B2 0.881205 0.628507     LSTM_S-Clientes.csv
# 112       CRI_DJ_12B1 0.887431 0.661425     LSTM_S-Clientes.csv
# 113       CRI_DJ_12B2 0.403457 0.310490     LSTM_S-Clientes.csv
# 114       CRM_DJ_12T1 0.318343 0.236305     LSTM_S-Clientes.csv
# 115       CTE_DJ_12B1 0.189881 0.143375     LSTM_S-Clientes.csv
# 116       CTL_DJ_12B1 1.420327 1.240668     LSTM_S-Clientes.csv
# 117       CTR_DJ_12B1 0.647422 0.499872     LSTM_S-Clientes.csv
# 118       DIN_DJ_12B1 0.174380 0.121343     LSTM_S-Clientes.csv
# 119       DST_DJ_12B1 1.217241 1.079594     LSTM_S-Clientes.csv
# 120       DST_DJ_12B2 0.424021 0.319811     LSTM_S-Clientes.csv
# 121       ESP_DJ_12B1 0.306564 0.227872     LSTM_S-Clientes.csv
# 122       GBA_DJ_12B1 0.399036 0.306447     LSTM_S-Clientes.csv
# 123       GBA_DJ_12B2 0.949479 0.745201     LSTM_S-Clientes.csv
# 124       IBR_DJ_12B1 0.098914 0.078982     LSTM_S-Clientes.csv
# 125       ILB_DJ_12B1 0.463948 0.332775     LSTM_S-Clientes.csv
# 126       ITA_DJ_12B1 0.738372 0.527945     LSTM_S-Clientes.csv
# 127       ITO_DJ_12B1 0.559660 0.417060     LSTM_S-Clientes.csv
# 128       JCU_DJ_12B1 0.208094 0.153685     LSTM_S-Clientes.csv
# 129       JRC_DJ_12B1 0.238088 0.188195     LSTM_S-Clientes.csv
# 130       JTB_DJ_12B1 1.054862 0.892839     LSTM_S-Clientes.csv
# 131       JZR_DJ_12B1 0.345637 0.255499     LSTM_S-Clientes.csv
# 132       LCN_DJ_12B1 0.677530 0.542835     LSTM_S-Clientes.csv
# 133       MAA_DJ_12B1 0.666858 0.513506     LSTM_S-Clientes.csv
# 134       MGB_DJ_12B1 1.210892 0.945092     LSTM_S-Clientes.csv
# 135       MGB_DJ_12B2 0.782011 0.562141     LSTM_S-Clientes.csv
# 136       MLT_DJ_12B1 0.402345 0.302887     LSTM_S-Clientes.csv
# 137       MNT_DJ_12T1 0.398801 0.294123     LSTM_S-Clientes.csv
# 138       MRO_DJ_12B1 0.484014 0.362656     LSTM_S-Clientes.csv
# 139       MRU_DJ_12B1 0.531772 0.444346     LSTM_S-Clientes.csv
# 140       MRU_DJ_12B2 1.056566 0.771893     LSTM_S-Clientes.csv
# 141       ORT_DJ_12B1 0.462336 0.365075     LSTM_S-Clientes.csv
# 142       PBL_DJ_12B1 0.640775 0.491936     LSTM_S-Clientes.csv
# 143       PCI_DJ_12B1 0.180343 0.142968     LSTM_S-Clientes.csv
# 144       PCO_DJ_12B1 0.470323 0.321844     LSTM_S-Clientes.csv
# 145       PLT_DJ_12B1 0.385269 0.321475     LSTM_S-Clientes.csv
# 146       PLV_DJ_12B1 0.129224 0.097264     LSTM_S-Clientes.csv
# 147       POC_DJ_12B1 0.195989 0.154593     LSTM_S-Clientes.csv
# 148       PRI_DJ_12B1 0.383320 0.277933     LSTM_S-Clientes.csv
# 149       PRT_DJ_12B1 1.223500 1.088492     LSTM_S-Clientes.csv
# 150       PTS_DJ_12B1 0.987154 0.768960     LSTM_S-Clientes.csv
# 151       QMD_DJ_12B1 0.552274 0.467250     LSTM_S-Clientes.csv
# 152       RIC_DJ_12B1 0.738497 0.611424     LSTM_S-Clientes.csv
# 153       RTT_DJ_12B1 0.902922 0.651807     LSTM_S-Clientes.csv
# 154       RTT_DJ_12B2 0.602467 0.451176     LSTM_S-Clientes.csv
# 155       SBT_DJ_12B1 1.049619 0.856124     LSTM_S-Clientes.csv
# 156       SGL_DJ_12T1 0.488769 0.389246     LSTM_S-Clientes.csv
# 157       SJC_DJ_12T1 0.226637 0.164539     LSTM_S-Clientes.csv
# 158       SLD_DJ_12B1 0.134011 0.107766     LSTM_S-Clientes.csv
# 159       SLZ_DJ_12B1 0.308723 0.239676     LSTM_S-Clientes.csv
# 160       SPE_DJ_12B2 1.049028 0.822947     LSTM_S-Clientes.csv
# 161       SPX_DJ_12B1 0.395036 0.270799     LSTM_S-Clientes.csv
# 162       STR_DJ_12B1 0.709671 0.504029     LSTM_S-Clientes.csv
# 163       STR_DJ_12B2 0.889456 0.728429     LSTM_S-Clientes.csv
# 164       SZA_DJ_12B1 0.753570 0.607273     LSTM_S-Clientes.csv
# 165       SZA_DJ_12B2 0.716307 0.529926     LSTM_S-Clientes.csv
# 166       TBU_DJ_12B1 0.879845 0.625780     LSTM_S-Clientes.csv
# 167       TBU_DJ_12B2 1.024744 0.756364     LSTM_S-Clientes.csv
# 168       TXR_DJ_12B1 0.263092 0.197043     LSTM_S-Clientes.csv
# 169       URN_DJ_12B1 0.008141 0.006203     LSTM_S-Clientes.csv
# 170       ABR_DJ_12B1 0.418541 0.332519           LSTM_S-GD.csv
# 171       AER_DJ_12B1 0.654038 0.482588           LSTM_S-GD.csv
# 172       APL_DJ_12B1 0.400159 0.286088           LSTM_S-GD.csv
# 173       ARA_DJ_12B1 0.555211 0.424502           LSTM_S-GD.csv
# 174       ARN_DJ_12B1 0.091329 0.064065           LSTM_S-GD.csv
# 175       ARR_DJ_12B1 0.173549 0.131073           LSTM_S-GD.csv
# 176       BBR_DJ_12B1 0.422743 0.329981           LSTM_S-GD.csv
# 177       BBR_DJ_12B2 0.407901 0.298856           LSTM_S-GD.csv
# 178       BJC_DJ_12B1 0.235191 0.172137           LSTM_S-GD.csv
# 179       BNR_DJ_12B1 0.562734 0.423334           LSTM_S-GD.csv
# 180       BQR_DJ_12B1 0.330414 0.256879           LSTM_S-GD.csv
# 181       BSA_DJ_12B1 1.260248 0.883439           LSTM_S-GD.csv
# 182       BSA_DJ_12B2 0.713251 0.520798           LSTM_S-GD.csv
# 183       BVA_DJ_12T1 0.414322 0.355473           LSTM_S-GD.csv
# 184       BVT_DJ_12B1 0.534962 0.376141           LSTM_S-GD.csv
# 185       BVT_DJ_12B2 0.233445 0.182473           LSTM_S-GD.csv
# 186       BYX_DJ_12B1 0.771513 0.575001           LSTM_S-GD.csv
# 187       CAA_DJ_12B1 0.474295 0.376059           LSTM_S-GD.csv
# 188       CBD_DJ_12B1 1.114346 0.822665           LSTM_S-GD.csv
# 189       CBD_DJ_12B2 0.725246 0.558702           LSTM_S-GD.csv
# 190       CDE_DJ_12B1 0.866889 0.639057           LSTM_S-GD.csv
# 191       CGU_DJ_12B1 0.349450 0.282536           LSTM_S-GD.csv
# 192       CGU_DJ_12B2 0.280617 0.227132           LSTM_S-GD.csv
# 193       CJZ_DJ_12B1 1.056614 0.827513           LSTM_S-GD.csv
# 194       CJZ_DJ_12B2 1.058319 0.829452           LSTM_S-GD.csv
# 195       CPX_DJ_12B1 0.212022 0.158307           LSTM_S-GD.csv
# 196       CPX_DJ_12B2 0.919786 0.666845           LSTM_S-GD.csv
# 197       CRI_DJ_12B1 0.876753 0.652869           LSTM_S-GD.csv
# 198       CRI_DJ_12B2 0.404073 0.310531           LSTM_S-GD.csv
# 199       CRM_DJ_12T1 0.316195 0.234330           LSTM_S-GD.csv
# 200       CTE_DJ_12B1 0.194776 0.145999           LSTM_S-GD.csv
# 201       CTL_DJ_12B1 1.346985 1.121589           LSTM_S-GD.csv
# 202       CTR_DJ_12B1 0.652528 0.501687           LSTM_S-GD.csv
# 203       DIN_DJ_12B1 0.165607 0.116168           LSTM_S-GD.csv
# 204       DST_DJ_12B1 1.164155 1.002329           LSTM_S-GD.csv
# 205       DST_DJ_12B2 0.425301 0.316968           LSTM_S-GD.csv
# 206       ESP_DJ_12B1 0.282515 0.204038           LSTM_S-GD.csv
# 207       GBA_DJ_12B1 0.383206 0.292447           LSTM_S-GD.csv
# 208       GBA_DJ_12B2 0.876670 0.681990           LSTM_S-GD.csv
# 209       IBR_DJ_12B1 0.106023 0.086343           LSTM_S-GD.csv
# 210       ILB_DJ_12B1 0.501007 0.370470           LSTM_S-GD.csv
# 211       ITA_DJ_12B1 0.726998 0.524449           LSTM_S-GD.csv
# 212       ITO_DJ_12B1 0.540960 0.407538           LSTM_S-GD.csv
# 213       JCU_DJ_12B1 0.184988 0.135590           LSTM_S-GD.csv
# 214       JRC_DJ_12B1 0.224002 0.169303           LSTM_S-GD.csv
# 215       JTB_DJ_12B1 0.950091 0.769801           LSTM_S-GD.csv
# 216       JZR_DJ_12B1 0.336859 0.246293           LSTM_S-GD.csv
# 217       LCN_DJ_12B1 0.638971 0.473737           LSTM_S-GD.csv
# 218       MAA_DJ_12B1 0.651007 0.499008           LSTM_S-GD.csv
# 219       MGB_DJ_12B1 1.326196 1.078502           LSTM_S-GD.csv
# 220       MGB_DJ_12B2 0.796852 0.574418           LSTM_S-GD.csv
# 221       MLT_DJ_12B1 0.403129 0.303594           LSTM_S-GD.csv
# 222       MNT_DJ_12T1 0.414795 0.310754           LSTM_S-GD.csv
# 223       MRO_DJ_12B1 0.482679 0.362733           LSTM_S-GD.csv
# 224       MRU_DJ_12B1 0.493478 0.403615           LSTM_S-GD.csv
# 225       MRU_DJ_12B2 1.032313 0.741232           LSTM_S-GD.csv
# 226       ORT_DJ_12B1 0.446134 0.351726           LSTM_S-GD.csv
# 227       PBL_DJ_12B1 0.636639 0.486558           LSTM_S-GD.csv
# 228       PCI_DJ_12B1 0.180601 0.143315           LSTM_S-GD.csv
# 229       PCO_DJ_12B1 0.468216 0.324817           LSTM_S-GD.csv
# 230       PLT_DJ_12B1 0.389298 0.325335           LSTM_S-GD.csv
# 231       PLV_DJ_12B1 0.129249 0.097758           LSTM_S-GD.csv
# 232       POC_DJ_12B1 0.196319 0.155561           LSTM_S-GD.csv
# 233       PRI_DJ_12B1 0.384173 0.284562           LSTM_S-GD.csv
# 234       PRT_DJ_12B1 1.555632 1.451747           LSTM_S-GD.csv
# 235       PTS_DJ_12B1 0.930791 0.675180           LSTM_S-GD.csv
# 236       QMD_DJ_12B1 0.565793 0.483709           LSTM_S-GD.csv
# 237       RIC_DJ_12B1 0.761622 0.616470           LSTM_S-GD.csv
# 238       RTT_DJ_12B1 0.885739 0.630655           LSTM_S-GD.csv
# 239       RTT_DJ_12B2 0.597574 0.452185           LSTM_S-GD.csv
# 240       SBT_DJ_12B1 1.061019 0.877570           LSTM_S-GD.csv
# 241       SGL_DJ_12T1 0.480352 0.384842           LSTM_S-GD.csv
# 242       SJC_DJ_12T1 0.213274 0.148005           LSTM_S-GD.csv
# 243       SLD_DJ_12B1 0.132591 0.106304           LSTM_S-GD.csv
# 244       SLZ_DJ_12B1 0.320515 0.253697           LSTM_S-GD.csv
# 245       SPE_DJ_12B2 1.048052 0.811297           LSTM_S-GD.csv
# 246       SPX_DJ_12B1 0.434740 0.315726           LSTM_S-GD.csv
# 247       STR_DJ_12B1 0.788947 0.559684           LSTM_S-GD.csv
# 248       STR_DJ_12B2 0.893905 0.720345           LSTM_S-GD.csv
# 249       SZA_DJ_12B1 0.772351 0.627400           LSTM_S-GD.csv
# 250       SZA_DJ_12B2 0.707129 0.524613           LSTM_S-GD.csv
# 251       TBU_DJ_12B1 0.913347 0.640026           LSTM_S-GD.csv
# 252       TBU_DJ_12B2 0.999869 0.738998           LSTM_S-GD.csv
# 253       TXR_DJ_12B1 0.256933 0.187653           LSTM_S-GD.csv
# 254       URN_DJ_12B1 0.024189 0.022834           LSTM_S-GD.csv
# 255       ABR_DJ_12B1 1.097466 0.952425              LSTM_S.csv
# 256       AER_DJ_12B1 0.899263 0.667245              LSTM_S.csv
# 257       APL_DJ_12B1 0.650803 0.520992              LSTM_S.csv
# 258       ARA_DJ_12B1 0.666353 0.504016              LSTM_S.csv
# 259       ARN_DJ_12B1 0.187055 0.133402              LSTM_S.csv
# 260       ARR_DJ_12B1 0.209494 0.172886              LSTM_S.csv
# 261       BBR_DJ_12B1 0.508158 0.353014              LSTM_S.csv
# 262       BBR_DJ_12B2 0.660895 0.504280              LSTM_S.csv
# 263       BJC_DJ_12B1 0.275925 0.182124              LSTM_S.csv
# 264       BNR_DJ_12B1 1.152067 0.973154              LSTM_S.csv
# 265       BQR_DJ_12B1 0.756349 0.580639              LSTM_S.csv
# 266       BSA_DJ_12B1 1.171291 0.946047              LSTM_S.csv
# 267       BSA_DJ_12B2 0.817545 0.523669              LSTM_S.csv
# 268       BVA_DJ_12T1 0.356059 0.264212              LSTM_S.csv
# 269       BVT_DJ_12B1 0.861446 0.609506              LSTM_S.csv
# 270       BVT_DJ_12B2 0.758667 0.554894              LSTM_S.csv
# 271       BYX_DJ_12B1 0.866177 0.708213              LSTM_S.csv
# 272       CAA_DJ_12B1 0.467606 0.321037              LSTM_S.csv
# 273       CBD_DJ_12B1 1.081693 0.769327              LSTM_S.csv
# 274       CBD_DJ_12B2 0.739123 0.466394              LSTM_S.csv
# 275       CDE_DJ_12B1 1.331774 1.014557              LSTM_S.csv
# 276       CGD_DJ_11T7 0.953671 0.761198              LSTM_S.csv
# 277       CGU_DJ_12B1 2.396500 2.155845              LSTM_S.csv
# 278       CGU_DJ_12B2 0.390269 0.296151              LSTM_S.csv
# 279       CJZ_DJ_12B1 1.303084 1.021518              LSTM_S.csv
# 280       CJZ_DJ_12B2 0.932514 0.748872              LSTM_S.csv
# 281       CPX_DJ_12B1 2.170832 1.530684              LSTM_S.csv
# 282       CPX_DJ_12B2 1.837575 1.351068              LSTM_S.csv
# 283       CRI_DJ_12B1 0.983497 0.768188              LSTM_S.csv
# 284       CRI_DJ_12B2 0.440866 0.316282              LSTM_S.csv
# 285       CRM_DJ_12T1 0.268615 0.194502              LSTM_S.csv
# 286       CTE_DJ_12B1 0.534093 0.443497              LSTM_S.csv
# 287       CTL_DJ_12B1 1.839126 1.497723              LSTM_S.csv
# 288       CTR_DJ_12B1 0.723228 0.584055              LSTM_S.csv
# 289       DIN_DJ_12B1 0.199260 0.156277              LSTM_S.csv
# 290       DST_DJ_12B1 1.339808 1.157309              LSTM_S.csv
# 291       DST_DJ_12B2 0.421659 0.298451              LSTM_S.csv
# 292       ESP_DJ_12B1 0.491100 0.362444              LSTM_S.csv
# 293       GBA_DJ_12B1 0.341201 0.268942              LSTM_S.csv
# 294       GBA_DJ_12B2 1.680567 1.456979              LSTM_S.csv
# 295       IBR_DJ_12B1 0.136158 0.110049              LSTM_S.csv
# 296       ILB_DJ_12B1 0.928292 0.657564              LSTM_S.csv
# 297       ITA_DJ_12B1 0.751674 0.575468              LSTM_S.csv
# 298       ITO_DJ_12B1 0.642921 0.492870              LSTM_S.csv
# 299       JCU_DJ_12B1 0.217406 0.162209              LSTM_S.csv
# 300       JPS_DJ_12B1 2.568425 1.903170              LSTM_S.csv
# 301       JPS_DJ_12B2 1.721755 1.318604              LSTM_S.csv
# 302       JRC_DJ_12B1 0.197047 0.145956              LSTM_S.csv
# 303       JTB_DJ_12B1 0.998646 0.776981              LSTM_S.csv
# 304       JZR_DJ_12B1 0.561823 0.458756              LSTM_S.csv
# 305       LCN_DJ_12B1 0.492239 0.324356              LSTM_S.csv
# 306       MAA_DJ_12B1 0.616887 0.460609              LSTM_S.csv
# 307       MGB_DJ_12B1 1.101761 0.876234              LSTM_S.csv
# 308       MGB_DJ_12B2 0.707403 0.445208              LSTM_S.csv
# 309       MLT_DJ_12B1 0.281399 0.195070              LSTM_S.csv
# 310       MNT_DJ_12T1 0.650944 0.533195              LSTM_S.csv
# 311       MRO_DJ_12B1 0.970499 0.683618              LSTM_S.csv
# 312       MRU_DJ_12B1 0.420331 0.324681              LSTM_S.csv
# 313       MRU_DJ_12B2 0.854295 0.654129              LSTM_S.csv
# 314       ORT_DJ_12B1 0.591868 0.489829              LSTM_S.csv
# 315       PBL_DJ_12B1 0.518959 0.381494              LSTM_S.csv
# 316       PCI_DJ_12B1 0.324195 0.278889              LSTM_S.csv
# 317       PCO_DJ_12B1 0.427513 0.324456              LSTM_S.csv
# 318       PLT_DJ_12B1 0.331131 0.255948              LSTM_S.csv
# 319       PLU_DJ_12B1 0.445060 0.308032              LSTM_S.csv
# 320   PLU_DJ_12B1_D_P 0.000000 0.000000              LSTM_S.csv
# 321       PLV_DJ_12B1 0.274651 0.209961              LSTM_S.csv
# 322       POC_DJ_12B1 0.241117 0.201378              LSTM_S.csv
# 323       PRI_DJ_12B1 0.433038 0.346283              LSTM_S.csv
# 324       PRT_DJ_12B1 1.339530 0.981559              LSTM_S.csv
# 325       PTS_DJ_12B1 1.008527 0.774105              LSTM_S.csv
# 326       QMD_DJ_12B1 0.535735 0.406008              LSTM_S.csv
# 327       RIC_DJ_12B1 0.752131 0.645533              LSTM_S.csv
# 328       RTT_DJ_12B1 1.269377 0.908604              LSTM_S.csv
# 329       RTT_DJ_12B2 0.574913 0.417997              LSTM_S.csv
# 330       SBT_DJ_12B1 1.025888 0.856710              LSTM_S.csv
# 331       SGL_DJ_12T1 0.468452 0.366336              LSTM_S.csv
# 332       SJC_DJ_12T1 0.350668 0.289597              LSTM_S.csv
# 333       SLD_DJ_12B1 0.301507 0.249999              LSTM_S.csv
# 334       SLZ_DJ_12B1 0.341817 0.278298              LSTM_S.csv
# 335       SPE_DJ_12B2 1.026157 0.811343              LSTM_S.csv
# 336       SPX_DJ_12B1 0.322043 0.245936              LSTM_S.csv
# 337       STR_DJ_12B1 0.537587 0.425989              LSTM_S.csv
# 338       STR_DJ_12B2 0.989419 0.782120              LSTM_S.csv
# 339       SZA_DJ_12B1 0.550107 0.426206              LSTM_S.csv
# 340       SZA_DJ_12B2 0.691652 0.511720              LSTM_S.csv
# 341       TBU_DJ_12B1 1.864505 1.617375              LSTM_S.csv
# 342       TBU_DJ_12B2 1.035706 0.790349              LSTM_S.csv
# 343       TXR_DJ_12B1 0.288164 0.223722              LSTM_S.csv
# 344       URN_DJ_12B1 0.091906 0.090212              LSTM_S.csv
# 345       ABR_DJ_12B1 0.584535 0.481702   RFR_S-Clientes-GD.csv
# 346       AER_DJ_12B1 0.654778 0.578298   RFR_S-Clientes-GD.csv
# 347       APL_DJ_12B1 1.041853 0.893131   RFR_S-Clientes-GD.csv
# 348       ARA_DJ_12B1 0.918812 0.771668   RFR_S-Clientes-GD.csv
# 349       ARN_DJ_12B1 0.251020 0.208033   RFR_S-Clientes-GD.csv
# 350       ARR_DJ_12B1 0.334481 0.267401   RFR_S-Clientes-GD.csv
# 351       BBR_DJ_12B1 0.423017 0.308688   RFR_S-Clientes-GD.csv
# 352       BBR_DJ_12B2 1.367257 1.289519   RFR_S-Clientes-GD.csv
# 353       BJC_DJ_12B1 0.631523 0.500732   RFR_S-Clientes-GD.csv
# 354       BNR_DJ_12B1 0.858838 0.713057   RFR_S-Clientes-GD.csv
# 355       BQR_DJ_12B1 0.895083 0.676871   RFR_S-Clientes-GD.csv
# 356       BSA_DJ_12B1 2.048443 1.778980   RFR_S-Clientes-GD.csv
# 357       BSA_DJ_12B2 1.703712 1.281976   RFR_S-Clientes-GD.csv
# 358       BVA_DJ_12T1 0.446699 0.383309   RFR_S-Clientes-GD.csv
# 359       BVT_DJ_12B1 0.634965 0.428999   RFR_S-Clientes-GD.csv
# 360       BVT_DJ_12B2 0.316354 0.266493   RFR_S-Clientes-GD.csv
# 361       BYX_DJ_12B1 1.161581 0.966864   RFR_S-Clientes-GD.csv
# 362       CAA_DJ_12B1 0.588535 0.488480   RFR_S-Clientes-GD.csv
# 363       CBD_DJ_12B1 1.327508 0.974006   RFR_S-Clientes-GD.csv
# 364       CBD_DJ_12B2 1.071606 0.802609   RFR_S-Clientes-GD.csv
# 365       CDE_DJ_12B1 1.102301 0.845951   RFR_S-Clientes-GD.csv
# 366       CGU_DJ_12B1 0.930899 0.757324   RFR_S-Clientes-GD.csv
# 367       CGU_DJ_12B2 0.358975 0.292372   RFR_S-Clientes-GD.csv
# 368       CJZ_DJ_12B1 1.386919 1.142146   RFR_S-Clientes-GD.csv
# 369       CJZ_DJ_12B2 2.931089 2.391565   RFR_S-Clientes-GD.csv
# 370       CPX_DJ_12B1 0.401539 0.350852   RFR_S-Clientes-GD.csv
# 371       CPX_DJ_12B2 1.523719 1.336485   RFR_S-Clientes-GD.csv
# 372       CRI_DJ_12B1 1.071198 0.856090   RFR_S-Clientes-GD.csv
# 373       CRI_DJ_12B2 0.889779 0.725523   RFR_S-Clientes-GD.csv
# 374       CRM_DJ_12T1 1.109356 0.886989   RFR_S-Clientes-GD.csv
# 375       CTE_DJ_12B1 0.443893 0.373203   RFR_S-Clientes-GD.csv
# 376       CTL_DJ_12B1 1.532789 1.218108   RFR_S-Clientes-GD.csv
# 377       CTR_DJ_12B1 1.549779 1.206394   RFR_S-Clientes-GD.csv
# 378       DIN_DJ_12B1 0.424670 0.373878   RFR_S-Clientes-GD.csv
# 379       DST_DJ_12B1 1.185106 1.001595   RFR_S-Clientes-GD.csv
# 380       DST_DJ_12B2 0.357417 0.277372   RFR_S-Clientes-GD.csv
# 381       ESP_DJ_12B1 0.525672 0.440008   RFR_S-Clientes-GD.csv
# 382       GBA_DJ_12B1 0.483065 0.389134   RFR_S-Clientes-GD.csv
# 383       GBA_DJ_12B2 1.655401 1.430328   RFR_S-Clientes-GD.csv
# 384       IBR_DJ_12B1 0.327098 0.243824   RFR_S-Clientes-GD.csv
# 385       ILB_DJ_12B1 1.342931 1.134899   RFR_S-Clientes-GD.csv
# 386       ITA_DJ_12B1 2.240147 1.991438   RFR_S-Clientes-GD.csv
# 387       ITO_DJ_12B1 1.433045 1.093091   RFR_S-Clientes-GD.csv
# 388       JCU_DJ_12B1 0.882681 0.772957   RFR_S-Clientes-GD.csv
# 389       JRC_DJ_12B1 0.424916 0.343514   RFR_S-Clientes-GD.csv
# 390       JTB_DJ_12B1 1.410755 1.133670   RFR_S-Clientes-GD.csv
# 391       JZR_DJ_12B1 0.515339 0.420296   RFR_S-Clientes-GD.csv
# 392       LCN_DJ_12B1 0.762722 0.583383   RFR_S-Clientes-GD.csv
# 393       MAA_DJ_12B1 0.715887 0.555266   RFR_S-Clientes-GD.csv
# 394       MGB_DJ_12B1 2.152226 1.771112   RFR_S-Clientes-GD.csv
# 395       MGB_DJ_12B2 1.479919 1.244806   RFR_S-Clientes-GD.csv
# 396       MLT_DJ_12B1 0.704842 0.580800   RFR_S-Clientes-GD.csv
# 397       MNT_DJ_12T1 1.067940 0.808889   RFR_S-Clientes-GD.csv
# 398       MRO_DJ_12B1 1.099894 0.965744   RFR_S-Clientes-GD.csv
# 399       MRU_DJ_12B1 0.813681 0.665110   RFR_S-Clientes-GD.csv
# 400       MRU_DJ_12B2 2.530632 2.250973   RFR_S-Clientes-GD.csv
# 401       ORT_DJ_12B1 1.033248 0.850246   RFR_S-Clientes-GD.csv
# 402       PBL_DJ_12B1 1.187207 0.932167   RFR_S-Clientes-GD.csv
# 403       PCI_DJ_12B1 0.264734 0.220122   RFR_S-Clientes-GD.csv
# 404       PCO_DJ_12B1 1.281808 0.979791   RFR_S-Clientes-GD.csv
# 405       PLT_DJ_12B1 0.716559 0.569258   RFR_S-Clientes-GD.csv
# 406       PLV_DJ_12B1 0.196794 0.163931   RFR_S-Clientes-GD.csv
# 407       POC_DJ_12B1 0.216303 0.178982   RFR_S-Clientes-GD.csv
# 408       PRI_DJ_12B1 1.105334 0.831785   RFR_S-Clientes-GD.csv
# 409       PRT_DJ_12B1 0.919894 0.714576   RFR_S-Clientes-GD.csv
# 410       PTS_DJ_12B1 1.779266 1.466303   RFR_S-Clientes-GD.csv
# 411       QMD_DJ_12B1 0.567878 0.448101   RFR_S-Clientes-GD.csv
# 412       RIC_DJ_12B1 0.899633 0.726063   RFR_S-Clientes-GD.csv
# 413       RTT_DJ_12B1 1.383707 1.114295   RFR_S-Clientes-GD.csv
# 414       RTT_DJ_12B2 0.930289 0.741437   RFR_S-Clientes-GD.csv
# 415       SBT_DJ_12B1 2.119543 1.743130   RFR_S-Clientes-GD.csv
# 416       SGL_DJ_12T1 1.484900 1.134566   RFR_S-Clientes-GD.csv
# 417       SJC_DJ_12T1 0.335862 0.268736   RFR_S-Clientes-GD.csv
# 418       SLD_DJ_12B1 0.150623 0.124999   RFR_S-Clientes-GD.csv
# 419       SLZ_DJ_12B1 0.579592 0.459811   RFR_S-Clientes-GD.csv
# 420       SPE_DJ_12B2 2.614179 1.960017   RFR_S-Clientes-GD.csv
# 421       SPX_DJ_12B1 0.904474 0.702468   RFR_S-Clientes-GD.csv
# 422       STR_DJ_12B1 1.519370 1.260279   RFR_S-Clientes-GD.csv
# 423       STR_DJ_12B2 1.153297 0.910650   RFR_S-Clientes-GD.csv
# 424       SZA_DJ_12B1 2.016643 1.681316   RFR_S-Clientes-GD.csv
# 425       SZA_DJ_12B2 1.286010 1.085985   RFR_S-Clientes-GD.csv
# 426       TBU_DJ_12B1 1.992317 1.407398   RFR_S-Clientes-GD.csv
# 427       TBU_DJ_12B2 1.981728 1.720675   RFR_S-Clientes-GD.csv
# 428       TXR_DJ_12B1 0.321546 0.245348   RFR_S-Clientes-GD.csv
# 429       URN_DJ_12B1 0.142431 0.127665   RFR_S-Clientes-GD.csv
# 430       ABR_DJ_12B1 0.608382 0.508777      RFR_S-Clientes.csv
# 431       AER_DJ_12B1 0.633277 0.558602      RFR_S-Clientes.csv
# 432       APL_DJ_12B1 1.043057 0.866591      RFR_S-Clientes.csv
# 433       ARA_DJ_12B1 0.781081 0.644746      RFR_S-Clientes.csv
# 434       ARN_DJ_12B1 0.242260 0.203315      RFR_S-Clientes.csv
# 435       ARR_DJ_12B1 0.327136 0.262807      RFR_S-Clientes.csv
# 436       BBR_DJ_12B1 0.407768 0.302381      RFR_S-Clientes.csv
# 437       BBR_DJ_12B2 1.467362 1.387221      RFR_S-Clientes.csv
# 438       BJC_DJ_12B1 0.592183 0.456994      RFR_S-Clientes.csv
# 439       BNR_DJ_12B1 0.811957 0.671513      RFR_S-Clientes.csv
# 440       BQR_DJ_12B1 0.864667 0.645497      RFR_S-Clientes.csv
# 441       BSA_DJ_12B1 1.905529 1.607754      RFR_S-Clientes.csv
# 442       BSA_DJ_12B2 1.722825 1.283600      RFR_S-Clientes.csv
# 443       BVA_DJ_12T1 0.442358 0.379129      RFR_S-Clientes.csv
# 444       BVT_DJ_12B1 0.620817 0.419478      RFR_S-Clientes.csv
# 445       BVT_DJ_12B2 0.300100 0.249416      RFR_S-Clientes.csv
# 446       BYX_DJ_12B1 1.024773 0.834656      RFR_S-Clientes.csv
# 447       CAA_DJ_12B1 0.569045 0.477867      RFR_S-Clientes.csv
# 448       CBD_DJ_12B1 1.286895 1.003360      RFR_S-Clientes.csv
# 449       CBD_DJ_12B2 1.034462 0.772573      RFR_S-Clientes.csv
# 450       CDE_DJ_12B1 1.071235 0.809169      RFR_S-Clientes.csv
# 451       CGU_DJ_12B1 0.952958 0.771233      RFR_S-Clientes.csv
# 452       CGU_DJ_12B2 0.355026 0.290987      RFR_S-Clientes.csv
# 453       CJZ_DJ_12B1 1.400314 1.132185      RFR_S-Clientes.csv
# 454       CJZ_DJ_12B2 2.765283 2.219200      RFR_S-Clientes.csv
# 455       CPX_DJ_12B1 0.370804 0.319538      RFR_S-Clientes.csv
# 456       CPX_DJ_12B2 1.677193 1.498514      RFR_S-Clientes.csv
# 457       CRI_DJ_12B1 1.089320 0.887905      RFR_S-Clientes.csv
# 458       CRI_DJ_12B2 0.800379 0.642043      RFR_S-Clientes.csv
# 459       CRM_DJ_12T1 0.999907 0.814359      RFR_S-Clientes.csv
# 460       CTE_DJ_12B1 0.463795 0.397727      RFR_S-Clientes.csv
# 461       CTL_DJ_12B1 1.581084 1.305745      RFR_S-Clientes.csv
# 462       CTR_DJ_12B1 1.516950 1.179470      RFR_S-Clientes.csv
# 463       DIN_DJ_12B1 0.449686 0.401338      RFR_S-Clientes.csv
# 464       DST_DJ_12B1 1.184579 1.002630      RFR_S-Clientes.csv
# 465       DST_DJ_12B2 0.377878 0.302536      RFR_S-Clientes.csv
# 466       ESP_DJ_12B1 0.505185 0.420915      RFR_S-Clientes.csv
# 467       GBA_DJ_12B1 0.520697 0.425070      RFR_S-Clientes.csv
# 468       GBA_DJ_12B2 1.603797 1.393101      RFR_S-Clientes.csv
# 469       IBR_DJ_12B1 0.325284 0.243003      RFR_S-Clientes.csv
# 470       ILB_DJ_12B1 1.264902 1.049877      RFR_S-Clientes.csv
# 471       ITA_DJ_12B1 2.165794 1.899290      RFR_S-Clientes.csv
# 472       ITO_DJ_12B1 1.414634 1.082365      RFR_S-Clientes.csv
# 473       JCU_DJ_12B1 0.885555 0.769921      RFR_S-Clientes.csv
# 474       JRC_DJ_12B1 0.410317 0.333403      RFR_S-Clientes.csv
# 475       JTB_DJ_12B1 1.345380 1.088626      RFR_S-Clientes.csv
# 476       JZR_DJ_12B1 0.509727 0.408374      RFR_S-Clientes.csv
# 477       LCN_DJ_12B1 0.701740 0.530610      RFR_S-Clientes.csv
# 478       MAA_DJ_12B1 0.690075 0.529705      RFR_S-Clientes.csv
# 479       MGB_DJ_12B1 2.030394 1.686920      RFR_S-Clientes.csv
# 480       MGB_DJ_12B2 1.478480 1.236799      RFR_S-Clientes.csv
# 481       MLT_DJ_12B1 0.698733 0.577784      RFR_S-Clientes.csv
# 482       MNT_DJ_12T1 1.073763 0.812552      RFR_S-Clientes.csv
# 483       MRO_DJ_12B1 1.132987 0.979255      RFR_S-Clientes.csv
# 484       MRU_DJ_12B1 0.804179 0.660592      RFR_S-Clientes.csv
# 485       MRU_DJ_12B2 2.881528 2.577815      RFR_S-Clientes.csv
# 486       ORT_DJ_12B1 1.008440 0.827109      RFR_S-Clientes.csv
# 487       PBL_DJ_12B1 1.165531 0.913857      RFR_S-Clientes.csv
# 488       PCI_DJ_12B1 0.248390 0.203571      RFR_S-Clientes.csv
# 489       PCO_DJ_12B1 1.160581 0.888816      RFR_S-Clientes.csv
# 490       PLT_DJ_12B1 0.730962 0.578752      RFR_S-Clientes.csv
# 491       PLV_DJ_12B1 0.215240 0.179926      RFR_S-Clientes.csv
# 492       POC_DJ_12B1 0.204959 0.168172      RFR_S-Clientes.csv
# 493       PRI_DJ_12B1 1.062273 0.790365      RFR_S-Clientes.csv
# 494       PRT_DJ_12B1 0.880987 0.671965      RFR_S-Clientes.csv
# 495       PTS_DJ_12B1 1.763773 1.456056      RFR_S-Clientes.csv
# 496       QMD_DJ_12B1 0.563112 0.443330      RFR_S-Clientes.csv
# 497       RIC_DJ_12B1 0.951107 0.767812      RFR_S-Clientes.csv
# 498       RTT_DJ_12B1 1.371737 1.105349      RFR_S-Clientes.csv
# 499       RTT_DJ_12B2 0.903359 0.719109      RFR_S-Clientes.csv
# 500       SBT_DJ_12B1 2.049223 1.682852      RFR_S-Clientes.csv
# 501       SGL_DJ_12T1 1.423832 1.078687      RFR_S-Clientes.csv
# 502       SJC_DJ_12T1 0.340272 0.274000      RFR_S-Clientes.csv
# 503       SLD_DJ_12B1 0.149104 0.124441      RFR_S-Clientes.csv
# 504       SLZ_DJ_12B1 0.561995 0.446514      RFR_S-Clientes.csv
# 505       SPE_DJ_12B2 2.485298 1.846184      RFR_S-Clientes.csv
# 506       SPX_DJ_12B1 0.912229 0.727355      RFR_S-Clientes.csv
# 507       STR_DJ_12B1 1.597164 1.323913      RFR_S-Clientes.csv
# 508       STR_DJ_12B2 1.102839 0.870507      RFR_S-Clientes.csv
# 509       SZA_DJ_12B1 2.016877 1.703001      RFR_S-Clientes.csv
# 510       SZA_DJ_12B2 1.412217 1.197062      RFR_S-Clientes.csv
# 511       TBU_DJ_12B1 1.946534 1.335522      RFR_S-Clientes.csv
# 512       TBU_DJ_12B2 1.871081 1.579540      RFR_S-Clientes.csv
# 513       TXR_DJ_12B1 0.294656 0.221976      RFR_S-Clientes.csv
# 514       URN_DJ_12B1 0.145559 0.130619      RFR_S-Clientes.csv
# 515       ABR_DJ_12B1 0.532231 0.429310            RFR_S-GD.csv
# 516       AER_DJ_12B1 0.465662 0.377059            RFR_S-GD.csv
# 517       APL_DJ_12B1 0.783600 0.622528            RFR_S-GD.csv
# 518       ARA_DJ_12B1 0.780397 0.635446            RFR_S-GD.csv
# 519       ARN_DJ_12B1 0.248066 0.206335            RFR_S-GD.csv
# 520       ARR_DJ_12B1 0.340168 0.274704            RFR_S-GD.csv
# 521       BBR_DJ_12B1 0.433102 0.313999            RFR_S-GD.csv
# 522       BBR_DJ_12B2 1.265444 1.190661            RFR_S-GD.csv
# 523       BJC_DJ_12B1 0.556842 0.429908            RFR_S-GD.csv
# 524       BNR_DJ_12B1 0.756613 0.608962            RFR_S-GD.csv
# 525       BQR_DJ_12B1 0.787188 0.588470            RFR_S-GD.csv
# 526       BSA_DJ_12B1 1.924230 1.583466            RFR_S-GD.csv
# 527       BSA_DJ_12B2 1.655585 1.204937            RFR_S-GD.csv
# 528       BVA_DJ_12T1 0.379451 0.318828            RFR_S-GD.csv
# 529       BVT_DJ_12B1 0.600252 0.409688            RFR_S-GD.csv
# 530       BVT_DJ_12B2 0.291300 0.239574            RFR_S-GD.csv
# 531       BYX_DJ_12B1 1.214456 1.009140            RFR_S-GD.csv
# 532       CAA_DJ_12B1 0.599163 0.510695            RFR_S-GD.csv
# 533       CBD_DJ_12B1 1.228457 0.958015            RFR_S-GD.csv
# 534       CBD_DJ_12B2 1.072635 0.803745            RFR_S-GD.csv
# 535       CDE_DJ_12B1 1.060586 0.828753            RFR_S-GD.csv
# 536       CGU_DJ_12B1 0.852213 0.700109            RFR_S-GD.csv
# 537       CGU_DJ_12B2 0.347972 0.287180            RFR_S-GD.csv
# 538       CJZ_DJ_12B1 2.087311 1.619199            RFR_S-GD.csv
# 539       CJZ_DJ_12B2 2.482330 1.948028            RFR_S-GD.csv
# 540       CPX_DJ_12B1 0.361258 0.310760            RFR_S-GD.csv
# 541       CPX_DJ_12B2 1.433695 1.085041            RFR_S-GD.csv
# 542       CRI_DJ_12B1 1.020161 0.809072            RFR_S-GD.csv
# 543       CRI_DJ_12B2 0.646075 0.522209            RFR_S-GD.csv
# 544       CRM_DJ_12T1 0.730525 0.569172            RFR_S-GD.csv
# 545       CTE_DJ_12B1 0.423426 0.356272            RFR_S-GD.csv
# 546       CTL_DJ_12B1 1.326064 1.055374            RFR_S-GD.csv
# 547       CTR_DJ_12B1 1.397616 1.086236            RFR_S-GD.csv
# 548       DIN_DJ_12B1 0.407710 0.352904            RFR_S-GD.csv
# 549       DST_DJ_12B1 0.911303 0.763161            RFR_S-GD.csv
# 550       DST_DJ_12B2 0.352801 0.269022            RFR_S-GD.csv
# 551       ESP_DJ_12B1 0.467438 0.387854            RFR_S-GD.csv
# 552       GBA_DJ_12B1 0.549557 0.452669            RFR_S-GD.csv
# 553       GBA_DJ_12B2 1.798552 1.559805            RFR_S-GD.csv
# 554       IBR_DJ_12B1 0.278659 0.210511            RFR_S-GD.csv
# 555       ILB_DJ_12B1 1.109140 0.915796            RFR_S-GD.csv
# 556       ITA_DJ_12B1 2.040432 1.769355            RFR_S-GD.csv
# 557       ITO_DJ_12B1 1.286637 0.978848            RFR_S-GD.csv
# 558       JCU_DJ_12B1 0.869009 0.755710            RFR_S-GD.csv
# 559       JRC_DJ_12B1 0.411925 0.332182            RFR_S-GD.csv
# 560       JTB_DJ_12B1 1.378486 1.119200            RFR_S-GD.csv
# 561       JZR_DJ_12B1 0.510723 0.408571            RFR_S-GD.csv
# 562       LCN_DJ_12B1 0.814369 0.581607            RFR_S-GD.csv
# 563       MAA_DJ_12B1 0.640295 0.491358            RFR_S-GD.csv
# 564       MGB_DJ_12B1 2.091017 1.720948            RFR_S-GD.csv
# 565       MGB_DJ_12B2 1.262579 1.052923            RFR_S-GD.csv
# 566       MLT_DJ_12B1 0.669801 0.548797            RFR_S-GD.csv
# 567       MNT_DJ_12T1 1.061363 0.794802            RFR_S-GD.csv
# 568       MRO_DJ_12B1 0.939039 0.810919            RFR_S-GD.csv
# 569       MRU_DJ_12B1 0.771566 0.630225            RFR_S-GD.csv
# 570       MRU_DJ_12B2 1.625815 1.366851            RFR_S-GD.csv
# 571       ORT_DJ_12B1 0.957489 0.796546            RFR_S-GD.csv
# 572       PBL_DJ_12B1 1.055199 0.833045            RFR_S-GD.csv
# 573       PCI_DJ_12B1 0.255334 0.211117            RFR_S-GD.csv
# 574       PCO_DJ_12B1 1.097522 0.849164            RFR_S-GD.csv
# 575       PLT_DJ_12B1 0.698604 0.554626            RFR_S-GD.csv
# 576       PLV_DJ_12B1 0.199880 0.167087            RFR_S-GD.csv
# 577       POC_DJ_12B1 0.207676 0.165472            RFR_S-GD.csv
# 578       PRI_DJ_12B1 1.054432 0.789059            RFR_S-GD.csv
# 579       PRT_DJ_12B1 0.911774 0.697848            RFR_S-GD.csv
# 580       PTS_DJ_12B1 1.758684 1.432212            RFR_S-GD.csv
# 581       QMD_DJ_12B1 0.538778 0.425169            RFR_S-GD.csv
# 582       RIC_DJ_12B1 0.935889 0.761884            RFR_S-GD.csv
# 583       RTT_DJ_12B1 1.344502 1.084493            RFR_S-GD.csv
# 584       RTT_DJ_12B2 0.843690 0.665030            RFR_S-GD.csv
# 585       SBT_DJ_12B1 1.830407 1.482959            RFR_S-GD.csv
# 586       SGL_DJ_12T1 1.320147 1.015883            RFR_S-GD.csv
# 587       SJC_DJ_12T1 0.287068 0.223555            RFR_S-GD.csv
# 588       SLD_DJ_12B1 0.142964 0.117541            RFR_S-GD.csv
# 589       SLZ_DJ_12B1 0.535670 0.433083            RFR_S-GD.csv
# 590       SPE_DJ_12B2 2.408663 1.764903            RFR_S-GD.csv
# 591       SPX_DJ_12B1 0.798578 0.614160            RFR_S-GD.csv
# 592       STR_DJ_12B1 1.331785 1.101403            RFR_S-GD.csv
# 593       STR_DJ_12B2 1.081292 0.852084            RFR_S-GD.csv
# 594       SZA_DJ_12B1 1.832663 1.510375            RFR_S-GD.csv
# 595       SZA_DJ_12B2 1.193689 0.981565            RFR_S-GD.csv
# 596       TBU_DJ_12B1 1.892701 1.301488            RFR_S-GD.csv
# 597       TBU_DJ_12B2 1.734855 1.492008            RFR_S-GD.csv
# 598       TXR_DJ_12B1 0.296824 0.220967            RFR_S-GD.csv
# 599       URN_DJ_12B1 0.147804 0.132307            RFR_S-GD.csv
# 600       ABR_DJ_12B1 1.379933 1.149840               RFR_S.csv
# 601       AER_DJ_12B1 0.969687 0.808912               RFR_S.csv
# 602       APL_DJ_12B1 0.561075 0.423234               RFR_S.csv
# 603       ARA_DJ_12B1 0.748496 0.594681               RFR_S.csv
# 604       ARN_DJ_12B1 0.238183 0.184333               RFR_S.csv
# 605       ARR_DJ_12B1 0.316875 0.262087               RFR_S.csv
# 606       BBR_DJ_12B1 0.708328 0.515697               RFR_S.csv
# 607       BBR_DJ_12B2 0.826940 0.673551               RFR_S.csv
# 608       BJC_DJ_12B1 0.380550 0.296299               RFR_S.csv
# 609       BNR_DJ_12B1 1.443299 1.198153               RFR_S.csv
# 610       BQR_DJ_12B1 1.083715 0.776977               RFR_S.csv
# 611       BSA_DJ_12B1 1.641139 1.301717               RFR_S.csv
# 612       BSA_DJ_12B2 2.640915 2.097599               RFR_S.csv
# 613       BVA_DJ_12T1 0.361454 0.282932               RFR_S.csv
# 614       BVT_DJ_12B1 1.052548 0.742247               RFR_S.csv
# 615       BVT_DJ_12B2 0.695150 0.450780               RFR_S.csv
# 616       BYX_DJ_12B1 0.677845 0.517440               RFR_S.csv
# 617       CAA_DJ_12B1 0.698057 0.437487               RFR_S.csv
# 618       CBD_DJ_12B1 1.124647 0.891202               RFR_S.csv
# 619       CBD_DJ_12B2 0.862982 0.576357               RFR_S.csv
# 620       CDE_DJ_12B1 1.434207 1.061180               RFR_S.csv
# 621       CGD_DJ_11T7 1.827980 1.523809               RFR_S.csv
# 622       CGU_DJ_12B1 2.315883 1.886690               RFR_S.csv
# 623       CGU_DJ_12B2 0.433551 0.335381               RFR_S.csv
# 624       CJZ_DJ_12B1 1.242181 0.996923               RFR_S.csv
# 625       CJZ_DJ_12B2 2.391698 1.830257               RFR_S.csv
# 626       CPX_DJ_12B1 1.912249 1.261769               RFR_S.csv
# 627       CPX_DJ_12B2 2.369551 1.778142               RFR_S.csv
# 628       CRI_DJ_12B1 1.013950 0.777575               RFR_S.csv
# 629       CRI_DJ_12B2 0.462280 0.342103               RFR_S.csv
# 630       CRM_DJ_12T1 0.473241 0.367362               RFR_S.csv
# 631       CTE_DJ_12B1 0.451118 0.352884               RFR_S.csv
# 632       CTL_DJ_12B1 1.867713 1.490101               RFR_S.csv
# 633       CTR_DJ_12B1 1.002057 0.779616               RFR_S.csv
# 634       DIN_DJ_12B1 0.218631 0.166378               RFR_S.csv
# 635       DST_DJ_12B1 1.134952 0.932143               RFR_S.csv
# 636       DST_DJ_12B2 0.426042 0.337645               RFR_S.csv
# 637       ESP_DJ_12B1 0.550872 0.398624               RFR_S.csv
# 638       GBA_DJ_12B1 0.471316 0.368015               RFR_S.csv
# 639       GBA_DJ_12B2 1.367235 1.133733               RFR_S.csv
# 640       IBR_DJ_12B1 0.562875 0.417595               RFR_S.csv
# 641       ILB_DJ_12B1 1.393108 1.075626               RFR_S.csv
# 642       ITA_DJ_12B1 1.007852 0.763223               RFR_S.csv
# 643       ITO_DJ_12B1 0.713638 0.541145               RFR_S.csv
# 644       JCU_DJ_12B1 0.437817 0.325452               RFR_S.csv
# 645       JPS_DJ_12B1 3.408004 2.725520               RFR_S.csv
# 646       JPS_DJ_12B2 2.221882 1.587923               RFR_S.csv
# 647       JRC_DJ_12B1 1.213313 1.122258               RFR_S.csv
# 648       JTB_DJ_12B1 0.953465 0.732110               RFR_S.csv
# 649       JZR_DJ_12B1 0.579047 0.424501               RFR_S.csv
# 650       LCN_DJ_12B1 0.664491 0.521401               RFR_S.csv
# 651       MAA_DJ_12B1 0.668967 0.524295               RFR_S.csv
# 652       MGB_DJ_12B1 1.790058 1.435709               RFR_S.csv
# 653       MGB_DJ_12B2 0.975026 0.748574               RFR_S.csv
# 654       MLT_DJ_12B1 0.474984 0.387119               RFR_S.csv
# 655       MNT_DJ_12T1 1.270837 0.990738               RFR_S.csv
# 656       MRO_DJ_12B1 1.364242 0.955651               RFR_S.csv
# 657       MRU_DJ_12B1 0.599552 0.491603               RFR_S.csv
# 658       MRU_DJ_12B2 1.091031 0.812665               RFR_S.csv
# 659       ORT_DJ_12B1 0.729013 0.597214               RFR_S.csv
# 660       PBL_DJ_12B1 0.870969 0.706329               RFR_S.csv
# 661       PCI_DJ_12B1 0.455903 0.408935               RFR_S.csv
# 662       PCO_DJ_12B1 0.634395 0.508835               RFR_S.csv
# 663       PLT_DJ_12B1 0.407799 0.326504               RFR_S.csv
# 664       PLU_DJ_12B1 0.567800 0.382844               RFR_S.csv
# 665   PLU_DJ_12B1_D_P 0.000000 0.000000               RFR_S.csv
# 666       PLV_DJ_12B1 0.405003 0.280926               RFR_S.csv
# 667       POC_DJ_12B1 0.237504 0.188068               RFR_S.csv
# 668       PRI_DJ_12B1 0.610077 0.461760               RFR_S.csv
# 669       PRT_DJ_12B1 5.688786 3.527613               RFR_S.csv
# 670       PTS_DJ_12B1 1.345500 1.082724               RFR_S.csv
# 671       QMD_DJ_12B1 0.574225 0.462730               RFR_S.csv
# 672       RIC_DJ_12B1 0.672171 0.537966               RFR_S.csv
# 673       RTT_DJ_12B1 1.342742 0.972461               RFR_S.csv
# 674       RTT_DJ_12B2 0.795270 0.615179               RFR_S.csv
# 675       SBT_DJ_12B1 1.271814 1.032900               RFR_S.csv
# 676       SGL_DJ_12T1 0.812187 0.616638               RFR_S.csv
# 677       SJC_DJ_12T1 0.460224 0.360888               RFR_S.csv
# 678       SLD_DJ_12B1 0.354932 0.272054               RFR_S.csv
# 679       SLZ_DJ_12B1 0.341082 0.273627               RFR_S.csv
# 680       SPE_DJ_12B2 2.115177 1.599928               RFR_S.csv
# 681       SPX_DJ_12B1 0.444824 0.340509               RFR_S.csv
# 682       STR_DJ_12B1 1.332715 1.113538               RFR_S.csv
# 683       STR_DJ_12B2 0.942728 0.710785               RFR_S.csv
# 684       SZA_DJ_12B1 0.727840 0.573395               RFR_S.csv
# 685       SZA_DJ_12B2 0.975019 0.740306               RFR_S.csv
# 686       TBU_DJ_12B1 1.863457 1.475388               RFR_S.csv
# 687       TBU_DJ_12B2 1.778072 1.299430               RFR_S.csv
# 688       TXR_DJ_12B1 0.317518 0.249611               RFR_S.csv
# 689       URN_DJ_12B1 0.147540 0.136219               RFR_S.csv
# 690       ABR_DJ_12B1 0.685124 0.556264   SVR_S-Clientes-GD.csv
# 691       AER_DJ_12B1 0.691882 0.580178   SVR_S-Clientes-GD.csv
# 692       APL_DJ_12B1 1.716778 1.370214   SVR_S-Clientes-GD.csv
# 693       ARA_DJ_12B1 1.234215 0.936433   SVR_S-Clientes-GD.csv
# 694       ARN_DJ_12B1 0.566439 0.485041   SVR_S-Clientes-GD.csv
# 695       ARR_DJ_12B1 1.519919 1.422752   SVR_S-Clientes-GD.csv
# 696       BBR_DJ_12B1 1.137424 0.975010   SVR_S-Clientes-GD.csv
# 697       BBR_DJ_12B2 1.103710 0.976827   SVR_S-Clientes-GD.csv
# 698       BJC_DJ_12B1 0.487725 0.398662   SVR_S-Clientes-GD.csv
# 699       BNR_DJ_12B1 0.852561 0.704476   SVR_S-Clientes-GD.csv
# 700       BQR_DJ_12B1 1.109941 0.946974   SVR_S-Clientes-GD.csv
# 701       BSA_DJ_12B1 3.520881 3.018368   SVR_S-Clientes-GD.csv
# 702       BSA_DJ_12B2 1.981679 1.382982   SVR_S-Clientes-GD.csv
# 703       BVA_DJ_12T1 0.867660 0.757640   SVR_S-Clientes-GD.csv
# 704       BVT_DJ_12B1 0.706080 0.543873   SVR_S-Clientes-GD.csv
# 705       BVT_DJ_12B2 0.472777 0.385208   SVR_S-Clientes-GD.csv
# 706       BYX_DJ_12B1 3.086454 2.814141   SVR_S-Clientes-GD.csv
# 707       CAA_DJ_12B1 1.270637 1.015769   SVR_S-Clientes-GD.csv
# 708       CBD_DJ_12B1 4.105472 3.721002   SVR_S-Clientes-GD.csv
# 709       CBD_DJ_12B2 2.973176 2.702905   SVR_S-Clientes-GD.csv
# 710       CDE_DJ_12B1 1.756797 1.388176   SVR_S-Clientes-GD.csv
# 711       CGU_DJ_12B1 0.620933 0.502972   SVR_S-Clientes-GD.csv
# 712       CGU_DJ_12B2 0.543710 0.471222   SVR_S-Clientes-GD.csv
# 713       CJZ_DJ_12B1 1.866146 1.517968   SVR_S-Clientes-GD.csv
# 714       CJZ_DJ_12B2 4.619070 3.580829   SVR_S-Clientes-GD.csv
# 715       CPX_DJ_12B1 0.573233 0.478782   SVR_S-Clientes-GD.csv
# 716       CPX_DJ_12B2 2.117641 1.758545   SVR_S-Clientes-GD.csv
# 717       CRI_DJ_12B1 4.376129 4.063026   SVR_S-Clientes-GD.csv
# 718       CRI_DJ_12B2 0.544821 0.458303   SVR_S-Clientes-GD.csv
# 719       CRM_DJ_12T1 0.615969 0.488814   SVR_S-Clientes-GD.csv
# 720       CTE_DJ_12B1 0.620784 0.511090   SVR_S-Clientes-GD.csv
# 721       CTL_DJ_12B1 2.702451 2.226433   SVR_S-Clientes-GD.csv
# 722       CTR_DJ_12B1 1.010635 0.780028   SVR_S-Clientes-GD.csv
# 723       DIN_DJ_12B1 0.247652 0.213526   SVR_S-Clientes-GD.csv
# 724       DST_DJ_12B1 2.982090 2.642155   SVR_S-Clientes-GD.csv
# 725       DST_DJ_12B2 0.840483 0.710361   SVR_S-Clientes-GD.csv
# 726       ESP_DJ_12B1 0.877840 0.772313   SVR_S-Clientes-GD.csv
# 727       GBA_DJ_12B1 1.342352 1.218708   SVR_S-Clientes-GD.csv
# 728       GBA_DJ_12B2 2.533638 2.265164   SVR_S-Clientes-GD.csv
# 729       IBR_DJ_12B1 0.206831 0.178719   SVR_S-Clientes-GD.csv
# 730       ILB_DJ_12B1 1.439630 1.170061   SVR_S-Clientes-GD.csv
# 731       ITA_DJ_12B1 4.324734 4.000484   SVR_S-Clientes-GD.csv
# 732       ITO_DJ_12B1 1.327592 1.094831   SVR_S-Clientes-GD.csv
# 733       JCU_DJ_12B1 0.876077 0.816299   SVR_S-Clientes-GD.csv
# 734       JRC_DJ_12B1 0.984799 0.786623   SVR_S-Clientes-GD.csv
# 735       JTB_DJ_12B1 1.298827 1.077917   SVR_S-Clientes-GD.csv
# 736       JZR_DJ_12B1 0.745220 0.541338   SVR_S-Clientes-GD.csv
# 737       LCN_DJ_12B1 0.716301 0.556919   SVR_S-Clientes-GD.csv
# 738       MAA_DJ_12B1 0.947102 0.764279   SVR_S-Clientes-GD.csv
# 739       MGB_DJ_12B1 3.838934 3.472608   SVR_S-Clientes-GD.csv
# 740       MGB_DJ_12B2 1.418631 1.158028   SVR_S-Clientes-GD.csv
# 741       MLT_DJ_12B1 0.528356 0.413247   SVR_S-Clientes-GD.csv
# 742       MNT_DJ_12T1 1.289831 0.991904   SVR_S-Clientes-GD.csv
# 743       MRO_DJ_12B1 1.311902 0.969640   SVR_S-Clientes-GD.csv
# 744       MRU_DJ_12B1 1.042284 0.911617   SVR_S-Clientes-GD.csv
# 745       MRU_DJ_12B2 4.182625 3.626178   SVR_S-Clientes-GD.csv
# 746       ORT_DJ_12B1 0.935189 0.766640   SVR_S-Clientes-GD.csv
# 747       PBL_DJ_12B1 1.436197 1.200316   SVR_S-Clientes-GD.csv
# 748       PCI_DJ_12B1 0.222566 0.176294   SVR_S-Clientes-GD.csv
# ...
# 785       BQR_DJ_12B1 1.439411 1.266035      SVR_S-Clientes.csv
# 786       BSA_DJ_12B1 3.969697 3.410599      SVR_S-Clientes.csv
# 787       BSA_DJ_12B2 2.119835 1.660653      SVR_S-Clientes.csv
# 788       BVA_DJ_12T1 0.436765 0.322059      SVR_S-Clientes.csv
# 789       BVT_DJ_12B1 0.646298 0.478223      SVR_S-Clientes.csv
# 790       BVT_DJ_12B2 0.475474 0.388575      SVR_S-Clientes.csv
# 791       BYX_DJ_12B1 2.247524 2.023873      SVR_S-Clientes.csv
# 792       CAA_DJ_12B1 1.344310 1.143451      SVR_S-Clientes.csv
# 793       CBD_DJ_12B1 4.181791 3.765966      SVR_S-Clientes.csv
# 794       CBD_DJ_12B2 2.274657 1.885411      SVR_S-Clientes.csv
# 795       CDE_DJ_12B1 1.840526 1.453787      SVR_S-Clientes.csv
# 796       CGU_DJ_12B1 0.563655 0.450972      SVR_S-Clientes.csv
# 797       CGU_DJ_12B2 0.315405 0.249714      SVR_S-Clientes.csv
# 798       CJZ_DJ_12B1 1.690219 1.342335      SVR_S-Clientes.csv
# 799       CJZ_DJ_12B2 4.500386 3.406493      SVR_S-Clientes.csv
# 800       CPX_DJ_12B1 0.579330 0.505033      SVR_S-Clientes.csv
# 801       CPX_DJ_12B2 1.891311 1.553215      SVR_S-Clientes.csv
# 802       CRI_DJ_12B1 5.176634 4.635256      SVR_S-Clientes.csv
# 803       CRI_DJ_12B2 0.616369 0.520175      SVR_S-Clientes.csv
# 804       CRM_DJ_12T1 0.381423 0.283474      SVR_S-Clientes.csv
# 805       CTE_DJ_12B1 0.532637 0.437909      SVR_S-Clientes.csv
# 806       CTL_DJ_12B1 1.808273 1.449282      SVR_S-Clientes.csv
# 807       CTR_DJ_12B1 0.829642 0.653195      SVR_S-Clientes.csv
# 808       DIN_DJ_12B1 0.489220 0.445440      SVR_S-Clientes.csv
# 809       DST_DJ_12B1 1.278663 1.041822      SVR_S-Clientes.csv
# 810       DST_DJ_12B2 0.843332 0.711171      SVR_S-Clientes.csv
# 811       ESP_DJ_12B1 0.590423 0.509817      SVR_S-Clientes.csv
# 812       GBA_DJ_12B1 1.490799 1.379173      SVR_S-Clientes.csv
# 813       GBA_DJ_12B2 2.298619 1.957844      SVR_S-Clientes.csv
# 814       IBR_DJ_12B1 0.132303 0.107989      SVR_S-Clientes.csv
# 815       ILB_DJ_12B1 1.418012 1.128952      SVR_S-Clientes.csv
# 816       ITA_DJ_12B1 1.261461 1.017362      SVR_S-Clientes.csv
# 817       ITO_DJ_12B1 1.744122 1.439247      SVR_S-Clientes.csv
# 818       JCU_DJ_12B1 0.804896 0.754685      SVR_S-Clientes.csv
# 819       JRC_DJ_12B1 0.855831 0.688024      SVR_S-Clientes.csv
# 820       JTB_DJ_12B1 1.191592 0.940368      SVR_S-Clientes.csv
# 821       JZR_DJ_12B1 1.284988 1.091320      SVR_S-Clientes.csv
# 822       LCN_DJ_12B1 1.219025 1.042925      SVR_S-Clientes.csv
# 823       MAA_DJ_12B1 0.838468 0.653376      SVR_S-Clientes.csv
# 824       MGB_DJ_12B1 1.293557 0.997023      SVR_S-Clientes.csv
# 825       MGB_DJ_12B2 1.030373 0.782888      SVR_S-Clientes.csv
# 826       MLT_DJ_12B1 0.474606 0.365878      SVR_S-Clientes.csv
# 827       MNT_DJ_12T1 1.839870 1.593000      SVR_S-Clientes.csv
# 828       MRO_DJ_12B1 1.114024 0.918563      SVR_S-Clientes.csv
# 829       MRU_DJ_12B1 1.327916 1.236258      SVR_S-Clientes.csv
# 830       MRU_DJ_12B2 3.463989 2.918021      SVR_S-Clientes.csv
# 831       ORT_DJ_12B1 1.049198 0.892482      SVR_S-Clientes.csv
# 832       PBL_DJ_12B1 0.838391 0.661620      SVR_S-Clientes.csv
# 833       PCI_DJ_12B1 0.278608 0.233990      SVR_S-Clientes.csv
# 834       PCO_DJ_12B1 0.635569 0.467930      SVR_S-Clientes.csv
# 835       PLT_DJ_12B1 0.346735 0.271623      SVR_S-Clientes.csv
# 836       PLV_DJ_12B1 0.197630 0.156271      SVR_S-Clientes.csv
# 837       POC_DJ_12B1 0.311070 0.254721      SVR_S-Clientes.csv
# 838       PRI_DJ_12B1 0.575447 0.448435      SVR_S-Clientes.csv
# 839       PRT_DJ_12B1 1.061624 0.873655      SVR_S-Clientes.csv
# 840       PTS_DJ_12B1 2.258169 1.968738      SVR_S-Clientes.csv
# 841       QMD_DJ_12B1 0.773950 0.610903      SVR_S-Clientes.csv
# 842       RIC_DJ_12B1 0.748930 0.581047      SVR_S-Clientes.csv
# 843       RTT_DJ_12B1 1.625360 1.329319      SVR_S-Clientes.csv
# 844       RTT_DJ_12B2 0.684493 0.548032      SVR_S-Clientes.csv
# 845       SBT_DJ_12B1 1.589164 1.347359      SVR_S-Clientes.csv
# 846       SGL_DJ_12T1 0.961808 0.750167      SVR_S-Clientes.csv
# 847       SJC_DJ_12T1 0.278466 0.217352      SVR_S-Clientes.csv
# 848       SLD_DJ_12B1 0.850282 0.777337      SVR_S-Clientes.csv
# 849       SLZ_DJ_12B1 0.680798 0.560679      SVR_S-Clientes.csv
# 850       SPE_DJ_12B2 1.674402 1.325008      SVR_S-Clientes.csv
# 851       SPX_DJ_12B1 0.989819 0.897820      SVR_S-Clientes.csv
# 852       STR_DJ_12B1 2.718296 2.063112      SVR_S-Clientes.csv
# 853       STR_DJ_12B2 1.488848 1.294022      SVR_S-Clientes.csv
# 854       SZA_DJ_12B1 1.682851 1.529524      SVR_S-Clientes.csv
# 855       SZA_DJ_12B2 1.727026 1.472205      SVR_S-Clientes.csv
# 856       TBU_DJ_12B1 2.204813 1.782232      SVR_S-Clientes.csv
# 857       TBU_DJ_12B2 2.535061 2.159405      SVR_S-Clientes.csv
# 858       TXR_DJ_12B1 1.821500 1.664052      SVR_S-Clientes.csv
# 859       URN_DJ_12B1 0.073851 0.062063      SVR_S-Clientes.csv
# 860       ABR_DJ_12B1 0.553723 0.450760            SVR_S-GD.csv
# 861       AER_DJ_12B1 0.478705 0.379660            SVR_S-GD.csv
# 862       APL_DJ_12B1 1.867854 1.572436            SVR_S-GD.csv
# 863       ARA_DJ_12B1 0.721429 0.584580            SVR_S-GD.csv
# 864       ARN_DJ_12B1 0.244300 0.210667            SVR_S-GD.csv
# 865       ARR_DJ_12B1 1.014897 0.942094            SVR_S-GD.csv
# 866       BBR_DJ_12B1 0.483350 0.361131            SVR_S-GD.csv
# 867       BBR_DJ_12B2 0.812403 0.702711            SVR_S-GD.csv
# 868       BJC_DJ_12B1 0.296608 0.235595            SVR_S-GD.csv
# 869       BNR_DJ_12B1 0.815154 0.660985            SVR_S-GD.csv
# 870       BQR_DJ_12B1 1.309090 1.123620            SVR_S-GD.csv
# 871       BSA_DJ_12B1 1.225117 0.925201            SVR_S-GD.csv
# 872       BSA_DJ_12B2 1.005157 0.828347            SVR_S-GD.csv
# 873       BVA_DJ_12T1 1.052211 0.930503            SVR_S-GD.csv
# 874       BVT_DJ_12B1 0.674486 0.561329            SVR_S-GD.csv
# 875       BVT_DJ_12B2 0.374162 0.307973            SVR_S-GD.csv
# 876       BYX_DJ_12B1 1.845419 1.536624            SVR_S-GD.csv
# 877       CAA_DJ_12B1 0.888746 0.732514            SVR_S-GD.csv
# 878       CBD_DJ_12B1 2.146338 1.802968            SVR_S-GD.csv
# 879       CBD_DJ_12B2 1.159871 0.935221            SVR_S-GD.csv
# 880       CDE_DJ_12B1 1.172734 0.915828            SVR_S-GD.csv
# 881       CGU_DJ_12B1 0.624112 0.502781            SVR_S-GD.csv
# 882       CGU_DJ_12B2 0.426639 0.350421            SVR_S-GD.csv
# 883       CJZ_DJ_12B1 1.804054 1.490234            SVR_S-GD.csv
# 884       CJZ_DJ_12B2 2.822522 2.234721            SVR_S-GD.csv
# 885       CPX_DJ_12B1 0.295491 0.244184            SVR_S-GD.csv
# 886       CPX_DJ_12B2 1.042916 0.825063            SVR_S-GD.csv
# 887       CRI_DJ_12B1 0.868958 0.673988            SVR_S-GD.csv
# 888       CRI_DJ_12B2 0.576870 0.448141            SVR_S-GD.csv
# 889       CRM_DJ_12T1 0.347891 0.257836            SVR_S-GD.csv
# 890       CTE_DJ_12B1 0.316116 0.251806            SVR_S-GD.csv
# 891       CTL_DJ_12B1 1.180792 0.917767            SVR_S-GD.csv
# 892       CTR_DJ_12B1 0.647049 0.510462            SVR_S-GD.csv
# 893       DIN_DJ_12B1 0.167805 0.128684            SVR_S-GD.csv
# 894       DST_DJ_12B1 0.892318 0.679611            SVR_S-GD.csv
# 895       DST_DJ_12B2 0.457167 0.369047            SVR_S-GD.csv
# 896       ESP_DJ_12B1 0.378514 0.292370            SVR_S-GD.csv
# 897       GBA_DJ_12B1 0.768697 0.677088            SVR_S-GD.csv
# 898       GBA_DJ_12B2 1.720676 1.509671            SVR_S-GD.csv
# 899       IBR_DJ_12B1 0.243449 0.215193            SVR_S-GD.csv
# 900       ILB_DJ_12B1 0.965117 0.778746            SVR_S-GD.csv
# 901       ITA_DJ_12B1 1.587583 1.338572            SVR_S-GD.csv
# 902       ITO_DJ_12B1 0.595326 0.459312            SVR_S-GD.csv
# 903       JCU_DJ_12B1 0.290357 0.243374            SVR_S-GD.csv
# 904       JRC_DJ_12B1 0.306781 0.241377            SVR_S-GD.csv
# 905       JTB_DJ_12B1 1.543180 1.273938            SVR_S-GD.csv
# 906       JZR_DJ_12B1 0.481234 0.352293            SVR_S-GD.csv
# 907       LCN_DJ_12B1 0.719574 0.541455            SVR_S-GD.csv
# 908       MAA_DJ_12B1 0.790437 0.605258            SVR_S-GD.csv
# 909       MGB_DJ_12B1 2.604845 2.127849            SVR_S-GD.csv
# 910       MGB_DJ_12B2 0.951268 0.709728            SVR_S-GD.csv
# 911       MLT_DJ_12B1 0.471768 0.367023            SVR_S-GD.csv
# 912       MNT_DJ_12T1 0.598681 0.494112            SVR_S-GD.csv
# 913       MRO_DJ_12B1 0.915165 0.752972            SVR_S-GD.csv
# 914       MRU_DJ_12B1 0.691182 0.570594            SVR_S-GD.csv
# 915       MRU_DJ_12B2 2.629194 2.252199            SVR_S-GD.csv
# 916       ORT_DJ_12B1 1.323232 1.016341            SVR_S-GD.csv
# 917       PBL_DJ_12B1 0.696667 0.518688            SVR_S-GD.csv
# 918       PCI_DJ_12B1 0.220313 0.174277            SVR_S-GD.csv
# 919       PCO_DJ_12B1 0.709441 0.546995            SVR_S-GD.csv
# 920       PLT_DJ_12B1 0.507756 0.415497            SVR_S-GD.csv
# 921       PLV_DJ_12B1 0.164836 0.131717            SVR_S-GD.csv
# 922       POC_DJ_12B1 0.391800 0.315534            SVR_S-GD.csv
# 923       PRI_DJ_12B1 0.447140 0.345326            SVR_S-GD.csv
# 924       PRT_DJ_12B1 1.043575 0.844656            SVR_S-GD.csv
# 925       PTS_DJ_12B1 1.763291 1.469774            SVR_S-GD.csv
# 926       QMD_DJ_12B1 0.469677 0.375968            SVR_S-GD.csv
# 927       RIC_DJ_12B1 0.722567 0.572157            SVR_S-GD.csv
# 928       RTT_DJ_12B1 1.221159 0.984628            SVR_S-GD.csv
# 929       RTT_DJ_12B2 0.710756 0.566732            SVR_S-GD.csv
# 930       SBT_DJ_12B1 1.069834 0.811700            SVR_S-GD.csv
# 931       SGL_DJ_12T1 0.611360 0.507464            SVR_S-GD.csv
# 932       SJC_DJ_12T1 0.330176 0.256647            SVR_S-GD.csv
# 933       SLD_DJ_12B1 0.267167 0.221481            SVR_S-GD.csv
# 934       SLZ_DJ_12B1 0.356930 0.277181            SVR_S-GD.csv
# 935       SPE_DJ_12B2 1.360688 1.057710            SVR_S-GD.csv
# 936       SPX_DJ_12B1 0.461662 0.334532            SVR_S-GD.csv
# 937       STR_DJ_12B1 0.711778 0.518857            SVR_S-GD.csv
# 938       STR_DJ_12B2 1.802498 1.475121            SVR_S-GD.csv
# 939       SZA_DJ_12B1 0.957221 0.755637            SVR_S-GD.csv
# 940       SZA_DJ_12B2 1.707887 1.458409            SVR_S-GD.csv
# 941       TBU_DJ_12B1 1.761009 1.592841            SVR_S-GD.csv
# 942       TBU_DJ_12B2 1.857616 1.581735            SVR_S-GD.csv
# 943       TXR_DJ_12B1 0.539098 0.461226            SVR_S-GD.csv
# 944       URN_DJ_12B1 0.145169 0.119773            SVR_S-GD.csv
# 945       ABR_DJ_12B1 0.896745 0.711847               SVR_S.csv
# 946       AER_DJ_12B1 0.688095 0.480530               SVR_S.csv
# 947       APL_DJ_12B1 0.634941 0.506791               SVR_S.csv
# 948       ARA_DJ_12B1 0.575894 0.433550               SVR_S.csv
# 949       ARN_DJ_12B1 0.169598 0.114927               SVR_S.csv
# 950       ARR_DJ_12B1 0.233043 0.181197               SVR_S.csv
# 951       BBR_DJ_12B1 0.470436 0.321616               SVR_S.csv
# 952       BBR_DJ_12B2 0.620963 0.466929               SVR_S.csv
# 953       BJC_DJ_12B1 0.281750 0.175756               SVR_S.csv
# 954       BNR_DJ_12B1 0.986220 0.770389               SVR_S.csv
# 955       BQR_DJ_12B1 0.657619 0.508488               SVR_S.csv
# 956       BSA_DJ_12B1 1.042432 0.788262               SVR_S.csv
# 957       BSA_DJ_12B2 0.696674 0.421844               SVR_S.csv
# 958       BVA_DJ_12T1 0.305962 0.218324               SVR_S.csv
# 959       BVT_DJ_12B1 0.789038 0.554075               SVR_S.csv
# 960       BVT_DJ_12B2 0.666036 0.419240               SVR_S.csv
# 961       BYX_DJ_12B1 0.593903 0.459184               SVR_S.csv
# 962       CAA_DJ_12B1 0.474445 0.332672               SVR_S.csv
# 963       CBD_DJ_12B1 1.048190 0.806181               SVR_S.csv
# 964       CBD_DJ_12B2 0.725848 0.472308               SVR_S.csv
# 965       CDE_DJ_12B1 1.404955 0.998131               SVR_S.csv
# 966       CGD_DJ_11T7 0.678550 0.480852               SVR_S.csv
# 967       CGU_DJ_12B1 1.545584 1.100986               SVR_S.csv
# 968       CGU_DJ_12B2 0.330522 0.221765               SVR_S.csv
# 969       CJZ_DJ_12B1 0.844746 0.638272               SVR_S.csv
# 970       CJZ_DJ_12B2 0.712991 0.530613               SVR_S.csv
# 971       CPX_DJ_12B1 1.799539 1.090067               SVR_S.csv
# 972       CPX_DJ_12B2 1.697307 1.191622               SVR_S.csv
# 973       CRI_DJ_12B1 0.735692 0.516042               SVR_S.csv
# 974       CRI_DJ_12B2 0.490890 0.365746               SVR_S.csv
# 975       CRM_DJ_12T1 0.288427 0.213663               SVR_S.csv
# 976       CTE_DJ_12B1 0.410123 0.302724               SVR_S.csv
# 977       CTL_DJ_12B1 1.467406 1.097599               SVR_S.csv
# 978       CTR_DJ_12B1 0.566904 0.431480               SVR_S.csv
# 979       DIN_DJ_12B1 0.162343 0.118505               SVR_S.csv
# 980       DST_DJ_12B1 0.862475 0.633102               SVR_S.csv
# 981       DST_DJ_12B2 0.470979 0.379953               SVR_S.csv
# 982       ESP_DJ_12B1 0.403956 0.269660               SVR_S.csv
# 983       GBA_DJ_12B1 0.298915 0.226159               SVR_S.csv
# 984       GBA_DJ_12B2 1.115895 0.894800               SVR_S.csv
# 985       IBR_DJ_12B1 0.115674 0.087714               SVR_S.csv
# 986       ILB_DJ_12B1 0.908206 0.680458               SVR_S.csv
# 987       ITA_DJ_12B1 0.614652 0.455635               SVR_S.csv
# 988       ITO_DJ_12B1 0.581175 0.425386               SVR_S.csv
# 989       JCU_DJ_12B1 0.207615 0.154978               SVR_S.csv
# 990       JPS_DJ_12B1 2.723145 2.113502               SVR_S.csv
# 991       JPS_DJ_12B2 1.497440 1.095601               SVR_S.csv
# 992       JRC_DJ_12B1 0.279353 0.229144               SVR_S.csv
# 993       JTB_DJ_12B1 0.666807 0.492025               SVR_S.csv
# 994       JZR_DJ_12B1 0.408774 0.294328               SVR_S.csv
# 995       LCN_DJ_12B1 0.477340 0.330135               SVR_S.csv
# 996       MAA_DJ_12B1 0.666967 0.519549               SVR_S.csv
# 997       MGB_DJ_12B1 1.229036 1.033764               SVR_S.csv
# 998       MGB_DJ_12B2 0.774044 0.520554               SVR_S.csv
# 999       MLT_DJ_12B1 0.290200 0.203250               SVR_S.csv
# 1000      MNT_DJ_12T1 0.528704 0.372173               SVR_S.csv
# 1001      MRO_DJ_12B1 1.127364 0.856301               SVR_S.csv
# 1002      MRU_DJ_12B1 0.329546 0.246001               SVR_S.csv
# 1003      MRU_DJ_12B2 0.854611 0.633069               SVR_S.csv
# 1004      ORT_DJ_12B1 0.532529 0.430266               SVR_S.csv
# 1005      PBL_DJ_12B1 0.539311 0.400658               SVR_S.csv
# 1006      PCI_DJ_12B1 0.715333 0.628292               SVR_S.csv
# 1007      PCO_DJ_12B1 0.401003 0.300448               SVR_S.csv
# 1008      PLT_DJ_12B1 0.274165 0.203321               SVR_S.csv
# 1009      PLU_DJ_12B1 0.404988 0.242997               SVR_S.csv
# 1010  PLU_DJ_12B1_D_P 0.000000 0.000000               SVR_S.csv
# 1011      PLV_DJ_12B1 0.229662 0.171538               SVR_S.csv
# 1012      POC_DJ_12B1 0.234170 0.180407               SVR_S.csv
# 1013      PRI_DJ_12B1 0.407722 0.306505               SVR_S.csv
# 1014      PRT_DJ_12B1 2.472324 2.198422               SVR_S.csv
# 1015      PTS_DJ_12B1 1.222209 0.971872               SVR_S.csv
# 1016      QMD_DJ_12B1 0.421700 0.325718               SVR_S.csv
# 1017      RIC_DJ_12B1 0.592218 0.474399               SVR_S.csv
# 1018      RTT_DJ_12B1 1.426234 1.019350               SVR_S.csv
# 1019      RTT_DJ_12B2 0.512514 0.373947               SVR_S.csv
# 1020      SBT_DJ_12B1 0.706918 0.554212               SVR_S.csv
# 1021      SGL_DJ_12T1 0.439723 0.330265               SVR_S.csv
# 1022      SJC_DJ_12T1 0.281929 0.207080               SVR_S.csv
# 1023      SLD_DJ_12B1 0.238058 0.183878               SVR_S.csv
# 1024      SLZ_DJ_12B1 0.272148 0.210864               SVR_S.csv
# 1025      SPE_DJ_12B2 1.030913 0.822983               SVR_S.csv
# 1026      SPX_DJ_12B1 0.295370 0.220369               SVR_S.csv
# 1027      STR_DJ_12B1 0.503309 0.391838               SVR_S.csv
# 1028      STR_DJ_12B2 0.797547 0.572439               SVR_S.csv
# 1029      SZA_DJ_12B1 0.534548 0.399850               SVR_S.csv
# 1030      SZA_DJ_12B2 0.828302 0.623723               SVR_S.csv
# 1031      TBU_DJ_12B1 1.210776 0.913673               SVR_S.csv
# 1032      TBU_DJ_12B2 1.054693 0.782419               SVR_S.csv
# 1033      TXR_DJ_12B1 0.249975 0.183903               SVR_S.csv
# 1034      URN_DJ_12B1 0.120759 0.100481               SVR_S.csv

# %%
top15_GD = {
    "TRAFO": [
        "PTS_DJ_12B1", "JTB_DJ_12B1", "CTR_DJ_12B1", "CJZ_DJ_12B1", "SZA_DJ_12B2",
        "CBD_DJ_12B1", "SBT_DJ_12B1", "SZA_DJ_12B1", "ABR_DJ_12B1", "PBL_DJ_12B1",
        "PRT_DJ_12B1", "CTL_DJ_12B1", "GBA_DJ_12B2", "SGL_DJ_12T1", "MGB_DJ_12B2"
    ],
    "PotenciaAcumulada": [
        18.11019000000007, 14.390984999999995, 12.482614999999988, 11.970245000000013, 11.226030000000003,
        10.83012999999999, 10.829459999999996, 9.407430000000025, 8.66734999999998, 8.325459999999996,
        8.020819999999983, 8.012269999999988, 7.1918599999999895, 7.179259999999999, 7.032454999999988
    ]
}

# %%
df_concatenado[["Modelo", "Features"]] = df_concatenado["Arquivo"].str.split("_", n=1, expand=True)
df_concatenado = df_concatenado.drop("Arquivo", axis=1)

# %%
ver_GD_top3 = top3_pivot[top3_pivot['Trafo'].isin(top15_GD['TRAFO'])]
ver_GD_top3
# Out:
#           Trafo              Melhor          Segundo Melhor  \
# 0   ABR_DJ_12B1       LSTM_S-GD.csv     LSTM_S-Clientes.csv
# 18  CBD_DJ_12B1           SVR_S.csv              LSTM_S.csv
# 24  CJZ_DJ_12B1           SVR_S.csv  LSTM_S-Clientes-GD.csv
# 32  CTL_DJ_12B1        SVR_S-GD.csv            RFR_S-GD.csv
# 33  CTR_DJ_12B1           SVR_S.csv            SVR_S-GD.csv
# 39  GBA_DJ_12B2       LSTM_S-GD.csv  LSTM_S-Clientes-GD.csv
# 48  JTB_DJ_12B1           SVR_S.csv           LSTM_S-GD.csv
# 53  MGB_DJ_12B2          LSTM_S.csv               SVR_S.csv
# 60  PBL_DJ_12B1          LSTM_S.csv               SVR_S.csv
# 69  PRT_DJ_12B1  RFR_S-Clientes.csv            RFR_S-GD.csv
# 70  PTS_DJ_12B1       LSTM_S-GD.csv  LSTM_S-Clientes-GD.csv
# 75  SBT_DJ_12B1           SVR_S.csv  LSTM_S-Clientes-GD.csv
# 76  SGL_DJ_12T1           SVR_S.csv              LSTM_S.csv
# 84  SZA_DJ_12B1           SVR_S.csv              LSTM_S.csv
# 85  SZA_DJ_12B2          LSTM_S.csv           LSTM_S-GD.csv
#
#            Terceiro Melhor
# 0   LSTM_S-Clientes-GD.csv
# 18     LSTM_S-Clientes.csv
# 24           LSTM_S-GD.csv
# 32           LSTM_S-GD.csv
# 33     LSTM_S-Clientes.csv
# 39     LSTM_S-Clientes.csv
# 48               RFR_S.csv
# 53     LSTM_S-Clientes.csv
# 60           LSTM_S-GD.csv
# 69   RFR_S-Clientes-GD.csv
# 70     LSTM_S-Clientes.csv
# 75              LSTM_S.csv
# 76           LSTM_S-GD.csv
# 84               RFR_S.csv
# 85  LSTM_S-Clientes-GD.csv

# %%
ver_GD = df_concatenado[df_concatenado['Trafo'].isin(top15_GD['TRAFO'])]
ver_GD.sort_values('RMSE')
# Out:
#             Trafo     RMSE Modelo           Features
# 170   ABR_DJ_12B1 0.418541   LSTM           S-GD.csv
# 85    ABR_DJ_12B1 0.422110   LSTM     S-Clientes.csv
# 0     ABR_DJ_12B1 0.429187   LSTM  S-Clientes-GD.csv
# 1021  SGL_DJ_12T1 0.439723    SVR              S.csv
# 331   SGL_DJ_12T1 0.468452   LSTM              S.csv
# 241   SGL_DJ_12T1 0.480352   LSTM           S-GD.csv
# 71    SGL_DJ_12T1 0.483016   LSTM  S-Clientes-GD.csv
# 156   SGL_DJ_12T1 0.488769   LSTM     S-Clientes.csv
# 315   PBL_DJ_12B1 0.518959   LSTM              S.csv
# 515   ABR_DJ_12B1 0.532231    RFR           S-GD.csv
# 1029  SZA_DJ_12B1 0.534548    SVR              S.csv
# 1005  PBL_DJ_12B1 0.539311    SVR              S.csv
# 339   SZA_DJ_12B1 0.550107   LSTM              S.csv
# 860   ABR_DJ_12B1 0.553723    SVR           S-GD.csv
# 978   CTR_DJ_12B1 0.566904    SVR              S.csv
# 775   ABR_DJ_12B1 0.578495    SVR     S-Clientes.csv
# 345   ABR_DJ_12B1 0.584535    RFR  S-Clientes-GD.csv
# 430   ABR_DJ_12B1 0.608382    RFR     S-Clientes.csv
# 931   SGL_DJ_12T1 0.611360    SVR           S-GD.csv
# 227   PBL_DJ_12B1 0.636639   LSTM           S-GD.csv
# 142   PBL_DJ_12B1 0.640775   LSTM     S-Clientes.csv
# 892   CTR_DJ_12B1 0.647049    SVR           S-GD.csv
# 117   CTR_DJ_12B1 0.647422   LSTM     S-Clientes.csv
# 202   CTR_DJ_12B1 0.652528   LSTM           S-GD.csv
# 993   JTB_DJ_12B1 0.666807    SVR              S.csv
# 57    PBL_DJ_12B1 0.682046   LSTM  S-Clientes-GD.csv
# 690   ABR_DJ_12B1 0.685124    SVR  S-Clientes-GD.csv
# 340   SZA_DJ_12B2 0.691652   LSTM              S.csv
# 32    CTR_DJ_12B1 0.692208   LSTM  S-Clientes-GD.csv
# 917   PBL_DJ_12B1 0.696667    SVR           S-GD.csv
# 1020  SBT_DJ_12B1 0.706918    SVR              S.csv
# 250   SZA_DJ_12B2 0.707129   LSTM           S-GD.csv
# 308   MGB_DJ_12B2 0.707403   LSTM              S.csv
# 80    SZA_DJ_12B2 0.713964   LSTM  S-Clientes-GD.csv
# 165   SZA_DJ_12B2 0.716307   LSTM     S-Clientes.csv
# 288   CTR_DJ_12B1 0.723228   LSTM              S.csv
# 684   SZA_DJ_12B1 0.727840    RFR              S.csv
# 164   SZA_DJ_12B1 0.753570   LSTM     S-Clientes.csv
# 79    SZA_DJ_12B1 0.764623   LSTM  S-Clientes-GD.csv
# 249   SZA_DJ_12B1 0.772351   LSTM           S-GD.csv
# 998   MGB_DJ_12B2 0.774044    SVR              S.csv
# 135   MGB_DJ_12B2 0.782011   LSTM     S-Clientes.csv
# 50    MGB_DJ_12B2 0.792419   LSTM  S-Clientes-GD.csv
# 220   MGB_DJ_12B2 0.796852   LSTM           S-GD.csv
# 676   SGL_DJ_12T1 0.812187    RFR              S.csv
# 1030  SZA_DJ_12B2 0.828302    SVR              S.csv
# 807   CTR_DJ_12B1 0.829642    SVR     S-Clientes.csv
# 832   PBL_DJ_12B1 0.838391    SVR     S-Clientes.csv
# 969   CJZ_DJ_12B1 0.844746    SVR              S.csv
# 660   PBL_DJ_12B1 0.870969    RFR              S.csv
# 208   GBA_DJ_12B2 0.876670   LSTM           S-GD.csv
# 494   PRT_DJ_12B1 0.880987    RFR     S-Clientes.csv
# 945   ABR_DJ_12B1 0.896745    SVR              S.csv
# 579   PRT_DJ_12B1 0.911774    RFR           S-GD.csv
# 409   PRT_DJ_12B1 0.919894    RFR  S-Clientes-GD.csv
# 235   PTS_DJ_12B1 0.930791   LSTM           S-GD.csv
# 38    GBA_DJ_12B2 0.942008   LSTM  S-Clientes-GD.csv
# 123   GBA_DJ_12B2 0.949479   LSTM     S-Clientes.csv
# 215   JTB_DJ_12B1 0.950091   LSTM           S-GD.csv
# 910   MGB_DJ_12B2 0.951268    SVR           S-GD.csv
# 648   JTB_DJ_12B1 0.953465    RFR              S.csv
# 939   SZA_DJ_12B1 0.957221    SVR           S-GD.csv
# 846   SGL_DJ_12T1 0.961808    SVR     S-Clientes.csv
# 65    PTS_DJ_12B1 0.968303   LSTM  S-Clientes-GD.csv
# 685   SZA_DJ_12B2 0.975019    RFR              S.csv
# 653   MGB_DJ_12B2 0.975026    RFR              S.csv
# 150   PTS_DJ_12B1 0.987154   LSTM     S-Clientes.csv
# 303   JTB_DJ_12B1 0.998646   LSTM              S.csv
# 633   CTR_DJ_12B1 1.002057    RFR              S.csv
# 325   PTS_DJ_12B1 1.008527   LSTM              S.csv
# 722   CTR_DJ_12B1 1.010635    SVR  S-Clientes-GD.csv
# 70    SBT_DJ_12B1 1.021883   LSTM  S-Clientes-GD.csv
# 330   SBT_DJ_12B1 1.025888   LSTM              S.csv
# 825   MGB_DJ_12B2 1.030373    SVR     S-Clientes.csv
# 754   PRT_DJ_12B1 1.035733    SVR  S-Clientes-GD.csv
# 924   PRT_DJ_12B1 1.043575    SVR           S-GD.csv
# 963   CBD_DJ_12B1 1.048190    SVR              S.csv
# 155   SBT_DJ_12B1 1.049619   LSTM     S-Clientes.csv
# 23    CJZ_DJ_12B1 1.052893   LSTM  S-Clientes-GD.csv
# 130   JTB_DJ_12B1 1.054862   LSTM     S-Clientes.csv
# 572   PBL_DJ_12B1 1.055199    RFR           S-GD.csv
# 193   CJZ_DJ_12B1 1.056614   LSTM           S-GD.csv
# 240   SBT_DJ_12B1 1.061019   LSTM           S-GD.csv
# 108   CJZ_DJ_12B1 1.061465   LSTM     S-Clientes.csv
# 839   PRT_DJ_12B1 1.061624    SVR     S-Clientes.csv
# 930   SBT_DJ_12B1 1.069834    SVR           S-GD.csv
# 273   CBD_DJ_12B1 1.081693   LSTM              S.csv
# 255   ABR_DJ_12B1 1.097466   LSTM              S.csv
# 103   CBD_DJ_12B1 1.110196   LSTM     S-Clientes.csv
# 188   CBD_DJ_12B1 1.114346   LSTM           S-GD.csv
# 984   GBA_DJ_12B2 1.115895    SVR              S.csv
# 618   CBD_DJ_12B1 1.124647    RFR              S.csv
# 18    CBD_DJ_12B1 1.141173   LSTM  S-Clientes-GD.csv
# 487   PBL_DJ_12B1 1.165531    RFR     S-Clientes.csv
# 891   CTL_DJ_12B1 1.180792    SVR           S-GD.csv
# 402   PBL_DJ_12B1 1.187207    RFR  S-Clientes-GD.csv
# 820   JTB_DJ_12B1 1.191592    SVR     S-Clientes.csv
# 595   SZA_DJ_12B2 1.193689    RFR           S-GD.csv
# 45    JTB_DJ_12B1 1.200789   LSTM  S-Clientes-GD.csv
# 1015  PTS_DJ_12B1 1.222209    SVR              S.csv
# 149   PRT_DJ_12B1 1.223500   LSTM     S-Clientes.csv
# 533   CBD_DJ_12B1 1.228457    RFR           S-GD.csv
# 624   CJZ_DJ_12B1 1.242181    RFR              S.csv
# 565   MGB_DJ_12B2 1.262579    RFR           S-GD.csv
# 760   SBT_DJ_12B1 1.264593    SVR  S-Clientes-GD.csv
# 675   SBT_DJ_12B1 1.271814    RFR              S.csv
# 425   SZA_DJ_12B2 1.286010    RFR  S-Clientes-GD.csv
# 448   CBD_DJ_12B1 1.286895    RFR     S-Clientes.csv
# 735   JTB_DJ_12B1 1.298827    SVR  S-Clientes-GD.csv
# 279   CJZ_DJ_12B1 1.303084   LSTM              S.csv
# 586   SGL_DJ_12T1 1.320147    RFR           S-GD.csv
# 546   CTL_DJ_12B1 1.326064    RFR           S-GD.csv
# 363   CBD_DJ_12B1 1.327508    RFR  S-Clientes-GD.csv
# 324   PRT_DJ_12B1 1.339530   LSTM              S.csv
# 475   JTB_DJ_12B1 1.345380    RFR     S-Clientes.csv
# 670   PTS_DJ_12B1 1.345500    RFR              S.csv
# 201   CTL_DJ_12B1 1.346985   LSTM           S-GD.csv
# 639   GBA_DJ_12B2 1.367235    RFR              S.csv
# 560   JTB_DJ_12B1 1.378486    RFR           S-GD.csv
# 600   ABR_DJ_12B1 1.379933    RFR              S.csv
# 368   CJZ_DJ_12B1 1.386919    RFR  S-Clientes-GD.csv
# 31    CTL_DJ_12B1 1.395028   LSTM  S-Clientes-GD.csv
# 547   CTR_DJ_12B1 1.397616    RFR           S-GD.csv
# 453   CJZ_DJ_12B1 1.400314    RFR     S-Clientes.csv
# 390   JTB_DJ_12B1 1.410755    RFR  S-Clientes-GD.csv
# 510   SZA_DJ_12B2 1.412217    RFR     S-Clientes.csv
# 740   MGB_DJ_12B2 1.418631    SVR  S-Clientes-GD.csv
# 116   CTL_DJ_12B1 1.420327   LSTM     S-Clientes.csv
# 501   SGL_DJ_12T1 1.423832    RFR     S-Clientes.csv
# 747   PBL_DJ_12B1 1.436197    SVR  S-Clientes-GD.csv
# 977   CTL_DJ_12B1 1.467406    SVR              S.csv
# 480   MGB_DJ_12B2 1.478480    RFR     S-Clientes.csv
# 395   MGB_DJ_12B2 1.479919    RFR  S-Clientes-GD.csv
# 64    PRT_DJ_12B1 1.482459   LSTM  S-Clientes-GD.csv
# 416   SGL_DJ_12T1 1.484900    RFR  S-Clientes-GD.csv
# 761   SGL_DJ_12T1 1.499446    SVR  S-Clientes-GD.csv
# 462   CTR_DJ_12B1 1.516950    RFR     S-Clientes.csv
# 755   PTS_DJ_12B1 1.529258    SVR  S-Clientes-GD.csv
# 376   CTL_DJ_12B1 1.532789    RFR  S-Clientes-GD.csv
# 905   JTB_DJ_12B1 1.543180    SVR           S-GD.csv
# 377   CTR_DJ_12B1 1.549779    RFR  S-Clientes-GD.csv
# 234   PRT_DJ_12B1 1.555632   LSTM           S-GD.csv
# 461   CTL_DJ_12B1 1.581084    RFR     S-Clientes.csv
# 845   SBT_DJ_12B1 1.589164    SVR     S-Clientes.csv
# 468   GBA_DJ_12B2 1.603797    RFR     S-Clientes.csv
# 383   GBA_DJ_12B2 1.655401    RFR  S-Clientes-GD.csv
# 294   GBA_DJ_12B2 1.680567   LSTM              S.csv
# 854   SZA_DJ_12B1 1.682851    SVR     S-Clientes.csv
# 798   CJZ_DJ_12B1 1.690219    SVR     S-Clientes.csv
# 940   SZA_DJ_12B2 1.707887    SVR           S-GD.csv
# 898   GBA_DJ_12B2 1.720676    SVR           S-GD.csv
# 855   SZA_DJ_12B2 1.727026    SVR     S-Clientes.csv
# 580   PTS_DJ_12B1 1.758684    RFR           S-GD.csv
# 925   PTS_DJ_12B1 1.763291    SVR           S-GD.csv
# 495   PTS_DJ_12B1 1.763773    RFR     S-Clientes.csv
# 410   PTS_DJ_12B1 1.779266    RFR  S-Clientes-GD.csv
# 553   GBA_DJ_12B2 1.798552    RFR           S-GD.csv
# 883   CJZ_DJ_12B1 1.804054    SVR           S-GD.csv
# 806   CTL_DJ_12B1 1.808273    SVR     S-Clientes.csv
# 585   SBT_DJ_12B1 1.830407    RFR           S-GD.csv
# 594   SZA_DJ_12B1 1.832663    RFR           S-GD.csv
# 287   CTL_DJ_12B1 1.839126   LSTM              S.csv
# 713   CJZ_DJ_12B1 1.866146    SVR  S-Clientes-GD.csv
# 632   CTL_DJ_12B1 1.867713    RFR              S.csv
# 424   SZA_DJ_12B1 2.016643    RFR  S-Clientes-GD.csv
# 509   SZA_DJ_12B1 2.016877    RFR     S-Clientes.csv
# 500   SBT_DJ_12B1 2.049223    RFR     S-Clientes.csv
# 538   CJZ_DJ_12B1 2.087311    RFR           S-GD.csv
# 415   SBT_DJ_12B1 2.119543    RFR  S-Clientes-GD.csv
# 878   CBD_DJ_12B1 2.146338    SVR           S-GD.csv
# 769   SZA_DJ_12B1 2.170288    SVR  S-Clientes-GD.csv
# 840   PTS_DJ_12B1 2.258169    SVR     S-Clientes.csv
# 813   GBA_DJ_12B2 2.298619    SVR     S-Clientes.csv
# 770   SZA_DJ_12B2 2.349548    SVR  S-Clientes-GD.csv
# 1014  PRT_DJ_12B1 2.472324    SVR              S.csv
# 728   GBA_DJ_12B2 2.533638    SVR  S-Clientes-GD.csv
# 721   CTL_DJ_12B1 2.702451    SVR  S-Clientes-GD.csv
# 708   CBD_DJ_12B1 4.105472    SVR  S-Clientes-GD.csv
# 793   CBD_DJ_12B1 4.181791    SVR     S-Clientes.csv
# 669   PRT_DJ_12B1 5.688786    RFR              S.csv
