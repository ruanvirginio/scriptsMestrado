# %%
import os
import pandas as pd
pd.set_option('display.max_rows', None)

arquivos_csv = [f for f in os.listdir() if f.endswith('.csv')]

dataframes = []

for arquivo in arquivos_csv:
    df = pd.read_csv(arquivo, sep=';') 
    df['Arquivo'] = arquivo 
    df = df[['Trafo', 'RMSE', 'Arquivo']]
    dataframes.append(df)

df_concatenado = pd.concat(dataframes, ignore_index=True)

# Encontrando o arquivo com menor RMSE para cada trafo
min_rmse_files = df_concatenado.loc[df_concatenado.groupby("Trafo")["RMSE"].idxmin(), "Arquivo"]

# Contando quantas vezes cada arquivo aparece como menor RMSE
arquivo_counts = min_rmse_files.value_counts()

print('Qtd melhor resultado:')
print(arquivo_counts)

# Encontrando os dois menores RMSE para cada trafo
df_sorted = df_concatenado.sort_values(["Trafo", "RMSE"])
second_min_files = df_sorted.groupby("Trafo").nth(1)["Arquivo"]

# Contando quantas vezes cada arquivo aparece como segundo menor RMSE
second_min_counts = second_min_files.value_counts()

print('\nQtd segundo melhor resultado:')
print(second_min_counts)

# Encontrando os tres menores RMSE para cada trafo
third_min_files = df_sorted.groupby("Trafo").nth(2)["Arquivo"]

# Contando quantas vezes cada arquivo aparece como terceiro menor RMSE
third_min_counts = third_min_files.value_counts()

print('\nQtd terceiro melhor resultado:')
print(third_min_counts)

# Pega os 3 melhores RMSE para cada trafo
top3_files = df_sorted.groupby("Trafo").head(3)

top3_pivot = top3_files.assign(Rank=top3_files.groupby("Trafo").cumcount()+1).pivot(index="Trafo", columns="Rank", values="Arquivo")
top3_pivot.columns = ["Melhor", "Segundo Melhor", "Terceiro Melhor"]

print(top3_pivot)
# Out:
# Qtd melhor resultado:
# Arquivo
# SVR_S.csv                 32
# LSTM_S-GD.csv             19
# LSTM_S-Clientes.csv       18
# LSTM_S.csv                11
# LSTM_S-Clientes-GD.csv     4
# RFR_S-GD.csv               2
# RFR_S-Clientes.csv         2
# SVR_S-GD.csv               1
# RFR_S.csv                  1
# Name: count, dtype: int64
#
# Qtd segundo melhor resultado:
# Arquivo
# LSTM_S-GD.csv             20
# LSTM_S.csv                17
# LSTM_S-Clientes.csv       16
# LSTM_S-Clientes-GD.csv    16
# SVR_S.csv                 10
# SVR_S-GD.csv               5
# RFR_S-GD.csv               3
# RFR_S.csv                  2
# RFR_S-Clientes-GD.csv      1
# Name: count, dtype: int64
#
# Qtd terceiro melhor resultado:
# Arquivo
# LSTM_S-Clientes-GD.csv    28
# LSTM_S-GD.csv             22
# LSTM_S-Clientes.csv       18
# RFR_S.csv                  7
# LSTM_S.csv                 6
# SVR_S-GD.csv               3
# RFR_S-Clientes.csv         2
# SVR_S.csv                  1
# RFR_S-GD.csv               1
# SVR_S-Clientes.csv         1
# RFR_S-Clientes-GD.csv      1
# Name: count, dtype: int64
#                                  Melhor          Segundo Melhor  \
# Trafo
# ABR_DJ_12B1               LSTM_S-GD.csv     LSTM_S-Clientes.csv
# AER_DJ_12B1                RFR_S-GD.csv            SVR_S-GD.csv
# APL_DJ_12B1         LSTM_S-Clientes.csv           LSTM_S-GD.csv
# ARA_DJ_12B1         LSTM_S-Clientes.csv           LSTM_S-GD.csv
# ARN_DJ_12B1         LSTM_S-Clientes.csv           LSTM_S-GD.csv
# ARR_DJ_12B1               LSTM_S-GD.csv     LSTM_S-Clientes.csv
# BBR_DJ_12B1          RFR_S-Clientes.csv     LSTM_S-Clientes.csv
# BBR_DJ_12B2      LSTM_S-Clientes-GD.csv           LSTM_S-GD.csv
# BJC_DJ_12B1               LSTM_S-GD.csv     LSTM_S-Clientes.csv
# BNR_DJ_12B1      LSTM_S-Clientes-GD.csv     LSTM_S-Clientes.csv
# BQR_DJ_12B1      LSTM_S-Clientes-GD.csv     LSTM_S-Clientes.csv
# BSA_DJ_12B1                   SVR_S.csv              LSTM_S.csv
# BSA_DJ_12B2                   SVR_S.csv     LSTM_S-Clientes.csv
# BVA_DJ_12T1                   SVR_S.csv              LSTM_S.csv
# BVT_DJ_12B1               LSTM_S-GD.csv     LSTM_S-Clientes.csv
# BVT_DJ_12B2      LSTM_S-Clientes-GD.csv           LSTM_S-GD.csv
# BYX_DJ_12B1                   SVR_S.csv               RFR_S.csv
# CAA_DJ_12B1         LSTM_S-Clientes.csv  LSTM_S-Clientes-GD.csv
# CBD_DJ_12B1                   SVR_S.csv              LSTM_S.csv
# CBD_DJ_12B2               LSTM_S-GD.csv               SVR_S.csv
# CDE_DJ_12B1         LSTM_S-Clientes.csv  LSTM_S-Clientes-GD.csv
# CGD_DJ_11T7                   SVR_S.csv              LSTM_S.csv
# CGU_DJ_12B1         LSTM_S-Clientes.csv           LSTM_S-GD.csv
# CGU_DJ_12B2               LSTM_S-GD.csv     LSTM_S-Clientes.csv
# CJZ_DJ_12B1                   SVR_S.csv  LSTM_S-Clientes-GD.csv
# CJZ_DJ_12B2                   SVR_S.csv              LSTM_S.csv
# CPX_DJ_12B1               LSTM_S-GD.csv     LSTM_S-Clientes.csv
# CPX_DJ_12B2         LSTM_S-Clientes.csv  LSTM_S-Clientes-GD.csv
# CRI_DJ_12B1                   SVR_S.csv            SVR_S-GD.csv
# CRI_DJ_12B2         LSTM_S-Clientes.csv           LSTM_S-GD.csv
# CRM_DJ_12T1                  LSTM_S.csv               SVR_S.csv
# CTE_DJ_12B1         LSTM_S-Clientes.csv           LSTM_S-GD.csv
# CTL_DJ_12B1                SVR_S-GD.csv            RFR_S-GD.csv
# CTR_DJ_12B1                   SVR_S.csv            SVR_S-GD.csv
# DIN_DJ_12B1                   SVR_S.csv           LSTM_S-GD.csv
# DST_DJ_12B1                   SVR_S.csv            SVR_S-GD.csv
# DST_DJ_12B2                RFR_S-GD.csv   RFR_S-Clientes-GD.csv
# ESP_DJ_12B1               LSTM_S-GD.csv  LSTM_S-Clientes-GD.csv
# GBA_DJ_12B1                   SVR_S.csv              LSTM_S.csv
# GBA_DJ_12B2               LSTM_S-GD.csv  LSTM_S-Clientes-GD.csv
# IBR_DJ_12B1         LSTM_S-Clientes.csv           LSTM_S-GD.csv
# ILB_DJ_12B1         LSTM_S-Clientes.csv           LSTM_S-GD.csv
# ITA_DJ_12B1                   SVR_S.csv           LSTM_S-GD.csv
# ITO_DJ_12B1               LSTM_S-GD.csv  LSTM_S-Clientes-GD.csv
# JCU_DJ_12B1               LSTM_S-GD.csv               SVR_S.csv
# JPS_DJ_12B1                  LSTM_S.csv               SVR_S.csv
# JPS_DJ_12B2                   SVR_S.csv              LSTM_S.csv
# JRC_DJ_12B1                  LSTM_S.csv           LSTM_S-GD.csv
# JTB_DJ_12B1                   SVR_S.csv           LSTM_S-GD.csv
# JZR_DJ_12B1               LSTM_S-GD.csv     LSTM_S-Clientes.csv
# LCN_DJ_12B1                   SVR_S.csv              LSTM_S.csv
# MAA_DJ_12B1                  LSTM_S.csv            RFR_S-GD.csv
# MGB_DJ_12B1                  LSTM_S.csv  LSTM_S-Clientes-GD.csv
# MGB_DJ_12B2                  LSTM_S.csv               SVR_S.csv
# MLT_DJ_12B1                  LSTM_S.csv               SVR_S.csv
# MNT_DJ_12T1         LSTM_S-Clientes.csv  LSTM_S-Clientes-GD.csv
# MRO_DJ_12B1               LSTM_S-GD.csv     LSTM_S-Clientes.csv
# MRU_DJ_12B1                   SVR_S.csv              LSTM_S.csv
# MRU_DJ_12B2                  LSTM_S.csv               SVR_S.csv
# ORT_DJ_12B1               LSTM_S-GD.csv  LSTM_S-Clientes-GD.csv
# PBL_DJ_12B1                  LSTM_S.csv               SVR_S.csv
# PCI_DJ_12B1         LSTM_S-Clientes.csv           LSTM_S-GD.csv
# PCO_DJ_12B1                   SVR_S.csv              LSTM_S.csv
# PLT_DJ_12B1                   SVR_S.csv              LSTM_S.csv
# PLU_DJ_12B1                   SVR_S.csv              LSTM_S.csv
# PLU_DJ_12B1_D_P               RFR_S.csv               SVR_S.csv
# PLV_DJ_12B1         LSTM_S-Clientes.csv           LSTM_S-GD.csv
# POC_DJ_12B1         LSTM_S-Clientes.csv           LSTM_S-GD.csv
# PRI_DJ_12B1         LSTM_S-Clientes.csv           LSTM_S-GD.csv
# PRT_DJ_12B1          RFR_S-Clientes.csv            RFR_S-GD.csv
# PTS_DJ_12B1               LSTM_S-GD.csv  LSTM_S-Clientes-GD.csv
# QMD_DJ_12B1                   SVR_S.csv            SVR_S-GD.csv
# RIC_DJ_12B1                   SVR_S.csv               RFR_S.csv
# RTT_DJ_12B1               LSTM_S-GD.csv  LSTM_S-Clientes-GD.csv
# RTT_DJ_12B2                   SVR_S.csv              LSTM_S.csv
# SBT_DJ_12B1                   SVR_S.csv  LSTM_S-Clientes-GD.csv
# SGL_DJ_12T1                   SVR_S.csv              LSTM_S.csv
# SJC_DJ_12T1               LSTM_S-GD.csv     LSTM_S-Clientes.csv
# SLD_DJ_12B1               LSTM_S-GD.csv  LSTM_S-Clientes-GD.csv
# SLZ_DJ_12B1                   SVR_S.csv     LSTM_S-Clientes.csv
# SPE_DJ_12B2                  LSTM_S.csv               SVR_S.csv
# SPX_DJ_12B1                   SVR_S.csv              LSTM_S.csv
# STR_DJ_12B1                   SVR_S.csv              LSTM_S.csv
# STR_DJ_12B2                   SVR_S.csv     LSTM_S-Clientes.csv
# SZA_DJ_12B1                   SVR_S.csv              LSTM_S.csv
# SZA_DJ_12B2                  LSTM_S.csv           LSTM_S-GD.csv
# TBU_DJ_12B1         LSTM_S-Clientes.csv  LSTM_S-Clientes-GD.csv
# TBU_DJ_12B2               LSTM_S-GD.csv     LSTM_S-Clientes.csv
# TXR_DJ_12B1                   SVR_S.csv           LSTM_S-GD.csv
# URN_DJ_12B1         LSTM_S-Clientes.csv  LSTM_S-Clientes-GD.csv
#
#                         Terceiro Melhor
# Trafo
# ABR_DJ_12B1      LSTM_S-Clientes-GD.csv
# AER_DJ_12B1          RFR_S-Clientes.csv
# APL_DJ_12B1      LSTM_S-Clientes-GD.csv
# ARA_DJ_12B1                   SVR_S.csv
# ARN_DJ_12B1      LSTM_S-Clientes-GD.csv
# ARR_DJ_12B1      LSTM_S-Clientes-GD.csv
# BBR_DJ_12B1      LSTM_S-Clientes-GD.csv
# BBR_DJ_12B2         LSTM_S-Clientes.csv
# BJC_DJ_12B1      LSTM_S-Clientes-GD.csv
# BNR_DJ_12B1               LSTM_S-GD.csv
# BQR_DJ_12B1               LSTM_S-GD.csv
# BSA_DJ_12B1                SVR_S-GD.csv
# BSA_DJ_12B2               LSTM_S-GD.csv
# BVA_DJ_12T1                   RFR_S.csv
# BVT_DJ_12B1      LSTM_S-Clientes-GD.csv
# BVT_DJ_12B2         LSTM_S-Clientes.csv
# BYX_DJ_12B1         LSTM_S-Clientes.csv
# CAA_DJ_12B1                  LSTM_S.csv
# CBD_DJ_12B1         LSTM_S-Clientes.csv
# CBD_DJ_12B2                  LSTM_S.csv
# CDE_DJ_12B1               LSTM_S-GD.csv
# CGD_DJ_11T7                   RFR_S.csv
# CGU_DJ_12B1      LSTM_S-Clientes-GD.csv
# CGU_DJ_12B2      LSTM_S-Clientes-GD.csv
# CJZ_DJ_12B1               LSTM_S-GD.csv
# CJZ_DJ_12B2               LSTM_S-GD.csv
# CPX_DJ_12B1      LSTM_S-Clientes-GD.csv
# CPX_DJ_12B2               LSTM_S-GD.csv
# CRI_DJ_12B1               LSTM_S-GD.csv
# CRI_DJ_12B2      LSTM_S-Clientes-GD.csv
# CRM_DJ_12T1               LSTM_S-GD.csv
# CTE_DJ_12B1      LSTM_S-Clientes-GD.csv
# CTL_DJ_12B1               LSTM_S-GD.csv
# CTR_DJ_12B1         LSTM_S-Clientes.csv
# DIN_DJ_12B1                SVR_S-GD.csv
# DST_DJ_12B1                RFR_S-GD.csv
# DST_DJ_12B2          RFR_S-Clientes.csv
# ESP_DJ_12B1         LSTM_S-Clientes.csv
# GBA_DJ_12B1      LSTM_S-Clientes-GD.csv
# GBA_DJ_12B2         LSTM_S-Clientes.csv
# IBR_DJ_12B1      LSTM_S-Clientes-GD.csv
# ILB_DJ_12B1      LSTM_S-Clientes-GD.csv
# ITA_DJ_12B1         LSTM_S-Clientes.csv
# ITO_DJ_12B1         LSTM_S-Clientes.csv
# JCU_DJ_12B1         LSTM_S-Clientes.csv
# JPS_DJ_12B1                   RFR_S.csv
# JPS_DJ_12B2                   RFR_S.csv
# JRC_DJ_12B1      LSTM_S-Clientes-GD.csv
# JTB_DJ_12B1                   RFR_S.csv
# JZR_DJ_12B1      LSTM_S-Clientes-GD.csv
# LCN_DJ_12B1               LSTM_S-GD.csv
# MAA_DJ_12B1      LSTM_S-Clientes-GD.csv
# MGB_DJ_12B1         LSTM_S-Clientes.csv
# MGB_DJ_12B2         LSTM_S-Clientes.csv
# MLT_DJ_12B1      LSTM_S-Clientes-GD.csv
# MNT_DJ_12T1               LSTM_S-GD.csv
# MRO_DJ_12B1      LSTM_S-Clientes-GD.csv
# MRU_DJ_12B1               LSTM_S-GD.csv
# MRU_DJ_12B2               LSTM_S-GD.csv
# ORT_DJ_12B1         LSTM_S-Clientes.csv
# PBL_DJ_12B1               LSTM_S-GD.csv
# PCI_DJ_12B1      LSTM_S-Clientes-GD.csv
# PCO_DJ_12B1               LSTM_S-GD.csv
# PLT_DJ_12B1          SVR_S-Clientes.csv
# PLU_DJ_12B1                   RFR_S.csv
# PLU_DJ_12B1_D_P              LSTM_S.csv
# PLV_DJ_12B1      LSTM_S-Clientes-GD.csv
# POC_DJ_12B1      LSTM_S-Clientes-GD.csv
# PRI_DJ_12B1      LSTM_S-Clientes-GD.csv
# PRT_DJ_12B1       RFR_S-Clientes-GD.csv
# PTS_DJ_12B1         LSTM_S-Clientes.csv
# QMD_DJ_12B1                  LSTM_S.csv
# RIC_DJ_12B1                SVR_S-GD.csv
# RTT_DJ_12B1         LSTM_S-Clientes.csv
# RTT_DJ_12B2               LSTM_S-GD.csv
# SBT_DJ_12B1                  LSTM_S.csv
# SGL_DJ_12T1               LSTM_S-GD.csv
# SJC_DJ_12T1      LSTM_S-Clientes-GD.csv
# SLD_DJ_12B1         LSTM_S-Clientes.csv
# SLZ_DJ_12B1      LSTM_S-Clientes-GD.csv
# SPE_DJ_12B2               LSTM_S-GD.csv
# SPX_DJ_12B1      LSTM_S-Clientes-GD.csv
# STR_DJ_12B1         LSTM_S-Clientes.csv
# STR_DJ_12B2               LSTM_S-GD.csv
# SZA_DJ_12B1                   RFR_S.csv
# SZA_DJ_12B2      LSTM_S-Clientes-GD.csv
# TBU_DJ_12B1               LSTM_S-GD.csv
# TBU_DJ_12B2                  LSTM_S.csv
# TXR_DJ_12B1         LSTM_S-Clientes.csv
# URN_DJ_12B1               LSTM_S-GD.csv

# %%
pd.set_option('display.float_format', '{:.6f}'.format)

df_concatenado.sort_values('RMSE')
# Out:
#                 Trafo     RMSE                 Arquivo
# 665   PLU_DJ_12B1_D_P 0.000000               RFR_S.csv
# 1010  PLU_DJ_12B1_D_P 0.000000               SVR_S.csv
# 320   PLU_DJ_12B1_D_P 0.000000              LSTM_S.csv
# 169       URN_DJ_12B1 0.008141     LSTM_S-Clientes.csv
# 84        URN_DJ_12B1 0.015833  LSTM_S-Clientes-GD.csv
# 254       URN_DJ_12B1 0.024189           LSTM_S-GD.csv
# 774       URN_DJ_12B1 0.055726   SVR_S-Clientes-GD.csv
# 859       URN_DJ_12B1 0.073851      SVR_S-Clientes.csv
# 89        ARN_DJ_12B1 0.087163     LSTM_S-Clientes.csv
# 174       ARN_DJ_12B1 0.091329           LSTM_S-GD.csv
# 344       URN_DJ_12B1 0.091906              LSTM_S.csv
# 4         ARN_DJ_12B1 0.092119  LSTM_S-Clientes-GD.csv
# 124       IBR_DJ_12B1 0.098914     LSTM_S-Clientes.csv
# 209       IBR_DJ_12B1 0.106023           LSTM_S-GD.csv
# 39        IBR_DJ_12B1 0.109428  LSTM_S-Clientes-GD.csv
# 985       IBR_DJ_12B1 0.115674               SVR_S.csv
# 1034      URN_DJ_12B1 0.120759               SVR_S.csv
# 146       PLV_DJ_12B1 0.129224     LSTM_S-Clientes.csv
# 231       PLV_DJ_12B1 0.129249           LSTM_S-GD.csv
# 814       IBR_DJ_12B1 0.132303      SVR_S-Clientes.csv
# 243       SLD_DJ_12B1 0.132591           LSTM_S-GD.csv
# 73        SLD_DJ_12B1 0.132656  LSTM_S-Clientes-GD.csv
# 158       SLD_DJ_12B1 0.134011     LSTM_S-Clientes.csv
# 295       IBR_DJ_12B1 0.136158              LSTM_S.csv
# 61        PLV_DJ_12B1 0.138275  LSTM_S-Clientes-GD.csv
# 429       URN_DJ_12B1 0.142431   RFR_S-Clientes-GD.csv
# 588       SLD_DJ_12B1 0.142964            RFR_S-GD.csv
# 944       URN_DJ_12B1 0.145169            SVR_S-GD.csv
# 514       URN_DJ_12B1 0.145559      RFR_S-Clientes.csv
# 689       URN_DJ_12B1 0.147540               RFR_S.csv
# 599       URN_DJ_12B1 0.147804            RFR_S-GD.csv
# 503       SLD_DJ_12B1 0.149104      RFR_S-Clientes.csv
# 418       SLD_DJ_12B1 0.150623   RFR_S-Clientes-GD.csv
# 979       DIN_DJ_12B1 0.162343               SVR_S.csv
# 921       PLV_DJ_12B1 0.164836            SVR_S-GD.csv
# 203       DIN_DJ_12B1 0.165607           LSTM_S-GD.csv
# 893       DIN_DJ_12B1 0.167805            SVR_S-GD.csv
# 949       ARN_DJ_12B1 0.169598               SVR_S.csv
# 175       ARR_DJ_12B1 0.173549           LSTM_S-GD.csv
# 33        DIN_DJ_12B1 0.173899  LSTM_S-Clientes-GD.csv
# 118       DIN_DJ_12B1 0.174380     LSTM_S-Clientes.csv
# 90        ARR_DJ_12B1 0.174967     LSTM_S-Clientes.csv
# 143       PCI_DJ_12B1 0.180343     LSTM_S-Clientes.csv
# 228       PCI_DJ_12B1 0.180601           LSTM_S-GD.csv
# 58        PCI_DJ_12B1 0.181986  LSTM_S-Clientes-GD.csv
# 5         ARR_DJ_12B1 0.183175  LSTM_S-Clientes-GD.csv
# 213       JCU_DJ_12B1 0.184988           LSTM_S-GD.csv
# 259       ARN_DJ_12B1 0.187055              LSTM_S.csv
# 115       CTE_DJ_12B1 0.189881     LSTM_S-Clientes.csv
# 200       CTE_DJ_12B1 0.194776           LSTM_S-GD.csv
# 147       POC_DJ_12B1 0.195989     LSTM_S-Clientes.csv
# 232       POC_DJ_12B1 0.196319           LSTM_S-GD.csv
# 406       PLV_DJ_12B1 0.196794   RFR_S-Clientes-GD.csv
# 302       JRC_DJ_12B1 0.197047              LSTM_S.csv
# 836       PLV_DJ_12B1 0.197630      SVR_S-Clientes.csv
# 62        POC_DJ_12B1 0.197682  LSTM_S-Clientes-GD.csv
# 289       DIN_DJ_12B1 0.199260              LSTM_S.csv
# 576       PLV_DJ_12B1 0.199880            RFR_S-GD.csv
# 30        CTE_DJ_12B1 0.200764  LSTM_S-Clientes-GD.csv
# 492       POC_DJ_12B1 0.204959      RFR_S-Clientes.csv
# 729       IBR_DJ_12B1 0.206831   SVR_S-Clientes-GD.csv
# 989       JCU_DJ_12B1 0.207615               SVR_S.csv
# 577       POC_DJ_12B1 0.207676            RFR_S-GD.csv
# 128       JCU_DJ_12B1 0.208094     LSTM_S-Clientes.csv
# 260       ARR_DJ_12B1 0.209494              LSTM_S.csv
# 751       PLV_DJ_12B1 0.211179   SVR_S-Clientes-GD.csv
# 195       CPX_DJ_12B1 0.212022           LSTM_S-GD.csv
# 242       SJC_DJ_12T1 0.213274           LSTM_S-GD.csv
# 491       PLV_DJ_12B1 0.215240      RFR_S-Clientes.csv
# 407       POC_DJ_12B1 0.216303   RFR_S-Clientes-GD.csv
# 299       JCU_DJ_12B1 0.217406              LSTM_S.csv
# 634       DIN_DJ_12B1 0.218631               RFR_S.csv
# 43        JCU_DJ_12B1 0.220122  LSTM_S-Clientes-GD.csv
# 918       PCI_DJ_12B1 0.220313            SVR_S-GD.csv
# 110       CPX_DJ_12B1 0.222104     LSTM_S-Clientes.csv
# 748       PCI_DJ_12B1 0.222566   SVR_S-Clientes-GD.csv
# 214       JRC_DJ_12B1 0.224002           LSTM_S-GD.csv
# 157       SJC_DJ_12T1 0.226637     LSTM_S-Clientes.csv
# 1011      PLV_DJ_12B1 0.229662               SVR_S.csv
# 15        BVT_DJ_12B2 0.230831  LSTM_S-Clientes-GD.csv
# 950       ARR_DJ_12B1 0.233043               SVR_S.csv
# 185       BVT_DJ_12B2 0.233445           LSTM_S-GD.csv
# 100       BVT_DJ_12B2 0.233895     LSTM_S-Clientes.csv
# 1012      POC_DJ_12B1 0.234170               SVR_S.csv
# 178       BJC_DJ_12B1 0.235191           LSTM_S-GD.csv
# 72        SJC_DJ_12T1 0.236821  LSTM_S-Clientes-GD.csv
# 667       POC_DJ_12B1 0.237504               RFR_S.csv
# 44        JRC_DJ_12B1 0.237660  LSTM_S-Clientes-GD.csv
# 1023      SLD_DJ_12B1 0.238058               SVR_S.csv
# 129       JRC_DJ_12B1 0.238088     LSTM_S-Clientes.csv
# 604       ARN_DJ_12B1 0.238183               RFR_S.csv
# 25        CPX_DJ_12B1 0.239953  LSTM_S-Clientes-GD.csv
# 322       POC_DJ_12B1 0.241117              LSTM_S.csv
# 434       ARN_DJ_12B1 0.242260      RFR_S-Clientes.csv
# 93        BJC_DJ_12B1 0.242397     LSTM_S-Clientes.csv
# 899       IBR_DJ_12B1 0.243449            SVR_S-GD.csv
# 864       ARN_DJ_12B1 0.244300            SVR_S-GD.csv
# 723       DIN_DJ_12B1 0.247652   SVR_S-Clientes-GD.csv
# 519       ARN_DJ_12B1 0.248066            RFR_S-GD.csv
# 488       PCI_DJ_12B1 0.248390      RFR_S-Clientes.csv
# 1033      TXR_DJ_12B1 0.249975               SVR_S.csv
# 349       ARN_DJ_12B1 0.251020   RFR_S-Clientes-GD.csv
# 573       PCI_DJ_12B1 0.255334            RFR_S-GD.csv
# 253       TXR_DJ_12B1 0.256933           LSTM_S-GD.csv
# 168       TXR_DJ_12B1 0.263092     LSTM_S-Clientes.csv
# 403       PCI_DJ_12B1 0.264734   RFR_S-Clientes-GD.csv
# 933       SLD_DJ_12B1 0.267167            SVR_S-GD.csv
# 285       CRM_DJ_12T1 0.268615              LSTM_S.csv
# 83        TXR_DJ_12B1 0.269624  LSTM_S-Clientes-GD.csv
# 8         BJC_DJ_12B1 0.270269  LSTM_S-Clientes-GD.csv
# 1024      SLZ_DJ_12B1 0.272148               SVR_S.csv
# 1008      PLT_DJ_12B1 0.274165               SVR_S.csv
# 321       PLV_DJ_12B1 0.274651              LSTM_S.csv
# 263       BJC_DJ_12B1 0.275925              LSTM_S.csv
# 847       SJC_DJ_12T1 0.278466      SVR_S-Clientes.csv
# 833       PCI_DJ_12B1 0.278608      SVR_S-Clientes.csv
# 554       IBR_DJ_12B1 0.278659            RFR_S-GD.csv
# 992       JRC_DJ_12B1 0.279353               SVR_S.csv
# 192       CGU_DJ_12B2 0.280617           LSTM_S-GD.csv
# 309       MLT_DJ_12B1 0.281399              LSTM_S.csv
# 953       BJC_DJ_12B1 0.281750               SVR_S.csv
# 1022      SJC_DJ_12T1 0.281929               SVR_S.csv
# 206       ESP_DJ_12B1 0.282515           LSTM_S-GD.csv
# 107       CGU_DJ_12B2 0.283405     LSTM_S-Clientes.csv
# 22        CGU_DJ_12B2 0.285512  LSTM_S-Clientes-GD.csv
# 587       SJC_DJ_12T1 0.287068            RFR_S-GD.csv
# 343       TXR_DJ_12B1 0.288164              LSTM_S.csv
# 975       CRM_DJ_12T1 0.288427               SVR_S.csv
# 762       SJC_DJ_12T1 0.289160   SVR_S-Clientes-GD.csv
# 999       MLT_DJ_12B1 0.290200               SVR_S.csv
# 903       JCU_DJ_12B1 0.290357            SVR_S-GD.csv
# 530       BVT_DJ_12B2 0.291300            RFR_S-GD.csv
# 513       TXR_DJ_12B1 0.294656      RFR_S-Clientes.csv
# 1026      SPX_DJ_12B1 0.295370               SVR_S.csv
# 885       CPX_DJ_12B1 0.295491            SVR_S-GD.csv
# 36        ESP_DJ_12B1 0.295505  LSTM_S-Clientes-GD.csv
# 868       BJC_DJ_12B1 0.296608            SVR_S-GD.csv
# 598       TXR_DJ_12B1 0.296824            RFR_S-GD.csv
# 983       GBA_DJ_12B1 0.298915               SVR_S.csv
# 445       BVT_DJ_12B2 0.300100      RFR_S-Clientes.csv
# 333       SLD_DJ_12B1 0.301507              LSTM_S.csv
# 958       BVA_DJ_12T1 0.305962               SVR_S.csv
# 121       ESP_DJ_12B1 0.306564     LSTM_S-Clientes.csv
# 904       JRC_DJ_12B1 0.306781            SVR_S-GD.csv
# 159       SLZ_DJ_12B1 0.308723     LSTM_S-Clientes.csv
# 837       POC_DJ_12B1 0.311070      SVR_S-Clientes.csv
# 74        SLZ_DJ_12B1 0.314974  LSTM_S-Clientes-GD.csv
# 797       CGU_DJ_12B2 0.315405      SVR_S-Clientes.csv
# 890       CTE_DJ_12B1 0.316116            SVR_S-GD.csv
# 199       CRM_DJ_12T1 0.316195           LSTM_S-GD.csv
# 360       BVT_DJ_12B2 0.316354   RFR_S-Clientes-GD.csv
# 605       ARR_DJ_12B1 0.316875               RFR_S.csv
# 688       TXR_DJ_12B1 0.317518               RFR_S.csv
# 114       CRM_DJ_12T1 0.318343     LSTM_S-Clientes.csv
# 244       SLZ_DJ_12B1 0.320515           LSTM_S-GD.csv
# 29        CRM_DJ_12T1 0.320911  LSTM_S-Clientes-GD.csv
# 10        BQR_DJ_12B1 0.321010  LSTM_S-Clientes-GD.csv
# 95        BQR_DJ_12B1 0.321522     LSTM_S-Clientes.csv
# 428       TXR_DJ_12B1 0.321546   RFR_S-Clientes-GD.csv
# 336       SPX_DJ_12B1 0.322043              LSTM_S.csv
# 316       PCI_DJ_12B1 0.324195              LSTM_S.csv
# 469       IBR_DJ_12B1 0.325284      RFR_S-Clientes.csv
# 384       IBR_DJ_12B1 0.327098   RFR_S-Clientes-GD.csv
# 435       ARR_DJ_12B1 0.327136      RFR_S-Clientes.csv
# 1002      MRU_DJ_12B1 0.329546               SVR_S.csv
# 932       SJC_DJ_12T1 0.330176            SVR_S-GD.csv
# 180       BQR_DJ_12B1 0.330414           LSTM_S-GD.csv
# 968       CGU_DJ_12B2 0.330522               SVR_S.csv
# 318       PLT_DJ_12B1 0.331131              LSTM_S.csv
# 350       ARR_DJ_12B1 0.334481   RFR_S-Clientes-GD.csv
# 417       SJC_DJ_12T1 0.335862   RFR_S-Clientes-GD.csv
# 216       JZR_DJ_12B1 0.336859           LSTM_S-GD.csv
# 520       ARR_DJ_12B1 0.340168            RFR_S-GD.csv
# 502       SJC_DJ_12T1 0.340272      RFR_S-Clientes.csv
# 679       SLZ_DJ_12B1 0.341082               RFR_S.csv
# 293       GBA_DJ_12B1 0.341201              LSTM_S.csv
# 334       SLZ_DJ_12B1 0.341817              LSTM_S.csv
# 131       JZR_DJ_12B1 0.345637     LSTM_S-Clientes.csv
# 835       PLT_DJ_12B1 0.346735      SVR_S-Clientes.csv
# 889       CRM_DJ_12T1 0.347891            SVR_S-GD.csv
# 537       CGU_DJ_12B2 0.347972            RFR_S-GD.csv
# 106       CGU_DJ_12B1 0.349323     LSTM_S-Clientes.csv
# 191       CGU_DJ_12B1 0.349450           LSTM_S-GD.csv
# 21        CGU_DJ_12B1 0.350458  LSTM_S-Clientes-GD.csv
# 332       SJC_DJ_12T1 0.350668              LSTM_S.csv
# 550       DST_DJ_12B2 0.352801            RFR_S-GD.csv
# 46        JZR_DJ_12B1 0.353795  LSTM_S-Clientes-GD.csv
# 678       SLD_DJ_12B1 0.354932               RFR_S.csv
# 452       CGU_DJ_12B2 0.355026      RFR_S-Clientes.csv
# 268       BVA_DJ_12T1 0.356059              LSTM_S.csv
# 934       SLZ_DJ_12B1 0.356930            SVR_S-GD.csv
# 37        GBA_DJ_12B1 0.357284  LSTM_S-Clientes-GD.csv
# 380       DST_DJ_12B2 0.357417   RFR_S-Clientes-GD.csv
# 367       CGU_DJ_12B2 0.358975   RFR_S-Clientes-GD.csv
# 540       CPX_DJ_12B1 0.361258            RFR_S-GD.csv
# 613       BVA_DJ_12T1 0.361454               RFR_S.csv
# 60        PLT_DJ_12B1 0.369786  LSTM_S-Clientes-GD.csv
# 455       CPX_DJ_12B1 0.370804      RFR_S-Clientes.csv
# 875       BVT_DJ_12B2 0.374162            SVR_S-GD.csv
# 465       DST_DJ_12B2 0.377878      RFR_S-Clientes.csv
# 896       ESP_DJ_12B1 0.378514            SVR_S-GD.csv
# 528       BVA_DJ_12T1 0.379451            RFR_S-GD.csv
# 608       BJC_DJ_12B1 0.380550               RFR_S.csv
# 804       CRM_DJ_12T1 0.381423      SVR_S-Clientes.csv
# 207       GBA_DJ_12B1 0.383206           LSTM_S-GD.csv
# 148       PRI_DJ_12B1 0.383320     LSTM_S-Clientes.csv
# 233       PRI_DJ_12B1 0.384173           LSTM_S-GD.csv
# 145       PLT_DJ_12B1 0.385269     LSTM_S-Clientes.csv
# 51        MLT_DJ_12B1 0.386662  LSTM_S-Clientes-GD.csv
# 76        SPX_DJ_12B1 0.386688  LSTM_S-Clientes-GD.csv
# 230       PLT_DJ_12B1 0.389298           LSTM_S-GD.csv
# 278       CGU_DJ_12B2 0.390269              LSTM_S.csv
# 922       POC_DJ_12B1 0.391800            SVR_S-GD.csv
# 161       SPX_DJ_12B1 0.395036     LSTM_S-Clientes.csv
# 750       PLT_DJ_12B1 0.395246   SVR_S-Clientes-GD.csv
# 87        APL_DJ_12B1 0.396902     LSTM_S-Clientes.csv
# 137       MNT_DJ_12T1 0.398801     LSTM_S-Clientes.csv
# 122       GBA_DJ_12B1 0.399036     LSTM_S-Clientes.csv
# 172       APL_DJ_12B1 0.400159           LSTM_S-GD.csv
# 1007      PCO_DJ_12B1 0.401003               SVR_S.csv
# 370       CPX_DJ_12B1 0.401539   RFR_S-Clientes-GD.csv
# 136       MLT_DJ_12B1 0.402345     LSTM_S-Clientes.csv
# 221       MLT_DJ_12B1 0.403129           LSTM_S-GD.csv
# 113       CRI_DJ_12B2 0.403457     LSTM_S-Clientes.csv
# 982       ESP_DJ_12B1 0.403956               SVR_S.csv
# 198       CRI_DJ_12B2 0.404073           LSTM_S-GD.csv
# 1009      PLU_DJ_12B1 0.404988               SVR_S.csv
# 666       PLV_DJ_12B1 0.405003               RFR_S.csv
# 102       CAA_DJ_12B1 0.405243     LSTM_S-Clientes.csv
# 63        PRI_DJ_12B1 0.405625  LSTM_S-Clientes-GD.csv
# 7         BBR_DJ_12B2 0.406673  LSTM_S-Clientes-GD.csv
# 548       DIN_DJ_12B1 0.407710            RFR_S-GD.csv
# 1013      PRI_DJ_12B1 0.407722               SVR_S.csv
# 436       BBR_DJ_12B1 0.407768      RFR_S-Clientes.csv
# 663       PLT_DJ_12B1 0.407799               RFR_S.csv
# 177       BBR_DJ_12B2 0.407901           LSTM_S-GD.csv
# 994       JZR_DJ_12B1 0.408774               SVR_S.csv
# 52        MNT_DJ_12T1 0.409833  LSTM_S-Clientes-GD.csv
# 976       CTE_DJ_12B1 0.410123               SVR_S.csv
# 474       JRC_DJ_12B1 0.410317      RFR_S-Clientes.csv
# 92        BBR_DJ_12B2 0.411023     LSTM_S-Clientes.csv
# 559       JRC_DJ_12B1 0.411925            RFR_S-GD.csv
# 2         APL_DJ_12B1 0.412543  LSTM_S-Clientes-GD.csv
# 183       BVA_DJ_12T1 0.414322           LSTM_S-GD.csv
# 222       MNT_DJ_12T1 0.414795           LSTM_S-GD.csv
# 91        BBR_DJ_12B1 0.415296     LSTM_S-Clientes.csv
# 6         BBR_DJ_12B1 0.417507  LSTM_S-Clientes-GD.csv
# 170       ABR_DJ_12B1 0.418541           LSTM_S-GD.csv
# 752       POC_DJ_12B1 0.418576   SVR_S-Clientes-GD.csv
# 312       MRU_DJ_12B1 0.420331              LSTM_S.csv
# 35        DST_DJ_12B2 0.421610  LSTM_S-Clientes-GD.csv
# 291       DST_DJ_12B2 0.421659              LSTM_S.csv
# 1016      QMD_DJ_12B1 0.421700               SVR_S.csv
# 85        ABR_DJ_12B1 0.422110     LSTM_S-Clientes.csv
# 176       BBR_DJ_12B1 0.422743           LSTM_S-GD.csv
# 351       BBR_DJ_12B1 0.423017   RFR_S-Clientes-GD.csv
# 98        BVA_DJ_12T1 0.423156     LSTM_S-Clientes.csv
# 545       CTE_DJ_12B1 0.423426            RFR_S-GD.csv
# 120       DST_DJ_12B2 0.424021     LSTM_S-Clientes.csv
# 378       DIN_DJ_12B1 0.424670   RFR_S-Clientes-GD.csv
# 389       JRC_DJ_12B1 0.424916   RFR_S-Clientes-GD.csv
# 205       DST_DJ_12B2 0.425301           LSTM_S-GD.csv
# 636       DST_DJ_12B2 0.426042               RFR_S.csv
# 882       CGU_DJ_12B2 0.426639            SVR_S-GD.csv
# 317       PCO_DJ_12B1 0.427513              LSTM_S.csv
# 0         ABR_DJ_12B1 0.429187  LSTM_S-Clientes-GD.csv
# 323       PRI_DJ_12B1 0.433038              LSTM_S.csv
# 521       BBR_DJ_12B1 0.433102            RFR_S-GD.csv
# 623       CGU_DJ_12B2 0.433551               RFR_S.csv
# 246       SPX_DJ_12B1 0.434740           LSTM_S-GD.csv
# 788       BVA_DJ_12T1 0.436765      SVR_S-Clientes.csv
# 13        BVA_DJ_12T1 0.437615  LSTM_S-Clientes-GD.csv
# 644       JCU_DJ_12B1 0.437817               RFR_S.csv
# 28        CRI_DJ_12B2 0.439053  LSTM_S-Clientes-GD.csv
# 1021      SGL_DJ_12T1 0.439723               SVR_S.csv
# 783       BJC_DJ_12B1 0.439986      SVR_S-Clientes.csv
# 284       CRI_DJ_12B2 0.440866              LSTM_S.csv
# 443       BVA_DJ_12T1 0.442358      RFR_S-Clientes.csv
# 17        CAA_DJ_12B1 0.443713  LSTM_S-Clientes-GD.csv
# 375       CTE_DJ_12B1 0.443893   RFR_S-Clientes-GD.csv
# 681       SPX_DJ_12B1 0.444824               RFR_S.csv
# 319       PLU_DJ_12B1 0.445060              LSTM_S.csv
# 226       ORT_DJ_12B1 0.446134           LSTM_S-GD.csv
# 358       BVA_DJ_12T1 0.446699   RFR_S-Clientes-GD.csv
# 923       PRI_DJ_12B1 0.447140            SVR_S-GD.csv
# 463       DIN_DJ_12B1 0.449686      RFR_S-Clientes.csv
# 631       CTE_DJ_12B1 0.451118               RFR_S.csv
# 56        ORT_DJ_12B1 0.452249  LSTM_S-Clientes-GD.csv
# 661       PCI_DJ_12B1 0.455903               RFR_S.csv
# 895       DST_DJ_12B2 0.457167            SVR_S-GD.csv
# 677       SJC_DJ_12T1 0.460224               RFR_S.csv
# 936       SPX_DJ_12B1 0.461662            SVR_S-GD.csv
# 629       CRI_DJ_12B2 0.462280               RFR_S.csv
# 141       ORT_DJ_12B1 0.462336     LSTM_S-Clientes.csv
# 460       CTE_DJ_12B1 0.463795      RFR_S-Clientes.csv
# 125       ILB_DJ_12B1 0.463948     LSTM_S-Clientes.csv
# 516       AER_DJ_12B1 0.465662            RFR_S-GD.csv
# 551       ESP_DJ_12B1 0.467438            RFR_S-GD.csv
# 766       SPX_DJ_12B1 0.467529   SVR_S-Clientes-GD.csv
# 272       CAA_DJ_12B1 0.467606              LSTM_S.csv
# 229       PCO_DJ_12B1 0.468216           LSTM_S-GD.csv
# 331       SGL_DJ_12T1 0.468452              LSTM_S.csv
# 926       QMD_DJ_12B1 0.469677            SVR_S-GD.csv
# 144       PCO_DJ_12B1 0.470323     LSTM_S-Clientes.csv
# 951       BBR_DJ_12B1 0.470436               SVR_S.csv
# 981       DST_DJ_12B2 0.470979               SVR_S.csv
# 59        PCO_DJ_12B1 0.471311  LSTM_S-Clientes-GD.csv
# 638       GBA_DJ_12B1 0.471316               RFR_S.csv
# 911       MLT_DJ_12B1 0.471768            SVR_S-GD.csv
# 705       BVT_DJ_12B2 0.472777   SVR_S-Clientes-GD.csv
# 630       CRM_DJ_12T1 0.473241               RFR_S.csv
# 187       CAA_DJ_12B1 0.474295           LSTM_S-GD.csv
# 962       CAA_DJ_12B1 0.474445               SVR_S.csv
# 826       MLT_DJ_12B1 0.474606      SVR_S-Clientes.csv
# 654       MLT_DJ_12B1 0.474984               RFR_S.csv
# 790       BVT_DJ_12B2 0.475474      SVR_S-Clientes.csv
# 995       LCN_DJ_12B1 0.477340               SVR_S.csv
# 861       AER_DJ_12B1 0.478705            SVR_S-GD.csv
# 241       SGL_DJ_12T1 0.480352           LSTM_S-GD.csv
# 906       JZR_DJ_12B1 0.481234            SVR_S-GD.csv
# 223       MRO_DJ_12B1 0.482679           LSTM_S-GD.csv
# 71        SGL_DJ_12T1 0.483016  LSTM_S-Clientes-GD.csv
# 382       GBA_DJ_12B1 0.483065   RFR_S-Clientes-GD.csv
# 866       BBR_DJ_12B1 0.483350            SVR_S-GD.csv
# 138       MRO_DJ_12B1 0.484014     LSTM_S-Clientes.csv
# 698       BJC_DJ_12B1 0.487725   SVR_S-Clientes-GD.csv
# 156       SGL_DJ_12T1 0.488769     LSTM_S-Clientes.csv
# 808       DIN_DJ_12B1 0.489220      SVR_S-Clientes.csv
# 974       CRI_DJ_12B2 0.490890               SVR_S.csv
# 292       ESP_DJ_12B1 0.491100              LSTM_S.csv
# 305       LCN_DJ_12B1 0.492239              LSTM_S.csv
# 224       MRU_DJ_12B1 0.493478           LSTM_S-GD.csv
# 54        MRU_DJ_12B1 0.496499  LSTM_S-Clientes-GD.csv
# 210       ILB_DJ_12B1 0.501007           LSTM_S-GD.csv
# 1027      STR_DJ_12B1 0.503309               SVR_S.csv
# 466       ESP_DJ_12B1 0.505185      RFR_S-Clientes.csv
# 920       PLT_DJ_12B1 0.507756            SVR_S-GD.csv
# 261       BBR_DJ_12B1 0.508158              LSTM_S.csv
# 476       JZR_DJ_12B1 0.509727      RFR_S-Clientes.csv
# 561       JZR_DJ_12B1 0.510723            RFR_S-GD.csv
# 1019      RTT_DJ_12B2 0.512514               SVR_S.csv
# 391       JZR_DJ_12B1 0.515339   RFR_S-Clientes-GD.csv
# 315       PBL_DJ_12B1 0.518959              LSTM_S.csv
# 467       GBA_DJ_12B1 0.520697      RFR_S-Clientes.csv
# 381       ESP_DJ_12B1 0.525672   RFR_S-Clientes-GD.csv
# 741       MLT_DJ_12B1 0.528356   SVR_S-Clientes-GD.csv
# 1000      MNT_DJ_12T1 0.528704               SVR_S.csv
# 9         BNR_DJ_12B1 0.530806  LSTM_S-Clientes-GD.csv
# 139       MRU_DJ_12B1 0.531772     LSTM_S-Clientes.csv
# 515       ABR_DJ_12B1 0.532231            RFR_S-GD.csv
# 1004      ORT_DJ_12B1 0.532529               SVR_S.csv
# 805       CTE_DJ_12B1 0.532637      SVR_S-Clientes.csv
# 286       CTE_DJ_12B1 0.534093              LSTM_S.csv
# 1029      SZA_DJ_12B1 0.534548               SVR_S.csv
# 184       BVT_DJ_12B1 0.534962           LSTM_S-GD.csv
# 589       SLZ_DJ_12B1 0.535670            RFR_S-GD.csv
# 326       QMD_DJ_12B1 0.535735              LSTM_S.csv
# 781       BBR_DJ_12B1 0.536125      SVR_S-Clientes.csv
# 40        ILB_DJ_12B1 0.537338  LSTM_S-Clientes-GD.csv
# 337       STR_DJ_12B1 0.537587              LSTM_S.csv
# 779       ARN_DJ_12B1 0.537693      SVR_S-Clientes.csv
# 53        MRO_DJ_12B1 0.537772  LSTM_S-Clientes-GD.csv
# 581       QMD_DJ_12B1 0.538778            RFR_S-GD.csv
# 943       TXR_DJ_12B1 0.539098            SVR_S-GD.csv
# 1005      PBL_DJ_12B1 0.539311               SVR_S.csv
# 94        BNR_DJ_12B1 0.540127     LSTM_S-Clientes.csv
# 212       ITO_DJ_12B1 0.540960           LSTM_S-GD.csv
# 712       CGU_DJ_12B2 0.543710   SVR_S-Clientes-GD.csv
# 718       CRI_DJ_12B2 0.544821   SVR_S-Clientes-GD.csv
# 42        ITO_DJ_12B1 0.546654  LSTM_S-Clientes-GD.csv
# 66        QMD_DJ_12B1 0.548953  LSTM_S-Clientes-GD.csv
# 552       GBA_DJ_12B1 0.549557            RFR_S-GD.csv
# 88        ARA_DJ_12B1 0.549810     LSTM_S-Clientes.csv
# 339       SZA_DJ_12B1 0.550107              LSTM_S.csv
# 637       ESP_DJ_12B1 0.550872               RFR_S.csv
# 151       QMD_DJ_12B1 0.552274     LSTM_S-Clientes.csv
# 860       ABR_DJ_12B1 0.553723            SVR_S-GD.csv
# 173       ARA_DJ_12B1 0.555211           LSTM_S-GD.csv
# 523       BJC_DJ_12B1 0.556842            RFR_S-GD.csv
# 127       ITO_DJ_12B1 0.559660     LSTM_S-Clientes.csv
# 602       APL_DJ_12B1 0.561075               RFR_S.csv
# 304       JZR_DJ_12B1 0.561823              LSTM_S.csv
# 504       SLZ_DJ_12B1 0.561995      RFR_S-Clientes.csv
# 179       BNR_DJ_12B1 0.562734           LSTM_S-GD.csv
# 640       IBR_DJ_12B1 0.562875               RFR_S.csv
# 496       QMD_DJ_12B1 0.563112      RFR_S-Clientes.csv
# 99        BVT_DJ_12B1 0.563285     LSTM_S-Clientes.csv
# 796       CGU_DJ_12B1 0.563655      SVR_S-Clientes.csv
# 236       QMD_DJ_12B1 0.565793           LSTM_S-GD.csv
# 694       ARN_DJ_12B1 0.566439   SVR_S-Clientes-GD.csv
# 978       CTR_DJ_12B1 0.566904               SVR_S.csv
# 664       PLU_DJ_12B1 0.567800               RFR_S.csv
# 411       QMD_DJ_12B1 0.567878   RFR_S-Clientes-GD.csv
# 447       CAA_DJ_12B1 0.569045      RFR_S-Clientes.csv
# 715       CPX_DJ_12B1 0.573233   SVR_S-Clientes-GD.csv
# 671       QMD_DJ_12B1 0.574225               RFR_S.csv
# 329       RTT_DJ_12B2 0.574913              LSTM_S.csv
# 838       PRI_DJ_12B1 0.575447      SVR_S-Clientes.csv
# 763       SLD_DJ_12B1 0.575761   SVR_S-Clientes-GD.csv
# 948       ARA_DJ_12B1 0.575894               SVR_S.csv
# 888       CRI_DJ_12B2 0.576870            SVR_S-GD.csv
# 775       ABR_DJ_12B1 0.578495      SVR_S-Clientes.csv
# 753       PRI_DJ_12B1 0.578815   SVR_S-Clientes-GD.csv
# 649       JZR_DJ_12B1 0.579047               RFR_S.csv
# 800       CPX_DJ_12B1 0.579330      SVR_S-Clientes.csv
# 419       SLZ_DJ_12B1 0.579592   RFR_S-Clientes-GD.csv
# 988       ITO_DJ_12B1 0.581175               SVR_S.csv
# 3         ARA_DJ_12B1 0.583582  LSTM_S-Clientes-GD.csv
# 345       ABR_DJ_12B1 0.584535   RFR_S-Clientes-GD.csv
# 362       CAA_DJ_12B1 0.588535   RFR_S-Clientes-GD.csv
# 811       ESP_DJ_12B1 0.590423      SVR_S-Clientes.csv
# 314       ORT_DJ_12B1 0.591868              LSTM_S.csv
# 438       BJC_DJ_12B1 0.592183      RFR_S-Clientes.csv
# 1017      RIC_DJ_12B1 0.592218               SVR_S.csv
# 961       BYX_DJ_12B1 0.593903               SVR_S.csv
# 902       ITO_DJ_12B1 0.595326            SVR_S-GD.csv
# 14        BVT_DJ_12B1 0.596324  LSTM_S-Clientes-GD.csv
# 756       QMD_DJ_12B1 0.596394   SVR_S-Clientes-GD.csv
# 239       RTT_DJ_12B2 0.597574           LSTM_S-GD.csv
# 912       MNT_DJ_12T1 0.598681            SVR_S-GD.csv
# 532       CAA_DJ_12B1 0.599163            RFR_S-GD.csv
# 657       MRU_DJ_12B1 0.599552               RFR_S.csv
# 529       BVT_DJ_12B1 0.600252            RFR_S-GD.csv
# 69        RTT_DJ_12B2 0.601614  LSTM_S-Clientes-GD.csv
# 154       RTT_DJ_12B2 0.602467     LSTM_S-Clientes.csv
# 430       ABR_DJ_12B1 0.608382      RFR_S-Clientes.csv
# 668       PRI_DJ_12B1 0.610077               RFR_S.csv
# 931       SGL_DJ_12T1 0.611360            SVR_S-GD.csv
# 764       SLZ_DJ_12B1 0.612466   SVR_S-Clientes-GD.csv
# 987       ITA_DJ_12B1 0.614652               SVR_S.csv
# 719       CRM_DJ_12T1 0.615969   SVR_S-Clientes-GD.csv
# 803       CRI_DJ_12B2 0.616369      SVR_S-Clientes.csv
# 306       MAA_DJ_12B1 0.616887              LSTM_S.csv
# 720       CTE_DJ_12B1 0.620784   SVR_S-Clientes-GD.csv
# 444       BVT_DJ_12B1 0.620817      RFR_S-Clientes.csv
# 711       CGU_DJ_12B1 0.620933   SVR_S-Clientes-GD.csv
# 952       BBR_DJ_12B2 0.620963               SVR_S.csv
# 881       CGU_DJ_12B1 0.624112            SVR_S-GD.csv
# 353       BJC_DJ_12B1 0.631523   RFR_S-Clientes-GD.csv
# 431       AER_DJ_12B1 0.633277      RFR_S-Clientes.csv
# 662       PCO_DJ_12B1 0.634395               RFR_S.csv
# 947       APL_DJ_12B1 0.634941               SVR_S.csv
# 359       BVT_DJ_12B1 0.634965   RFR_S-Clientes-GD.csv
# 834       PCO_DJ_12B1 0.635569      SVR_S-Clientes.csv
# 227       PBL_DJ_12B1 0.636639           LSTM_S-GD.csv
# 217       LCN_DJ_12B1 0.638971           LSTM_S-GD.csv
# 563       MAA_DJ_12B1 0.640295            RFR_S-GD.csv
# 142       PBL_DJ_12B1 0.640775     LSTM_S-Clientes.csv
# 298       ITO_DJ_12B1 0.642921              LSTM_S.csv
# 1         AER_DJ_12B1 0.645391  LSTM_S-Clientes-GD.csv
# 543       CRI_DJ_12B2 0.646075            RFR_S-GD.csv
# 789       BVT_DJ_12B1 0.646298      SVR_S-Clientes.csv
# 892       CTR_DJ_12B1 0.647049            SVR_S-GD.csv
# 117       CTR_DJ_12B1 0.647422     LSTM_S-Clientes.csv
# 48        MAA_DJ_12B1 0.649827  LSTM_S-Clientes-GD.csv
# 257       APL_DJ_12B1 0.650803              LSTM_S.csv
# 310       MNT_DJ_12T1 0.650944              LSTM_S.csv
# 218       MAA_DJ_12B1 0.651007           LSTM_S-GD.csv
# 202       CTR_DJ_12B1 0.652528           LSTM_S-GD.csv
# 171       AER_DJ_12B1 0.654038           LSTM_S-GD.csv
# 47        LCN_DJ_12B1 0.654139  LSTM_S-Clientes-GD.csv
# 346       AER_DJ_12B1 0.654778   RFR_S-Clientes-GD.csv
# 955       BQR_DJ_12B1 0.657619               SVR_S.csv
# 262       BBR_DJ_12B2 0.660895              LSTM_S.csv
# 650       LCN_DJ_12B1 0.664491               RFR_S.csv
# 776       AER_DJ_12B1 0.664888      SVR_S-Clientes.csv
# 86        AER_DJ_12B1 0.665284     LSTM_S-Clientes.csv
# 960       BVT_DJ_12B2 0.666036               SVR_S.csv
# 258       ARA_DJ_12B1 0.666353              LSTM_S.csv
# 993       JTB_DJ_12B1 0.666807               SVR_S.csv
# 133       MAA_DJ_12B1 0.666858     LSTM_S-Clientes.csv
# 996       MAA_DJ_12B1 0.666967               SVR_S.csv
# 651       MAA_DJ_12B1 0.668967               RFR_S.csv
# 566       MLT_DJ_12B1 0.669801            RFR_S-GD.csv
# 672       RIC_DJ_12B1 0.672171               RFR_S.csv
# 874       BVT_DJ_12B1 0.674486            SVR_S-GD.csv
# 132       LCN_DJ_12B1 0.677530     LSTM_S-Clientes.csv
# 616       BYX_DJ_12B1 0.677845               RFR_S.csv
# 966       CGD_DJ_11T7 0.678550               SVR_S.csv
# 849       SLZ_DJ_12B1 0.680798      SVR_S-Clientes.csv
# 57        PBL_DJ_12B1 0.682046  LSTM_S-Clientes-GD.csv
# 844       RTT_DJ_12B2 0.684493      SVR_S-Clientes.csv
# 690       ABR_DJ_12B1 0.685124   SVR_S-Clientes-GD.csv
# 946       AER_DJ_12B1 0.688095               SVR_S.csv
# 478       MAA_DJ_12B1 0.690075      RFR_S-Clientes.csv
# 914       MRU_DJ_12B1 0.691182            SVR_S-GD.csv
# 340       SZA_DJ_12B2 0.691652              LSTM_S.csv
# 691       AER_DJ_12B1 0.691882   SVR_S-Clientes-GD.csv
# 32        CTR_DJ_12B1 0.692208  LSTM_S-Clientes-GD.csv
# 615       BVT_DJ_12B2 0.695150               RFR_S.csv
# 917       PBL_DJ_12B1 0.696667            SVR_S-GD.csv
# 957       BSA_DJ_12B2 0.696674               SVR_S.csv
# 97        BSA_DJ_12B2 0.697560     LSTM_S-Clientes.csv
# 617       CAA_DJ_12B1 0.698057               RFR_S.csv
# 575       PLT_DJ_12B1 0.698604            RFR_S-GD.csv
# 481       MLT_DJ_12B1 0.698733      RFR_S-Clientes.csv
# 477       LCN_DJ_12B1 0.701740      RFR_S-Clientes.csv
# 396       MLT_DJ_12B1 0.704842   RFR_S-Clientes-GD.csv
# 704       BVT_DJ_12B1 0.706080   SVR_S-Clientes-GD.csv
# 1020      SBT_DJ_12B1 0.706918               SVR_S.csv
# 250       SZA_DJ_12B2 0.707129           LSTM_S-GD.csv
# 308       MGB_DJ_12B2 0.707403              LSTM_S.csv
# 606       BBR_DJ_12B1 0.708328               RFR_S.csv
# 919       PCO_DJ_12B1 0.709441            SVR_S-GD.csv
# 162       STR_DJ_12B1 0.709671     LSTM_S-Clientes.csv
# 929       RTT_DJ_12B2 0.710756            SVR_S-GD.csv
# 937       STR_DJ_12B1 0.711778            SVR_S-GD.csv
# 970       CJZ_DJ_12B2 0.712991               SVR_S.csv
# 182       BSA_DJ_12B2 0.713251           LSTM_S-GD.csv
# 643       ITO_DJ_12B1 0.713638               RFR_S.csv
# 80        SZA_DJ_12B2 0.713964  LSTM_S-Clientes-GD.csv
# 77        STR_DJ_12B1 0.714642  LSTM_S-Clientes-GD.csv
# 1006      PCI_DJ_12B1 0.715333               SVR_S.csv
# 393       MAA_DJ_12B1 0.715887   RFR_S-Clientes-GD.csv
# 737       LCN_DJ_12B1 0.716301   SVR_S-Clientes-GD.csv
# 165       SZA_DJ_12B2 0.716307     LSTM_S-Clientes.csv
# 405       PLT_DJ_12B1 0.716559   RFR_S-Clientes-GD.csv
# 907       LCN_DJ_12B1 0.719574            SVR_S-GD.csv
# 863       ARA_DJ_12B1 0.721429            SVR_S-GD.csv
# 927       RIC_DJ_12B1 0.722567            SVR_S-GD.csv
# 288       CTR_DJ_12B1 0.723228              LSTM_S.csv
# 12        BSA_DJ_12B2 0.725014  LSTM_S-Clientes-GD.csv
# 189       CBD_DJ_12B2 0.725246           LSTM_S-GD.csv
# 964       CBD_DJ_12B2 0.725848               SVR_S.csv
# 211       ITA_DJ_12B1 0.726998           LSTM_S-GD.csv
# 684       SZA_DJ_12B1 0.727840               RFR_S.csv
# 659       ORT_DJ_12B1 0.729013               RFR_S.csv
# 544       CRM_DJ_12T1 0.730525            RFR_S-GD.csv
# 490       PLT_DJ_12B1 0.730962      RFR_S-Clientes.csv
# 101       BYX_DJ_12B1 0.731034     LSTM_S-Clientes.csv
# 973       CRI_DJ_12B1 0.735692               SVR_S.csv
# 126       ITA_DJ_12B1 0.738372     LSTM_S-Clientes.csv
# 152       RIC_DJ_12B1 0.738497     LSTM_S-Clientes.csv
# 274       CBD_DJ_12B2 0.739123              LSTM_S.csv
# 41        ITA_DJ_12B1 0.741893  LSTM_S-Clientes-GD.csv
# 19        CBD_DJ_12B2 0.744935  LSTM_S-Clientes-GD.csv
# 736       JZR_DJ_12B1 0.745220   SVR_S-Clientes-GD.csv
# 603       ARA_DJ_12B1 0.748496               RFR_S.csv
# 842       RIC_DJ_12B1 0.748930      SVR_S-Clientes.csv
# 297       ITA_DJ_12B1 0.751674              LSTM_S.csv
# 327       RIC_DJ_12B1 0.752131              LSTM_S.csv
# 164       SZA_DJ_12B1 0.753570     LSTM_S-Clientes.csv
# 265       BQR_DJ_12B1 0.756349              LSTM_S.csv
# 524       BNR_DJ_12B1 0.756613            RFR_S-GD.csv
# 270       BVT_DJ_12B2 0.758667              LSTM_S.csv
# 67        RIC_DJ_12B1 0.758872  LSTM_S-Clientes-GD.csv
# 237       RIC_DJ_12B1 0.761622           LSTM_S-GD.csv
# 392       LCN_DJ_12B1 0.762722   RFR_S-Clientes-GD.csv
# 79        SZA_DJ_12B1 0.764623  LSTM_S-Clientes-GD.csv
# 897       GBA_DJ_12B1 0.768697            SVR_S-GD.csv
# 186       BYX_DJ_12B1 0.771513           LSTM_S-GD.csv
# 569       MRU_DJ_12B1 0.771566            RFR_S-GD.csv
# 249       SZA_DJ_12B1 0.772351           LSTM_S-GD.csv
# 841       QMD_DJ_12B1 0.773950      SVR_S-Clientes.csv
# 998       MGB_DJ_12B2 0.774044               SVR_S.csv
# 104       CBD_DJ_12B2 0.778036     LSTM_S-Clientes.csv
# 518       ARA_DJ_12B1 0.780397            RFR_S-GD.csv
# 433       ARA_DJ_12B1 0.781081      RFR_S-Clientes.csv
# 135       MGB_DJ_12B2 0.782011     LSTM_S-Clientes.csv
# 517       APL_DJ_12B1 0.783600            RFR_S-GD.csv
# 749       PCO_DJ_12B1 0.785855   SVR_S-Clientes-GD.csv
# 525       BQR_DJ_12B1 0.787188            RFR_S-GD.csv
# 247       STR_DJ_12B1 0.788947           LSTM_S-GD.csv
# 959       BVT_DJ_12B1 0.789038               SVR_S.csv
# 908       MAA_DJ_12B1 0.790437            SVR_S-GD.csv
# 50        MGB_DJ_12B2 0.792419  LSTM_S-Clientes-GD.csv
# 674       RTT_DJ_12B2 0.795270               RFR_S.csv
# 220       MGB_DJ_12B2 0.796852           LSTM_S-GD.csv
# 1028      STR_DJ_12B2 0.797547               SVR_S.csv
# 16        BYX_DJ_12B1 0.797993  LSTM_S-Clientes-GD.csv
# 591       SPX_DJ_12B1 0.798578            RFR_S-GD.csv
# 458       CRI_DJ_12B2 0.800379      RFR_S-Clientes.csv
# 484       MRU_DJ_12B1 0.804179      RFR_S-Clientes.csv
# 818       JCU_DJ_12B1 0.804896      SVR_S-Clientes.csv
# 439       BNR_DJ_12B1 0.811957      RFR_S-Clientes.csv
# 676       SGL_DJ_12T1 0.812187               RFR_S.csv
# 867       BBR_DJ_12B2 0.812403            SVR_S-GD.csv
# 399       MRU_DJ_12B1 0.813681   RFR_S-Clientes-GD.csv
# 562       LCN_DJ_12B1 0.814369            RFR_S-GD.csv
# 869       BNR_DJ_12B1 0.815154            SVR_S-GD.csv
# 267       BSA_DJ_12B2 0.817545              LSTM_S.csv
# 607       BBR_DJ_12B2 0.826940               RFR_S.csv
# 1030      SZA_DJ_12B2 0.828302               SVR_S.csv
# 807       CTR_DJ_12B1 0.829642      SVR_S-Clientes.csv
# 832       PBL_DJ_12B1 0.838391      SVR_S-Clientes.csv
# 823       MAA_DJ_12B1 0.838468      SVR_S-Clientes.csv
# 725       DST_DJ_12B2 0.840483   SVR_S-Clientes-GD.csv
# 810       DST_DJ_12B2 0.843332      SVR_S-Clientes.csv
# 584       RTT_DJ_12B2 0.843690            RFR_S-GD.csv
# 969       CJZ_DJ_12B1 0.844746               SVR_S.csv
# 848       SLD_DJ_12B1 0.850282      SVR_S-Clientes.csv
# 536       CGU_DJ_12B1 0.852213            RFR_S-GD.csv
# 699       BNR_DJ_12B1 0.852561   SVR_S-Clientes-GD.csv
# 105       CDE_DJ_12B1 0.854176     LSTM_S-Clientes.csv
# 313       MRU_DJ_12B2 0.854295              LSTM_S.csv
# 1003      MRU_DJ_12B2 0.854611               SVR_S.csv
# 819       JRC_DJ_12B1 0.855831      SVR_S-Clientes.csv
# 782       BBR_DJ_12B2 0.857826      SVR_S-Clientes.csv
# 354       BNR_DJ_12B1 0.858838   RFR_S-Clientes-GD.csv
# 20        CDE_DJ_12B1 0.860029  LSTM_S-Clientes-GD.csv
# 269       BVT_DJ_12B1 0.861446              LSTM_S.csv
# 980       DST_DJ_12B1 0.862475               SVR_S.csv
# 619       CBD_DJ_12B2 0.862982               RFR_S.csv
# 440       BQR_DJ_12B1 0.864667      RFR_S-Clientes.csv
# 271       BYX_DJ_12B1 0.866177              LSTM_S.csv
# 190       CDE_DJ_12B1 0.866889           LSTM_S-GD.csv
# 703       BVA_DJ_12T1 0.867660   SVR_S-Clientes-GD.csv
# 887       CRI_DJ_12B1 0.868958            SVR_S-GD.csv
# 558       JCU_DJ_12B1 0.869009            RFR_S-GD.csv
# 660       PBL_DJ_12B1 0.870969               RFR_S.csv
# 733       JCU_DJ_12B1 0.876077   SVR_S-Clientes-GD.csv
# 208       GBA_DJ_12B2 0.876670           LSTM_S-GD.csv
# 197       CRI_DJ_12B1 0.876753           LSTM_S-GD.csv
# 784       BNR_DJ_12B1 0.876977      SVR_S-Clientes.csv
# 726       ESP_DJ_12B1 0.877840   SVR_S-Clientes-GD.csv
# 27        CRI_DJ_12B1 0.879337  LSTM_S-Clientes-GD.csv
# 166       TBU_DJ_12B1 0.879845     LSTM_S-Clientes.csv
# 494       PRT_DJ_12B1 0.880987      RFR_S-Clientes.csv
# 111       CPX_DJ_12B2 0.881205     LSTM_S-Clientes.csv
# 388       JCU_DJ_12B1 0.882681   RFR_S-Clientes-GD.csv
# 473       JCU_DJ_12B1 0.885555      RFR_S-Clientes.csv
# 238       RTT_DJ_12B1 0.885739           LSTM_S-GD.csv
# 112       CRI_DJ_12B1 0.887431     LSTM_S-Clientes.csv
# 877       CAA_DJ_12B1 0.888746            SVR_S-GD.csv
# 163       STR_DJ_12B2 0.889456     LSTM_S-Clientes.csv
# 373       CRI_DJ_12B2 0.889779   RFR_S-Clientes-GD.csv
# 81        TBU_DJ_12B1 0.891110  LSTM_S-Clientes-GD.csv
# 894       DST_DJ_12B1 0.892318            SVR_S-GD.csv
# 248       STR_DJ_12B2 0.893905           LSTM_S-GD.csv
# 355       BQR_DJ_12B1 0.895083   RFR_S-Clientes-GD.csv
# 945       ABR_DJ_12B1 0.896745               SVR_S.csv
# 26        CPX_DJ_12B2 0.896760  LSTM_S-Clientes-GD.csv
# 256       AER_DJ_12B1 0.899263              LSTM_S.csv
# 68        RTT_DJ_12B1 0.899264  LSTM_S-Clientes-GD.csv
# 412       RIC_DJ_12B1 0.899633   RFR_S-Clientes-GD.csv
# 780       ARR_DJ_12B1 0.902817      SVR_S-Clientes.csv
# 153       RTT_DJ_12B1 0.902922     LSTM_S-Clientes.csv
# 499       RTT_DJ_12B2 0.903359      RFR_S-Clientes.csv
# 421       SPX_DJ_12B1 0.904474   RFR_S-Clientes-GD.csv
# 986       ILB_DJ_12B1 0.908206               SVR_S.csv
# 549       DST_DJ_12B1 0.911303            RFR_S-GD.csv
# 579       PRT_DJ_12B1 0.911774            RFR_S-GD.csv
# 506       SPX_DJ_12B1 0.912229      RFR_S-Clientes.csv
# 251       TBU_DJ_12B1 0.913347           LSTM_S-GD.csv
# 913       MRO_DJ_12B1 0.915165            SVR_S-GD.csv
# 348       ARA_DJ_12B1 0.918812   RFR_S-Clientes-GD.csv
# 196       CPX_DJ_12B2 0.919786           LSTM_S-GD.csv
# 409       PRT_DJ_12B1 0.919894   RFR_S-Clientes-GD.csv
# 296       ILB_DJ_12B1 0.928292              LSTM_S.csv
# 414       RTT_DJ_12B2 0.930289   RFR_S-Clientes-GD.csv
# 235       PTS_DJ_12B1 0.930791           LSTM_S-GD.csv
# 366       CGU_DJ_12B1 0.930899   RFR_S-Clientes-GD.csv
# 280       CJZ_DJ_12B2 0.932514              LSTM_S.csv
# 78        STR_DJ_12B2 0.933762  LSTM_S-Clientes-GD.csv
# 746       ORT_DJ_12B1 0.935189   SVR_S-Clientes-GD.csv
# 582       RIC_DJ_12B1 0.935889            RFR_S-GD.csv
# 568       MRO_DJ_12B1 0.939039            RFR_S-GD.csv
# 38        GBA_DJ_12B2 0.942008  LSTM_S-Clientes-GD.csv
# 683       STR_DJ_12B2 0.942728               RFR_S.csv
# 738       MAA_DJ_12B1 0.947102   SVR_S-Clientes-GD.csv
# 123       GBA_DJ_12B2 0.949479     LSTM_S-Clientes.csv
# 215       JTB_DJ_12B1 0.950091           LSTM_S-GD.csv
# 497       RIC_DJ_12B1 0.951107      RFR_S-Clientes.csv
# 910       MGB_DJ_12B2 0.951268            SVR_S-GD.csv
# 451       CGU_DJ_12B1 0.952958      RFR_S-Clientes.csv
# 648       JTB_DJ_12B1 0.953465               RFR_S.csv
# 276       CGD_DJ_11T7 0.953671              LSTM_S.csv
# 939       SZA_DJ_12B1 0.957221            SVR_S-GD.csv
# 571       ORT_DJ_12B1 0.957489            RFR_S-GD.csv
# 846       SGL_DJ_12T1 0.961808      SVR_S-Clientes.csv
# 900       ILB_DJ_12B1 0.965117            SVR_S-GD.csv
# 65        PTS_DJ_12B1 0.968303  LSTM_S-Clientes-GD.csv
# 601       AER_DJ_12B1 0.969687               RFR_S.csv
# 311       MRO_DJ_12B1 0.970499              LSTM_S.csv
# 685       SZA_DJ_12B2 0.975019               RFR_S.csv
# 653       MGB_DJ_12B2 0.975026               RFR_S.csv
# 283       CRI_DJ_12B1 0.983497              LSTM_S.csv
# 734       JRC_DJ_12B1 0.984799   SVR_S-Clientes-GD.csv
# 954       BNR_DJ_12B1 0.986220               SVR_S.csv
# 150       PTS_DJ_12B1 0.987154     LSTM_S-Clientes.csv
# 338       STR_DJ_12B2 0.989419              LSTM_S.csv
# 851       SPX_DJ_12B1 0.989819      SVR_S-Clientes.csv
# 303       JTB_DJ_12B1 0.998646              LSTM_S.csv
# 252       TBU_DJ_12B2 0.999869           LSTM_S-GD.csv
# 459       CRM_DJ_12T1 0.999907      RFR_S-Clientes.csv
# 633       CTR_DJ_12B1 1.002057               RFR_S.csv
# 872       BSA_DJ_12B2 1.005157            SVR_S-GD.csv
# 642       ITA_DJ_12B1 1.007852               RFR_S.csv
# 486       ORT_DJ_12B1 1.008440      RFR_S-Clientes.csv
# 325       PTS_DJ_12B1 1.008527              LSTM_S.csv
# 722       CTR_DJ_12B1 1.010635   SVR_S-Clientes-GD.csv
# 628       CRI_DJ_12B1 1.013950               RFR_S.csv
# 865       ARR_DJ_12B1 1.014897            SVR_S-GD.csv
# 542       CRI_DJ_12B1 1.020161            RFR_S-GD.csv
# 70        SBT_DJ_12B1 1.021883  LSTM_S-Clientes-GD.csv
# 167       TBU_DJ_12B2 1.024744     LSTM_S-Clientes.csv
# 446       BYX_DJ_12B1 1.024773      RFR_S-Clientes.csv
# 330       SBT_DJ_12B1 1.025888              LSTM_S.csv
# 335       SPE_DJ_12B2 1.026157              LSTM_S.csv
# 825       MGB_DJ_12B2 1.030373      SVR_S-Clientes.csv
# 1025      SPE_DJ_12B2 1.030913               SVR_S.csv
# 225       MRU_DJ_12B2 1.032313           LSTM_S-GD.csv
# 401       ORT_DJ_12B1 1.033248   RFR_S-Clientes-GD.csv
# 449       CBD_DJ_12B2 1.034462      RFR_S-Clientes.csv
# 342       TBU_DJ_12B2 1.035706              LSTM_S.csv
# 754       PRT_DJ_12B1 1.035733   SVR_S-Clientes-GD.csv
# 347       APL_DJ_12B1 1.041853   RFR_S-Clientes-GD.csv
# 744       MRU_DJ_12B1 1.042284   SVR_S-Clientes-GD.csv
# 956       BSA_DJ_12B1 1.042432               SVR_S.csv
# 886       CPX_DJ_12B2 1.042916            SVR_S-GD.csv
# 432       APL_DJ_12B1 1.043057      RFR_S-Clientes.csv
# 924       PRT_DJ_12B1 1.043575            SVR_S-GD.csv
# 82        TBU_DJ_12B2 1.044265  LSTM_S-Clientes-GD.csv
# 55        MRU_DJ_12B2 1.046375  LSTM_S-Clientes-GD.csv
# 245       SPE_DJ_12B2 1.048052           LSTM_S-GD.csv
# 963       CBD_DJ_12B1 1.048190               SVR_S.csv
# 160       SPE_DJ_12B2 1.049028     LSTM_S-Clientes.csv
# 831       ORT_DJ_12B1 1.049198      SVR_S-Clientes.csv
# 155       SBT_DJ_12B1 1.049619     LSTM_S-Clientes.csv
# 778       ARA_DJ_12B1 1.050904      SVR_S-Clientes.csv
# 873       BVA_DJ_12T1 1.052211            SVR_S-GD.csv
# 614       BVT_DJ_12B1 1.052548               RFR_S.csv
# 23        CJZ_DJ_12B1 1.052893  LSTM_S-Clientes-GD.csv
# 578       PRI_DJ_12B1 1.054432            RFR_S-GD.csv
# 1032      TBU_DJ_12B2 1.054693               SVR_S.csv
# 130       JTB_DJ_12B1 1.054862     LSTM_S-Clientes.csv
# 572       PBL_DJ_12B1 1.055199            RFR_S-GD.csv
# 140       MRU_DJ_12B2 1.056566     LSTM_S-Clientes.csv
# 193       CJZ_DJ_12B1 1.056614           LSTM_S-GD.csv
# 194       CJZ_DJ_12B2 1.058319           LSTM_S-GD.csv
# 535       CDE_DJ_12B1 1.060586            RFR_S-GD.csv
# 240       SBT_DJ_12B1 1.061019           LSTM_S-GD.csv
# 567       MNT_DJ_12T1 1.061363            RFR_S-GD.csv
# 108       CJZ_DJ_12B1 1.061465     LSTM_S-Clientes.csv
# 839       PRT_DJ_12B1 1.061624      SVR_S-Clientes.csv
# 493       PRI_DJ_12B1 1.062273      RFR_S-Clientes.csv
# 75        SPE_DJ_12B2 1.063516  LSTM_S-Clientes-GD.csv
# 397       MNT_DJ_12T1 1.067940   RFR_S-Clientes-GD.csv
# 930       SBT_DJ_12B1 1.069834            SVR_S-GD.csv
# 372       CRI_DJ_12B1 1.071198   RFR_S-Clientes-GD.csv
# 450       CDE_DJ_12B1 1.071235      RFR_S-Clientes.csv
# 364       CBD_DJ_12B2 1.071606   RFR_S-Clientes-GD.csv
# 534       CBD_DJ_12B2 1.072635            RFR_S-GD.csv
# 757       RIC_DJ_12B1 1.073669   SVR_S-Clientes-GD.csv
# 482       MNT_DJ_12T1 1.073763      RFR_S-Clientes.csv
# 593       STR_DJ_12B2 1.081292            RFR_S-GD.csv
# 273       CBD_DJ_12B1 1.081693              LSTM_S.csv
# 610       BQR_DJ_12B1 1.083715               RFR_S.csv
# 457       CRI_DJ_12B1 1.089320      RFR_S-Clientes.csv
# 658       MRU_DJ_12B2 1.091031               RFR_S.csv
# 255       ABR_DJ_12B1 1.097466              LSTM_S.csv
# 574       PCO_DJ_12B1 1.097522            RFR_S-GD.csv
# 398       MRO_DJ_12B1 1.099894   RFR_S-Clientes-GD.csv
# 307       MGB_DJ_12B1 1.101761              LSTM_S.csv
# 365       CDE_DJ_12B1 1.102301   RFR_S-Clientes-GD.csv
# 508       STR_DJ_12B2 1.102839      RFR_S-Clientes.csv
# 697       BBR_DJ_12B2 1.103710   SVR_S-Clientes-GD.csv
# 408       PRI_DJ_12B1 1.105334   RFR_S-Clientes-GD.csv
# 555       ILB_DJ_12B1 1.109140            RFR_S-GD.csv
# 374       CRM_DJ_12T1 1.109356   RFR_S-Clientes-GD.csv
# 700       BQR_DJ_12B1 1.109941   SVR_S-Clientes-GD.csv
# 103       CBD_DJ_12B1 1.110196     LSTM_S-Clientes.csv
# 828       MRO_DJ_12B1 1.114024      SVR_S-Clientes.csv
# 188       CBD_DJ_12B1 1.114346           LSTM_S-GD.csv
# 984       GBA_DJ_12B2 1.115895               SVR_S.csv
# 34        DST_DJ_12B1 1.116007  LSTM_S-Clientes-GD.csv
# 618       CBD_DJ_12B1 1.124647               RFR_S.csv
# 1001      MRO_DJ_12B1 1.127364               SVR_S.csv
# 24        CJZ_DJ_12B2 1.132815  LSTM_S-Clientes-GD.csv
# 483       MRO_DJ_12B1 1.132987      RFR_S-Clientes.csv
# 635       DST_DJ_12B1 1.134952               RFR_S.csv
# 696       BBR_DJ_12B1 1.137424   SVR_S-Clientes-GD.csv
# 18        CBD_DJ_12B1 1.141173  LSTM_S-Clientes-GD.csv
# 109       CJZ_DJ_12B2 1.142394     LSTM_S-Clientes.csv
# 264       BNR_DJ_12B1 1.152067              LSTM_S.csv
# 423       STR_DJ_12B2 1.153297   RFR_S-Clientes-GD.csv
# 879       CBD_DJ_12B2 1.159871            SVR_S-GD.csv
# 489       PCO_DJ_12B1 1.160581      RFR_S-Clientes.csv
# 361       BYX_DJ_12B1 1.161581   RFR_S-Clientes-GD.csv
# 204       DST_DJ_12B1 1.164155           LSTM_S-GD.csv
# 487       PBL_DJ_12B1 1.165531      RFR_S-Clientes.csv
# 49        MGB_DJ_12B1 1.170966  LSTM_S-Clientes-GD.csv
# 266       BSA_DJ_12B1 1.171291              LSTM_S.csv
# 880       CDE_DJ_12B1 1.172734            SVR_S-GD.csv
# 891       CTL_DJ_12B1 1.180792            SVR_S-GD.csv
# 464       DST_DJ_12B1 1.184579      RFR_S-Clientes.csv
# 379       DST_DJ_12B1 1.185106   RFR_S-Clientes-GD.csv
# 402       PBL_DJ_12B1 1.187207   RFR_S-Clientes-GD.csv
# 820       JTB_DJ_12B1 1.191592      SVR_S-Clientes.csv
# 595       SZA_DJ_12B2 1.193689            RFR_S-GD.csv
# 45        JTB_DJ_12B1 1.200789  LSTM_S-Clientes-GD.csv
# 1031      TBU_DJ_12B1 1.210776               SVR_S.csv
# 134       MGB_DJ_12B1 1.210892     LSTM_S-Clientes.csv
# 647       JRC_DJ_12B1 1.213313               RFR_S.csv
# 531       BYX_DJ_12B1 1.214456            RFR_S-GD.csv
# 119       DST_DJ_12B1 1.217241     LSTM_S-Clientes.csv
# 822       LCN_DJ_12B1 1.219025      SVR_S-Clientes.csv
# 928       RTT_DJ_12B1 1.221159            SVR_S-GD.csv
# 1015      PTS_DJ_12B1 1.222209               SVR_S.csv
# 149       PRT_DJ_12B1 1.223500     LSTM_S-Clientes.csv
# 871       BSA_DJ_12B1 1.225117            SVR_S-GD.csv
# 533       CBD_DJ_12B1 1.228457            RFR_S-GD.csv
# 997       MGB_DJ_12B1 1.229036               SVR_S.csv
# 693       ARA_DJ_12B1 1.234215   SVR_S-Clientes-GD.csv
# 624       CJZ_DJ_12B1 1.242181               RFR_S.csv
# 181       BSA_DJ_12B1 1.260248           LSTM_S-GD.csv
# 816       ITA_DJ_12B1 1.261461      SVR_S-Clientes.csv
# 565       MGB_DJ_12B2 1.262579            RFR_S-GD.csv
# 760       SBT_DJ_12B1 1.264593   SVR_S-Clientes-GD.csv
# 470       ILB_DJ_12B1 1.264902      RFR_S-Clientes.csv
# 522       BBR_DJ_12B2 1.265444            RFR_S-GD.csv
# 328       RTT_DJ_12B1 1.269377              LSTM_S.csv
# 707       CAA_DJ_12B1 1.270637   SVR_S-Clientes-GD.csv
# 655       MNT_DJ_12T1 1.270837               RFR_S.csv
# 675       SBT_DJ_12B1 1.271814               RFR_S.csv
# 809       DST_DJ_12B1 1.278663      SVR_S-Clientes.csv
# 404       PCO_DJ_12B1 1.281808   RFR_S-Clientes-GD.csv
# 759       RTT_DJ_12B2 1.283295   SVR_S-Clientes-GD.csv
# 821       JZR_DJ_12B1 1.284988      SVR_S-Clientes.csv
# 425       SZA_DJ_12B2 1.286010   RFR_S-Clientes-GD.csv
# 557       ITO_DJ_12B1 1.286637            RFR_S-GD.csv
# 448       CBD_DJ_12B1 1.286895      RFR_S-Clientes.csv
# 742       MNT_DJ_12T1 1.289831   SVR_S-Clientes-GD.csv
# 824       MGB_DJ_12B1 1.293557      SVR_S-Clientes.csv
# 735       JTB_DJ_12B1 1.298827   SVR_S-Clientes-GD.csv
# 279       CJZ_DJ_12B1 1.303084              LSTM_S.csv
# 870       BQR_DJ_12B1 1.309090            SVR_S-GD.csv
# 743       MRO_DJ_12B1 1.311902   SVR_S-Clientes-GD.csv
# 96        BSA_DJ_12B1 1.316641     LSTM_S-Clientes.csv
# 586       SGL_DJ_12T1 1.320147            RFR_S-GD.csv
# 916       ORT_DJ_12B1 1.323232            SVR_S-GD.csv
# 546       CTL_DJ_12B1 1.326064            RFR_S-GD.csv
# 219       MGB_DJ_12B1 1.326196           LSTM_S-GD.csv
# 363       CBD_DJ_12B1 1.327508   RFR_S-Clientes-GD.csv
# 732       ITO_DJ_12B1 1.327592   SVR_S-Clientes-GD.csv
# 829       MRU_DJ_12B1 1.327916      SVR_S-Clientes.csv
# 275       CDE_DJ_12B1 1.331774              LSTM_S.csv
# 592       STR_DJ_12B1 1.331785            RFR_S-GD.csv
# 682       STR_DJ_12B1 1.332715               RFR_S.csv
# 324       PRT_DJ_12B1 1.339530              LSTM_S.csv
# 290       DST_DJ_12B1 1.339808              LSTM_S.csv
# 727       GBA_DJ_12B1 1.342352   SVR_S-Clientes-GD.csv
# 673       RTT_DJ_12B1 1.342742               RFR_S.csv
# 385       ILB_DJ_12B1 1.342931   RFR_S-Clientes-GD.csv
# 792       CAA_DJ_12B1 1.344310      SVR_S-Clientes.csv
# 583       RTT_DJ_12B1 1.344502            RFR_S-GD.csv
# 475       JTB_DJ_12B1 1.345380      RFR_S-Clientes.csv
# 670       PTS_DJ_12B1 1.345500               RFR_S.csv
# 201       CTL_DJ_12B1 1.346985           LSTM_S-GD.csv
# 935       SPE_DJ_12B2 1.360688            SVR_S-GD.csv
# 656       MRO_DJ_12B1 1.364242               RFR_S.csv
# 639       GBA_DJ_12B2 1.367235               RFR_S.csv
# 352       BBR_DJ_12B2 1.367257   RFR_S-Clientes-GD.csv
# 498       RTT_DJ_12B1 1.371737      RFR_S-Clientes.csv
# 560       JTB_DJ_12B1 1.378486            RFR_S-GD.csv
# 600       ABR_DJ_12B1 1.379933               RFR_S.csv
# 413       RTT_DJ_12B1 1.383707   RFR_S-Clientes-GD.csv
# 368       CJZ_DJ_12B1 1.386919   RFR_S-Clientes-GD.csv
# 641       ILB_DJ_12B1 1.393108               RFR_S.csv
# 31        CTL_DJ_12B1 1.395028  LSTM_S-Clientes-GD.csv
# 11        BSA_DJ_12B1 1.397205  LSTM_S-Clientes-GD.csv
# 547       CTR_DJ_12B1 1.397616            RFR_S-GD.csv
# 453       CJZ_DJ_12B1 1.400314      RFR_S-Clientes.csv
# 965       CDE_DJ_12B1 1.404955               SVR_S.csv
# 390       JTB_DJ_12B1 1.410755   RFR_S-Clientes-GD.csv
# 510       SZA_DJ_12B2 1.412217      RFR_S-Clientes.csv
# 472       ITO_DJ_12B1 1.414634      RFR_S-Clientes.csv
# 815       ILB_DJ_12B1 1.418012      SVR_S-Clientes.csv
# 740       MGB_DJ_12B2 1.418631   SVR_S-Clientes-GD.csv
# 116       CTL_DJ_12B1 1.420327     LSTM_S-Clientes.csv
# 501       SGL_DJ_12T1 1.423832      RFR_S-Clientes.csv
# 1018      RTT_DJ_12B1 1.426234               SVR_S.csv
# 387       ITO_DJ_12B1 1.433045   RFR_S-Clientes-GD.csv
# 541       CPX_DJ_12B2 1.433695            RFR_S-GD.csv
# 620       CDE_DJ_12B1 1.434207               RFR_S.csv
# 747       PBL_DJ_12B1 1.436197   SVR_S-Clientes-GD.csv
# 785       BQR_DJ_12B1 1.439411      SVR_S-Clientes.csv
# 730       ILB_DJ_12B1 1.439630   SVR_S-Clientes-GD.csv
# 609       BNR_DJ_12B1 1.443299               RFR_S.csv
# 437       BBR_DJ_12B2 1.467362      RFR_S-Clientes.csv
# 977       CTL_DJ_12B1 1.467406               SVR_S.csv
# 480       MGB_DJ_12B2 1.478480      RFR_S-Clientes.csv
# 777       APL_DJ_12B1 1.479573      SVR_S-Clientes.csv
# 395       MGB_DJ_12B2 1.479919   RFR_S-Clientes-GD.csv
# 64        PRT_DJ_12B1 1.482459  LSTM_S-Clientes-GD.csv
# 416       SGL_DJ_12T1 1.484900   RFR_S-Clientes-GD.csv
# 853       STR_DJ_12B2 1.488848      SVR_S-Clientes.csv
# 812       GBA_DJ_12B1 1.490799      SVR_S-Clientes.csv
# 991       JPS_DJ_12B2 1.497440               SVR_S.csv
# 761       SGL_DJ_12T1 1.499446   SVR_S-Clientes-GD.csv
# 462       CTR_DJ_12B1 1.516950      RFR_S-Clientes.csv
# 422       STR_DJ_12B1 1.519370   RFR_S-Clientes-GD.csv
# 695       ARR_DJ_12B1 1.519919   SVR_S-Clientes-GD.csv
# 371       CPX_DJ_12B2 1.523719   RFR_S-Clientes-GD.csv
# 755       PTS_DJ_12B1 1.529258   SVR_S-Clientes-GD.csv
# 376       CTL_DJ_12B1 1.532789   RFR_S-Clientes-GD.csv
# 905       JTB_DJ_12B1 1.543180            SVR_S-GD.csv
# 967       CGU_DJ_12B1 1.545584               SVR_S.csv
# 377       CTR_DJ_12B1 1.549779   RFR_S-Clientes-GD.csv
# 234       PRT_DJ_12B1 1.555632           LSTM_S-GD.csv
# 461       CTL_DJ_12B1 1.581084      RFR_S-Clientes.csv
# 901       ITA_DJ_12B1 1.587583            SVR_S-GD.csv
# 845       SBT_DJ_12B1 1.589164      SVR_S-Clientes.csv
# 507       STR_DJ_12B1 1.597164      RFR_S-Clientes.csv
# 468       GBA_DJ_12B2 1.603797      RFR_S-Clientes.csv
# 843       RTT_DJ_12B1 1.625360      SVR_S-Clientes.csv
# 570       MRU_DJ_12B2 1.625815            RFR_S-GD.csv
# 611       BSA_DJ_12B1 1.641139               RFR_S.csv
# 383       GBA_DJ_12B2 1.655401   RFR_S-Clientes-GD.csv
# 527       BSA_DJ_12B2 1.655585            RFR_S-GD.csv
# 768       STR_DJ_12B2 1.666959   SVR_S-Clientes-GD.csv
# 850       SPE_DJ_12B2 1.674402      SVR_S-Clientes.csv
# 456       CPX_DJ_12B2 1.677193      RFR_S-Clientes.csv
# 294       GBA_DJ_12B2 1.680567              LSTM_S.csv
# 854       SZA_DJ_12B1 1.682851      SVR_S-Clientes.csv
# 798       CJZ_DJ_12B1 1.690219      SVR_S-Clientes.csv
# 972       CPX_DJ_12B2 1.697307               SVR_S.csv
# 357       BSA_DJ_12B2 1.703712   RFR_S-Clientes-GD.csv
# 940       SZA_DJ_12B2 1.707887            SVR_S-GD.csv
# 692       APL_DJ_12B1 1.716778   SVR_S-Clientes-GD.csv
# 898       GBA_DJ_12B2 1.720676            SVR_S-GD.csv
# 301       JPS_DJ_12B2 1.721755              LSTM_S.csv
# 442       BSA_DJ_12B2 1.722825      RFR_S-Clientes.csv
# 855       SZA_DJ_12B2 1.727026      SVR_S-Clientes.csv
# 597       TBU_DJ_12B2 1.734855            RFR_S-GD.csv
# 817       ITO_DJ_12B1 1.744122      SVR_S-Clientes.csv
# 710       CDE_DJ_12B1 1.756797   SVR_S-Clientes-GD.csv
# 580       PTS_DJ_12B1 1.758684            RFR_S-GD.csv
# 941       TBU_DJ_12B1 1.761009            SVR_S-GD.csv
# 925       PTS_DJ_12B1 1.763291            SVR_S-GD.csv
# 495       PTS_DJ_12B1 1.763773      RFR_S-Clientes.csv
# 758       RTT_DJ_12B1 1.777299   SVR_S-Clientes-GD.csv
# 687       TBU_DJ_12B2 1.778072               RFR_S.csv
# 410       PTS_DJ_12B1 1.779266   RFR_S-Clientes-GD.csv
# 652       MGB_DJ_12B1 1.790058               RFR_S.csv
# 553       GBA_DJ_12B2 1.798552            RFR_S-GD.csv
# 971       CPX_DJ_12B1 1.799539               SVR_S.csv
# 938       STR_DJ_12B2 1.802498            SVR_S-GD.csv
# 883       CJZ_DJ_12B1 1.804054            SVR_S-GD.csv
# 806       CTL_DJ_12B1 1.808273      SVR_S-Clientes.csv
# 858       TXR_DJ_12B1 1.821500      SVR_S-Clientes.csv
# 621       CGD_DJ_11T7 1.827980               RFR_S.csv
# 585       SBT_DJ_12B1 1.830407            RFR_S-GD.csv
# 594       SZA_DJ_12B1 1.832663            RFR_S-GD.csv
# 282       CPX_DJ_12B2 1.837575              LSTM_S.csv
# 287       CTL_DJ_12B1 1.839126              LSTM_S.csv
# 827       MNT_DJ_12T1 1.839870      SVR_S-Clientes.csv
# 795       CDE_DJ_12B1 1.840526      SVR_S-Clientes.csv
# 876       BYX_DJ_12B1 1.845419            SVR_S-GD.csv
# 942       TBU_DJ_12B2 1.857616            SVR_S-GD.csv
# 686       TBU_DJ_12B1 1.863457               RFR_S.csv
# 341       TBU_DJ_12B1 1.864505              LSTM_S.csv
# 713       CJZ_DJ_12B1 1.866146   SVR_S-Clientes-GD.csv
# 632       CTL_DJ_12B1 1.867713               RFR_S.csv
# 862       APL_DJ_12B1 1.867854            SVR_S-GD.csv
# 512       TBU_DJ_12B2 1.871081      RFR_S-Clientes.csv
# 801       CPX_DJ_12B2 1.891311      SVR_S-Clientes.csv
# 596       TBU_DJ_12B1 1.892701            RFR_S-GD.csv
# 441       BSA_DJ_12B1 1.905529      RFR_S-Clientes.csv
# 626       CPX_DJ_12B1 1.912249               RFR_S.csv
# 526       BSA_DJ_12B1 1.924230            RFR_S-GD.csv
# 511       TBU_DJ_12B1 1.946534      RFR_S-Clientes.csv
# 765       SPE_DJ_12B2 1.958681   SVR_S-Clientes-GD.csv
# 702       BSA_DJ_12B2 1.981679   SVR_S-Clientes-GD.csv
# 427       TBU_DJ_12B2 1.981728   RFR_S-Clientes-GD.csv
# 426       TBU_DJ_12B1 1.992317   RFR_S-Clientes-GD.csv
# 424       SZA_DJ_12B1 2.016643   RFR_S-Clientes-GD.csv
# 509       SZA_DJ_12B1 2.016877      RFR_S-Clientes.csv
# 479       MGB_DJ_12B1 2.030394      RFR_S-Clientes.csv
# 556       ITA_DJ_12B1 2.040432            RFR_S-GD.csv
# 356       BSA_DJ_12B1 2.048443   RFR_S-Clientes-GD.csv
# 500       SBT_DJ_12B1 2.049223      RFR_S-Clientes.csv
# 538       CJZ_DJ_12B1 2.087311            RFR_S-GD.csv
# 564       MGB_DJ_12B1 2.091017            RFR_S-GD.csv
# 680       SPE_DJ_12B2 2.115177               RFR_S.csv
# 716       CPX_DJ_12B2 2.117641   SVR_S-Clientes-GD.csv
# 415       SBT_DJ_12B1 2.119543   RFR_S-Clientes-GD.csv
# 787       BSA_DJ_12B2 2.119835      SVR_S-Clientes.csv
# 878       CBD_DJ_12B1 2.146338            SVR_S-GD.csv
# 394       MGB_DJ_12B1 2.152226   RFR_S-Clientes-GD.csv
# 773       TXR_DJ_12B1 2.162182   SVR_S-Clientes-GD.csv
# 471       ITA_DJ_12B1 2.165794      RFR_S-Clientes.csv
# 769       SZA_DJ_12B1 2.170288   SVR_S-Clientes-GD.csv
# 281       CPX_DJ_12B1 2.170832              LSTM_S.csv
# 856       TBU_DJ_12B1 2.204813      SVR_S-Clientes.csv
# 646       JPS_DJ_12B2 2.221882               RFR_S.csv
# 386       ITA_DJ_12B1 2.240147   RFR_S-Clientes-GD.csv
# 791       BYX_DJ_12B1 2.247524      SVR_S-Clientes.csv
# 840       PTS_DJ_12B1 2.258169      SVR_S-Clientes.csv
# 794       CBD_DJ_12B2 2.274657      SVR_S-Clientes.csv
# 813       GBA_DJ_12B2 2.298619      SVR_S-Clientes.csv
# 622       CGU_DJ_12B1 2.315883               RFR_S.csv
# 770       SZA_DJ_12B2 2.349548   SVR_S-Clientes-GD.csv
# 627       CPX_DJ_12B2 2.369551               RFR_S.csv
# 625       CJZ_DJ_12B2 2.391698               RFR_S.csv
# 277       CGU_DJ_12B1 2.396500              LSTM_S.csv
# 590       SPE_DJ_12B2 2.408663            RFR_S-GD.csv
# 1014      PRT_DJ_12B1 2.472324               SVR_S.csv
# 539       CJZ_DJ_12B2 2.482330            RFR_S-GD.csv
# 505       SPE_DJ_12B2 2.485298      RFR_S-Clientes.csv
# 400       MRU_DJ_12B2 2.530632   RFR_S-Clientes-GD.csv
# 728       GBA_DJ_12B2 2.533638   SVR_S-Clientes-GD.csv
# 857       TBU_DJ_12B2 2.535061      SVR_S-Clientes.csv
# 767       STR_DJ_12B1 2.549146   SVR_S-Clientes-GD.csv
# 300       JPS_DJ_12B1 2.568425              LSTM_S.csv
# 909       MGB_DJ_12B1 2.604845            SVR_S-GD.csv
# 420       SPE_DJ_12B2 2.614179   RFR_S-Clientes-GD.csv
# 915       MRU_DJ_12B2 2.629194            SVR_S-GD.csv
# 612       BSA_DJ_12B2 2.640915               RFR_S.csv
# 721       CTL_DJ_12B1 2.702451   SVR_S-Clientes-GD.csv
# 852       STR_DJ_12B1 2.718296      SVR_S-Clientes.csv
# 990       JPS_DJ_12B1 2.723145               SVR_S.csv
# 454       CJZ_DJ_12B2 2.765283      RFR_S-Clientes.csv
# 771       TBU_DJ_12B1 2.793794   SVR_S-Clientes-GD.csv
# 884       CJZ_DJ_12B2 2.822522            SVR_S-GD.csv
# 485       MRU_DJ_12B2 2.881528      RFR_S-Clientes.csv
# 369       CJZ_DJ_12B2 2.931089   RFR_S-Clientes-GD.csv
# 772       TBU_DJ_12B2 2.951591   SVR_S-Clientes-GD.csv
# 709       CBD_DJ_12B2 2.973176   SVR_S-Clientes-GD.csv
# 724       DST_DJ_12B1 2.982090   SVR_S-Clientes-GD.csv
# 706       BYX_DJ_12B1 3.086454   SVR_S-Clientes-GD.csv
# 645       JPS_DJ_12B1 3.408004               RFR_S.csv
# 830       MRU_DJ_12B2 3.463989      SVR_S-Clientes.csv
# 701       BSA_DJ_12B1 3.520881   SVR_S-Clientes-GD.csv
# 739       MGB_DJ_12B1 3.838934   SVR_S-Clientes-GD.csv
# 786       BSA_DJ_12B1 3.969697      SVR_S-Clientes.csv
# 708       CBD_DJ_12B1 4.105472   SVR_S-Clientes-GD.csv
# 793       CBD_DJ_12B1 4.181791      SVR_S-Clientes.csv
# 745       MRU_DJ_12B2 4.182625   SVR_S-Clientes-GD.csv
# 731       ITA_DJ_12B1 4.324734   SVR_S-Clientes-GD.csv
# 717       CRI_DJ_12B1 4.376129   SVR_S-Clientes-GD.csv
# 799       CJZ_DJ_12B2 4.500386      SVR_S-Clientes.csv
# 714       CJZ_DJ_12B2 4.619070   SVR_S-Clientes-GD.csv
# 802       CRI_DJ_12B1 5.176634      SVR_S-Clientes.csv
# 669       PRT_DJ_12B1 5.688786               RFR_S.csv

# %%
top3_pivot
# Out:
#                         Melhor Segundo Melhor Terceiro Melhor
# Trafo
# ABR_DJ_12B1      LSTM_S-GD.csv   RFR_S-GD.csv    SVR_S-GD.csv
# AER_DJ_12B1       RFR_S-GD.csv   SVR_S-GD.csv   LSTM_S-GD.csv
# APL_DJ_12B1      LSTM_S-GD.csv      RFR_S.csv       SVR_S.csv
# ARA_DJ_12B1      LSTM_S-GD.csv      SVR_S.csv      LSTM_S.csv
# ARN_DJ_12B1      LSTM_S-GD.csv      SVR_S.csv      LSTM_S.csv
# ARR_DJ_12B1      LSTM_S-GD.csv     LSTM_S.csv       SVR_S.csv
# BBR_DJ_12B1      LSTM_S-GD.csv   RFR_S-GD.csv       SVR_S.csv
# BBR_DJ_12B2      LSTM_S-GD.csv      SVR_S.csv      LSTM_S.csv
# BJC_DJ_12B1      LSTM_S-GD.csv     LSTM_S.csv       SVR_S.csv
# BNR_DJ_12B1      LSTM_S-GD.csv   RFR_S-GD.csv    SVR_S-GD.csv
# BQR_DJ_12B1      LSTM_S-GD.csv      SVR_S.csv      LSTM_S.csv
# BSA_DJ_12B1          SVR_S.csv     LSTM_S.csv    SVR_S-GD.csv
# BSA_DJ_12B2          SVR_S.csv  LSTM_S-GD.csv      LSTM_S.csv
# BVA_DJ_12T1          SVR_S.csv     LSTM_S.csv       RFR_S.csv
# BVT_DJ_12B1      LSTM_S-GD.csv   RFR_S-GD.csv    SVR_S-GD.csv
# BVT_DJ_12B2      LSTM_S-GD.csv   RFR_S-GD.csv    SVR_S-GD.csv
# BYX_DJ_12B1          SVR_S.csv      RFR_S.csv   LSTM_S-GD.csv
# CAA_DJ_12B1         LSTM_S.csv  LSTM_S-GD.csv       SVR_S.csv
# CBD_DJ_12B1          SVR_S.csv     LSTM_S.csv   LSTM_S-GD.csv
# CBD_DJ_12B2      LSTM_S-GD.csv      SVR_S.csv      LSTM_S.csv
# CDE_DJ_12B1      LSTM_S-GD.csv   RFR_S-GD.csv    SVR_S-GD.csv
# CGD_DJ_11T7          SVR_S.csv     LSTM_S.csv       RFR_S.csv
# CGU_DJ_12B1      LSTM_S-GD.csv   SVR_S-GD.csv    RFR_S-GD.csv
# CGU_DJ_12B2      LSTM_S-GD.csv      SVR_S.csv    RFR_S-GD.csv
# CJZ_DJ_12B1          SVR_S.csv  LSTM_S-GD.csv       RFR_S.csv
# CJZ_DJ_12B2          SVR_S.csv     LSTM_S.csv   LSTM_S-GD.csv
# CPX_DJ_12B1      LSTM_S-GD.csv   SVR_S-GD.csv    RFR_S-GD.csv
# CPX_DJ_12B2      LSTM_S-GD.csv   SVR_S-GD.csv    RFR_S-GD.csv
# CRI_DJ_12B1          SVR_S.csv   SVR_S-GD.csv   LSTM_S-GD.csv
# CRI_DJ_12B2      LSTM_S-GD.csv     LSTM_S.csv       RFR_S.csv
# CRM_DJ_12T1         LSTM_S.csv      SVR_S.csv   LSTM_S-GD.csv
# CTE_DJ_12B1      LSTM_S-GD.csv   SVR_S-GD.csv       SVR_S.csv
# CTL_DJ_12B1       SVR_S-GD.csv   RFR_S-GD.csv   LSTM_S-GD.csv
# CTR_DJ_12B1          SVR_S.csv   SVR_S-GD.csv   LSTM_S-GD.csv
# DIN_DJ_12B1          SVR_S.csv  LSTM_S-GD.csv    SVR_S-GD.csv
# DST_DJ_12B1          SVR_S.csv   SVR_S-GD.csv    RFR_S-GD.csv
# DST_DJ_12B2       RFR_S-GD.csv     LSTM_S.csv   LSTM_S-GD.csv
# ESP_DJ_12B1      LSTM_S-GD.csv   SVR_S-GD.csv       SVR_S.csv
# GBA_DJ_12B1          SVR_S.csv     LSTM_S.csv   LSTM_S-GD.csv
# GBA_DJ_12B2      LSTM_S-GD.csv      SVR_S.csv       RFR_S.csv
# IBR_DJ_12B1      LSTM_S-GD.csv      SVR_S.csv      LSTM_S.csv
# ILB_DJ_12B1      LSTM_S-GD.csv      SVR_S.csv      LSTM_S.csv
# ITA_DJ_12B1          SVR_S.csv  LSTM_S-GD.csv      LSTM_S.csv
# ITO_DJ_12B1      LSTM_S-GD.csv      SVR_S.csv    SVR_S-GD.csv
# JCU_DJ_12B1      LSTM_S-GD.csv      SVR_S.csv      LSTM_S.csv
# JPS_DJ_12B1         LSTM_S.csv      SVR_S.csv       RFR_S.csv
# JPS_DJ_12B2          SVR_S.csv     LSTM_S.csv       RFR_S.csv
# JRC_DJ_12B1         LSTM_S.csv  LSTM_S-GD.csv       SVR_S.csv
# JTB_DJ_12B1          SVR_S.csv  LSTM_S-GD.csv       RFR_S.csv
# JZR_DJ_12B1      LSTM_S-GD.csv      SVR_S.csv    SVR_S-GD.csv
# LCN_DJ_12B1          SVR_S.csv     LSTM_S.csv   LSTM_S-GD.csv
# MAA_DJ_12B1         LSTM_S.csv   RFR_S-GD.csv   LSTM_S-GD.csv
# MGB_DJ_12B1         LSTM_S.csv      SVR_S.csv   LSTM_S-GD.csv
# MGB_DJ_12B2         LSTM_S.csv      SVR_S.csv   LSTM_S-GD.csv
# MLT_DJ_12B1         LSTM_S.csv      SVR_S.csv   LSTM_S-GD.csv
# MNT_DJ_12T1      LSTM_S-GD.csv      SVR_S.csv    SVR_S-GD.csv
# MRO_DJ_12B1      LSTM_S-GD.csv   SVR_S-GD.csv    RFR_S-GD.csv
# MRU_DJ_12B1          SVR_S.csv     LSTM_S.csv   LSTM_S-GD.csv
# MRU_DJ_12B2         LSTM_S.csv      SVR_S.csv   LSTM_S-GD.csv
# ORT_DJ_12B1      LSTM_S-GD.csv      SVR_S.csv      LSTM_S.csv
# PBL_DJ_12B1         LSTM_S.csv      SVR_S.csv   LSTM_S-GD.csv
# PCI_DJ_12B1      LSTM_S-GD.csv   SVR_S-GD.csv    RFR_S-GD.csv
# PCO_DJ_12B1          SVR_S.csv     LSTM_S.csv   LSTM_S-GD.csv
# PLT_DJ_12B1          SVR_S.csv     LSTM_S.csv   LSTM_S-GD.csv
# PLU_DJ_12B1          SVR_S.csv     LSTM_S.csv       RFR_S.csv
# PLU_DJ_12B1_D_P      RFR_S.csv      SVR_S.csv      LSTM_S.csv
# PLV_DJ_12B1      LSTM_S-GD.csv   SVR_S-GD.csv    RFR_S-GD.csv
# POC_DJ_12B1      LSTM_S-GD.csv   RFR_S-GD.csv       SVR_S.csv
# PRI_DJ_12B1      LSTM_S-GD.csv      SVR_S.csv      LSTM_S.csv
# PRT_DJ_12B1       RFR_S-GD.csv   SVR_S-GD.csv      LSTM_S.csv
# PTS_DJ_12B1      LSTM_S-GD.csv     LSTM_S.csv       SVR_S.csv
# QMD_DJ_12B1          SVR_S.csv   SVR_S-GD.csv      LSTM_S.csv
# RIC_DJ_12B1          SVR_S.csv      RFR_S.csv    SVR_S-GD.csv
# RTT_DJ_12B1      LSTM_S-GD.csv   SVR_S-GD.csv      LSTM_S.csv
# RTT_DJ_12B2          SVR_S.csv     LSTM_S.csv   LSTM_S-GD.csv
# SBT_DJ_12B1          SVR_S.csv     LSTM_S.csv   LSTM_S-GD.csv
# SGL_DJ_12T1          SVR_S.csv     LSTM_S.csv   LSTM_S-GD.csv
# SJC_DJ_12T1      LSTM_S-GD.csv      SVR_S.csv    RFR_S-GD.csv
# SLD_DJ_12B1      LSTM_S-GD.csv   RFR_S-GD.csv       SVR_S.csv
# SLZ_DJ_12B1          SVR_S.csv  LSTM_S-GD.csv       RFR_S.csv
# SPE_DJ_12B2         LSTM_S.csv      SVR_S.csv   LSTM_S-GD.csv
# SPX_DJ_12B1          SVR_S.csv     LSTM_S.csv   LSTM_S-GD.csv
# STR_DJ_12B1          SVR_S.csv     LSTM_S.csv    SVR_S-GD.csv
# STR_DJ_12B2          SVR_S.csv  LSTM_S-GD.csv       RFR_S.csv
# SZA_DJ_12B1          SVR_S.csv     LSTM_S.csv       RFR_S.csv
# SZA_DJ_12B2         LSTM_S.csv  LSTM_S-GD.csv       SVR_S.csv
# TBU_DJ_12B1      LSTM_S-GD.csv      SVR_S.csv    SVR_S-GD.csv
# TBU_DJ_12B2      LSTM_S-GD.csv     LSTM_S.csv       SVR_S.csv
# TXR_DJ_12B1          SVR_S.csv  LSTM_S-GD.csv      LSTM_S.csv
# URN_DJ_12B1      LSTM_S-GD.csv     LSTM_S.csv       SVR_S.csv
