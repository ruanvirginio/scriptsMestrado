# %%
import os
import pandas as pd
pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', '{:.6f}'.format)

arquivos_csv = [f for f in os.listdir() if f.endswith('.csv')]

dataframes = []

for arquivo in arquivos_csv:
    df = pd.read_csv(arquivo, sep=';') 
    df['Arquivo'] = arquivo 
    df = df[['Trafo', 'RMSE', 'MAE', 'Arquivo']]
    dataframes.append(df)

df_concatenado = pd.concat(dataframes, ignore_index=True)

# Encontrando o arquivo com menor RMSE para cada trafo
min_rmse_files = df_concatenado.loc[df_concatenado.groupby("Trafo")["RMSE"].idxmin(), "Arquivo"]

# Contando quantas vezes cada arquivo aparece como menor RMSE
arquivo_counts = min_rmse_files.value_counts()

print('Qtd melhor resultado:')
print(arquivo_counts)

# Encontrando os dois menores RMSE para cada trafo
df_sorted = df_concatenado.sort_values(["Trafo", "RMSE"])
second_min_files = df_sorted.groupby("Trafo").nth(1)["Arquivo"]

# Contando quantas vezes cada arquivo aparece como segundo menor RMSE
second_min_counts = second_min_files.value_counts()

print('\nQtd segundo melhor resultado:')
print(second_min_counts)

# Encontrando os tres menores RMSE para cada trafo
third_min_files = df_sorted.groupby("Trafo").nth(2)["Arquivo"]

# Contando quantas vezes cada arquivo aparece como terceiro menor RMSE
third_min_counts = third_min_files.value_counts()

print('\nQtd terceiro melhor resultado:')
print(third_min_counts)

# Pega os 3 melhores RMSE para cada trafo
top3_files = df_sorted.groupby("Trafo").head(3)

top3_pivot = top3_files.assign(Rank=top3_files.groupby("Trafo").cumcount()+1).pivot(index="Trafo", columns="Rank", values="Arquivo")
top3_pivot.columns = ["Melhor", "Segundo Melhor", "Terceiro Melhor"]

top3_pivot = top3_pivot.reset_index()  # Transforma o índice em coluna
top3_pivot.columns = ['Trafo', 'Melhor', 'Segundo Melhor', 'Terceiro Melhor']  # Renomeia as colunas

top3_pivot
# Out:
# Qtd melhor resultado:
# Arquivo
# SVR_S.csv                 32
# LSTM_S-GD.csv             19
# LSTM_S-Clientes.csv       18
# LSTM_S.csv                11
# LSTM_S-Clientes-GD.csv     4
# RFR_S-GD.csv               2
# RFR_S-Clientes.csv         2
# SVR_S-GD.csv               1
# RFR_S.csv                  1
# Name: count, dtype: int64
#
# Qtd segundo melhor resultado:
# Arquivo
# LSTM_S-GD.csv             20
# LSTM_S.csv                17
# LSTM_S-Clientes.csv       16
# LSTM_S-Clientes-GD.csv    16
# SVR_S.csv                 10
# SVR_S-GD.csv               5
# RFR_S-GD.csv               3
# RFR_S.csv                  2
# RFR_S-Clientes-GD.csv      1
# Name: count, dtype: int64
#
# Qtd terceiro melhor resultado:
# Arquivo
# LSTM_S-Clientes-GD.csv    28
# LSTM_S-GD.csv             22
# LSTM_S-Clientes.csv       18
# RFR_S.csv                  7
# LSTM_S.csv                 6
# SVR_S-GD.csv               3
# RFR_S-Clientes.csv         2
# SVR_S.csv                  1
# RFR_S-GD.csv               1
# SVR_S-Clientes.csv         1
# RFR_S-Clientes-GD.csv      1
# Name: count, dtype: int64
#               Trafo                  Melhor          Segundo Melhor  \
# 0       ABR_DJ_12B1           LSTM_S-GD.csv     LSTM_S-Clientes.csv
# 1       AER_DJ_12B1            RFR_S-GD.csv            SVR_S-GD.csv
# 2       APL_DJ_12B1     LSTM_S-Clientes.csv           LSTM_S-GD.csv
# 3       ARA_DJ_12B1     LSTM_S-Clientes.csv           LSTM_S-GD.csv
# 4       ARN_DJ_12B1     LSTM_S-Clientes.csv           LSTM_S-GD.csv
# 5       ARR_DJ_12B1           LSTM_S-GD.csv     LSTM_S-Clientes.csv
# 6       BBR_DJ_12B1      RFR_S-Clientes.csv     LSTM_S-Clientes.csv
# 7       BBR_DJ_12B2  LSTM_S-Clientes-GD.csv           LSTM_S-GD.csv
# 8       BJC_DJ_12B1           LSTM_S-GD.csv     LSTM_S-Clientes.csv
# 9       BNR_DJ_12B1  LSTM_S-Clientes-GD.csv     LSTM_S-Clientes.csv
# 10      BQR_DJ_12B1  LSTM_S-Clientes-GD.csv     LSTM_S-Clientes.csv
# 11      BSA_DJ_12B1               SVR_S.csv              LSTM_S.csv
# 12      BSA_DJ_12B2               SVR_S.csv     LSTM_S-Clientes.csv
# 13      BVA_DJ_12T1               SVR_S.csv              LSTM_S.csv
# 14      BVT_DJ_12B1           LSTM_S-GD.csv     LSTM_S-Clientes.csv
# 15      BVT_DJ_12B2  LSTM_S-Clientes-GD.csv           LSTM_S-GD.csv
# 16      BYX_DJ_12B1               SVR_S.csv               RFR_S.csv
# 17      CAA_DJ_12B1     LSTM_S-Clientes.csv  LSTM_S-Clientes-GD.csv
# 18      CBD_DJ_12B1               SVR_S.csv              LSTM_S.csv
# 19      CBD_DJ_12B2           LSTM_S-GD.csv               SVR_S.csv
# 20      CDE_DJ_12B1     LSTM_S-Clientes.csv  LSTM_S-Clientes-GD.csv
# 21      CGD_DJ_11T7               SVR_S.csv              LSTM_S.csv
# 22      CGU_DJ_12B1     LSTM_S-Clientes.csv           LSTM_S-GD.csv
# 23      CGU_DJ_12B2           LSTM_S-GD.csv     LSTM_S-Clientes.csv
# 24      CJZ_DJ_12B1               SVR_S.csv  LSTM_S-Clientes-GD.csv
# 25      CJZ_DJ_12B2               SVR_S.csv              LSTM_S.csv
# 26      CPX_DJ_12B1           LSTM_S-GD.csv     LSTM_S-Clientes.csv
# 27      CPX_DJ_12B2     LSTM_S-Clientes.csv  LSTM_S-Clientes-GD.csv
# 28      CRI_DJ_12B1               SVR_S.csv            SVR_S-GD.csv
# 29      CRI_DJ_12B2     LSTM_S-Clientes.csv           LSTM_S-GD.csv
# 30      CRM_DJ_12T1              LSTM_S.csv               SVR_S.csv
# 31      CTE_DJ_12B1     LSTM_S-Clientes.csv           LSTM_S-GD.csv
# 32      CTL_DJ_12B1            SVR_S-GD.csv            RFR_S-GD.csv
# 33      CTR_DJ_12B1               SVR_S.csv            SVR_S-GD.csv
# 34      DIN_DJ_12B1               SVR_S.csv           LSTM_S-GD.csv
# 35      DST_DJ_12B1               SVR_S.csv            SVR_S-GD.csv
# 36      DST_DJ_12B2            RFR_S-GD.csv   RFR_S-Clientes-GD.csv
# 37      ESP_DJ_12B1           LSTM_S-GD.csv  LSTM_S-Clientes-GD.csv
# 38      GBA_DJ_12B1               SVR_S.csv              LSTM_S.csv
# 39      GBA_DJ_12B2           LSTM_S-GD.csv  LSTM_S-Clientes-GD.csv
# 40      IBR_DJ_12B1     LSTM_S-Clientes.csv           LSTM_S-GD.csv
# 41      ILB_DJ_12B1     LSTM_S-Clientes.csv           LSTM_S-GD.csv
# 42      ITA_DJ_12B1               SVR_S.csv           LSTM_S-GD.csv
# 43      ITO_DJ_12B1           LSTM_S-GD.csv  LSTM_S-Clientes-GD.csv
# 44      JCU_DJ_12B1           LSTM_S-GD.csv               SVR_S.csv
# 45      JPS_DJ_12B1              LSTM_S.csv               SVR_S.csv
# 46      JPS_DJ_12B2               SVR_S.csv              LSTM_S.csv
# 47      JRC_DJ_12B1              LSTM_S.csv           LSTM_S-GD.csv
# 48      JTB_DJ_12B1               SVR_S.csv           LSTM_S-GD.csv
# 49      JZR_DJ_12B1           LSTM_S-GD.csv     LSTM_S-Clientes.csv
# 50      LCN_DJ_12B1               SVR_S.csv              LSTM_S.csv
# 51      MAA_DJ_12B1              LSTM_S.csv            RFR_S-GD.csv
# 52      MGB_DJ_12B1              LSTM_S.csv  LSTM_S-Clientes-GD.csv
# 53      MGB_DJ_12B2              LSTM_S.csv               SVR_S.csv
# 54      MLT_DJ_12B1              LSTM_S.csv               SVR_S.csv
# 55      MNT_DJ_12T1     LSTM_S-Clientes.csv  LSTM_S-Clientes-GD.csv
# 56      MRO_DJ_12B1           LSTM_S-GD.csv     LSTM_S-Clientes.csv
# 57      MRU_DJ_12B1               SVR_S.csv              LSTM_S.csv
# 58      MRU_DJ_12B2              LSTM_S.csv               SVR_S.csv
# 59      ORT_DJ_12B1           LSTM_S-GD.csv  LSTM_S-Clientes-GD.csv
# 60      PBL_DJ_12B1              LSTM_S.csv               SVR_S.csv
# 61      PCI_DJ_12B1     LSTM_S-Clientes.csv           LSTM_S-GD.csv
# 62      PCO_DJ_12B1               SVR_S.csv              LSTM_S.csv
# 63      PLT_DJ_12B1               SVR_S.csv              LSTM_S.csv
# 64      PLU_DJ_12B1               SVR_S.csv              LSTM_S.csv
# 65  PLU_DJ_12B1_D_P               RFR_S.csv               SVR_S.csv
# 66      PLV_DJ_12B1     LSTM_S-Clientes.csv           LSTM_S-GD.csv
# 67      POC_DJ_12B1     LSTM_S-Clientes.csv           LSTM_S-GD.csv
# 68      PRI_DJ_12B1     LSTM_S-Clientes.csv           LSTM_S-GD.csv
# 69      PRT_DJ_12B1      RFR_S-Clientes.csv            RFR_S-GD.csv
# 70      PTS_DJ_12B1           LSTM_S-GD.csv  LSTM_S-Clientes-GD.csv
# 71      QMD_DJ_12B1               SVR_S.csv            SVR_S-GD.csv
# 72      RIC_DJ_12B1               SVR_S.csv               RFR_S.csv
# 73      RTT_DJ_12B1           LSTM_S-GD.csv  LSTM_S-Clientes-GD.csv
# 74      RTT_DJ_12B2               SVR_S.csv              LSTM_S.csv
# 75      SBT_DJ_12B1               SVR_S.csv  LSTM_S-Clientes-GD.csv
# 76      SGL_DJ_12T1               SVR_S.csv              LSTM_S.csv
# 77      SJC_DJ_12T1           LSTM_S-GD.csv     LSTM_S-Clientes.csv
# 78      SLD_DJ_12B1           LSTM_S-GD.csv  LSTM_S-Clientes-GD.csv
# 79      SLZ_DJ_12B1               SVR_S.csv     LSTM_S-Clientes.csv
# 80      SPE_DJ_12B2              LSTM_S.csv               SVR_S.csv
# 81      SPX_DJ_12B1               SVR_S.csv              LSTM_S.csv
# 82      STR_DJ_12B1               SVR_S.csv              LSTM_S.csv
# 83      STR_DJ_12B2               SVR_S.csv     LSTM_S-Clientes.csv
# 84      SZA_DJ_12B1               SVR_S.csv              LSTM_S.csv
# 85      SZA_DJ_12B2              LSTM_S.csv           LSTM_S-GD.csv
# 86      TBU_DJ_12B1     LSTM_S-Clientes.csv  LSTM_S-Clientes-GD.csv
# 87      TBU_DJ_12B2           LSTM_S-GD.csv     LSTM_S-Clientes.csv
# 88      TXR_DJ_12B1               SVR_S.csv           LSTM_S-GD.csv
# 89      URN_DJ_12B1     LSTM_S-Clientes.csv  LSTM_S-Clientes-GD.csv
#
#            Terceiro Melhor
# 0   LSTM_S-Clientes-GD.csv
# 1       RFR_S-Clientes.csv
# 2   LSTM_S-Clientes-GD.csv
# 3                SVR_S.csv
# 4   LSTM_S-Clientes-GD.csv
# 5   LSTM_S-Clientes-GD.csv
# 6   LSTM_S-Clientes-GD.csv
# 7      LSTM_S-Clientes.csv
# 8   LSTM_S-Clientes-GD.csv
# 9            LSTM_S-GD.csv
# 10           LSTM_S-GD.csv
# 11            SVR_S-GD.csv
# 12           LSTM_S-GD.csv
# 13               RFR_S.csv
# 14  LSTM_S-Clientes-GD.csv
# 15     LSTM_S-Clientes.csv
# 16     LSTM_S-Clientes.csv
# 17              LSTM_S.csv
# 18     LSTM_S-Clientes.csv
# 19              LSTM_S.csv
# 20           LSTM_S-GD.csv
# 21               RFR_S.csv
# 22  LSTM_S-Clientes-GD.csv
# 23  LSTM_S-Clientes-GD.csv
# 24           LSTM_S-GD.csv
# 25           LSTM_S-GD.csv
# 26  LSTM_S-Clientes-GD.csv
# 27           LSTM_S-GD.csv
# 28           LSTM_S-GD.csv
# 29  LSTM_S-Clientes-GD.csv
# 30           LSTM_S-GD.csv
# 31  LSTM_S-Clientes-GD.csv
# 32           LSTM_S-GD.csv
# 33     LSTM_S-Clientes.csv
# 34            SVR_S-GD.csv
# 35            RFR_S-GD.csv
# 36      RFR_S-Clientes.csv
# 37     LSTM_S-Clientes.csv
# 38  LSTM_S-Clientes-GD.csv
# 39     LSTM_S-Clientes.csv
# 40  LSTM_S-Clientes-GD.csv
# 41  LSTM_S-Clientes-GD.csv
# 42     LSTM_S-Clientes.csv
# 43     LSTM_S-Clientes.csv
# 44     LSTM_S-Clientes.csv
# 45               RFR_S.csv
# 46               RFR_S.csv
# 47  LSTM_S-Clientes-GD.csv
# 48               RFR_S.csv
# 49  LSTM_S-Clientes-GD.csv
# 50           LSTM_S-GD.csv
# 51  LSTM_S-Clientes-GD.csv
# 52     LSTM_S-Clientes.csv
# 53     LSTM_S-Clientes.csv
# 54  LSTM_S-Clientes-GD.csv
# 55           LSTM_S-GD.csv
# 56  LSTM_S-Clientes-GD.csv
# 57           LSTM_S-GD.csv
# 58           LSTM_S-GD.csv
# 59     LSTM_S-Clientes.csv
# 60           LSTM_S-GD.csv
# 61  LSTM_S-Clientes-GD.csv
# 62           LSTM_S-GD.csv
# 63      SVR_S-Clientes.csv
# 64               RFR_S.csv
# 65              LSTM_S.csv
# 66  LSTM_S-Clientes-GD.csv
# 67  LSTM_S-Clientes-GD.csv
# 68  LSTM_S-Clientes-GD.csv
# 69   RFR_S-Clientes-GD.csv
# 70     LSTM_S-Clientes.csv
# 71              LSTM_S.csv
# 72            SVR_S-GD.csv
# 73     LSTM_S-Clientes.csv
# 74           LSTM_S-GD.csv
# 75              LSTM_S.csv
# 76           LSTM_S-GD.csv
# 77  LSTM_S-Clientes-GD.csv
# 78     LSTM_S-Clientes.csv
# 79  LSTM_S-Clientes-GD.csv
# 80           LSTM_S-GD.csv
# 81  LSTM_S-Clientes-GD.csv
# 82     LSTM_S-Clientes.csv
# 83           LSTM_S-GD.csv
# 84               RFR_S.csv
# 85  LSTM_S-Clientes-GD.csv
# 86           LSTM_S-GD.csv
# 87              LSTM_S.csv
# 88     LSTM_S-Clientes.csv
# 89           LSTM_S-GD.csv

# %%
df_concatenado.to_csv('Resumo_Resultados.csv', sep=';', index=False)

# %%
top15_GD = {
    "TRAFO": [
        "PTS_DJ_12B1", "JTB_DJ_12B1", "CTR_DJ_12B1", "CJZ_DJ_12B1", "SZA_DJ_12B2",
        "CBD_DJ_12B1", "SBT_DJ_12B1", "SZA_DJ_12B1", "ABR_DJ_12B1", "PBL_DJ_12B1",
        "PRT_DJ_12B1", "CTL_DJ_12B1", "GBA_DJ_12B2", "SGL_DJ_12T1", "MGB_DJ_12B2"
    ],
    "PotenciaAcumulada": [
        18.11019000000007, 14.390984999999995, 12.482614999999988, 11.970245000000013, 11.226030000000003,
        10.83012999999999, 10.829459999999996, 9.407430000000025, 8.66734999999998, 8.325459999999996,
        8.020819999999983, 8.012269999999988, 7.1918599999999895, 7.179259999999999, 7.032454999999988
    ]
}

# %%
df_concatenado[["Modelo", "Features"]] = df_concatenado["Arquivo"].str.split("_", n=1, expand=True)
df_concatenado = df_concatenado.drop("Arquivo", axis=1)

# %%
ver_GD_top3 = top3_pivot[top3_pivot['Trafo'].isin(top15_GD['TRAFO'])]
ver_GD_top3
# Out:
#           Trafo              Melhor          Segundo Melhor  \
# 0   ABR_DJ_12B1       LSTM_S-GD.csv     LSTM_S-Clientes.csv
# 18  CBD_DJ_12B1           SVR_S.csv              LSTM_S.csv
# 24  CJZ_DJ_12B1           SVR_S.csv  LSTM_S-Clientes-GD.csv
# 32  CTL_DJ_12B1        SVR_S-GD.csv            RFR_S-GD.csv
# 33  CTR_DJ_12B1           SVR_S.csv            SVR_S-GD.csv
# 39  GBA_DJ_12B2       LSTM_S-GD.csv  LSTM_S-Clientes-GD.csv
# 48  JTB_DJ_12B1           SVR_S.csv           LSTM_S-GD.csv
# 53  MGB_DJ_12B2          LSTM_S.csv               SVR_S.csv
# 60  PBL_DJ_12B1          LSTM_S.csv               SVR_S.csv
# 69  PRT_DJ_12B1  RFR_S-Clientes.csv            RFR_S-GD.csv
# 70  PTS_DJ_12B1       LSTM_S-GD.csv  LSTM_S-Clientes-GD.csv
# 75  SBT_DJ_12B1           SVR_S.csv  LSTM_S-Clientes-GD.csv
# 76  SGL_DJ_12T1           SVR_S.csv              LSTM_S.csv
# 84  SZA_DJ_12B1           SVR_S.csv              LSTM_S.csv
# 85  SZA_DJ_12B2          LSTM_S.csv           LSTM_S-GD.csv
#
#            Terceiro Melhor
# 0   LSTM_S-Clientes-GD.csv
# 18     LSTM_S-Clientes.csv
# 24           LSTM_S-GD.csv
# 32           LSTM_S-GD.csv
# 33     LSTM_S-Clientes.csv
# 39     LSTM_S-Clientes.csv
# 48               RFR_S.csv
# 53     LSTM_S-Clientes.csv
# 60           LSTM_S-GD.csv
# 69   RFR_S-Clientes-GD.csv
# 70     LSTM_S-Clientes.csv
# 75              LSTM_S.csv
# 76           LSTM_S-GD.csv
# 84               RFR_S.csv
# 85  LSTM_S-Clientes-GD.csv

# %%
ver_GD = df_concatenado[df_concatenado['Trafo'].isin(top15_GD['TRAFO'])]
ver_GD.sort_values('RMSE')
# Out:
#             Trafo     RMSE      MAE Modelo           Features
# 170   ABR_DJ_12B1 0.418541 0.332519   LSTM           S-GD.csv
# 85    ABR_DJ_12B1 0.422110 0.332588   LSTM     S-Clientes.csv
# 0     ABR_DJ_12B1 0.429187 0.337620   LSTM  S-Clientes-GD.csv
# 1021  SGL_DJ_12T1 0.439723 0.330265    SVR              S.csv
# 331   SGL_DJ_12T1 0.468452 0.366336   LSTM              S.csv
# 241   SGL_DJ_12T1 0.480352 0.384842   LSTM           S-GD.csv
# 71    SGL_DJ_12T1 0.483016 0.384324   LSTM  S-Clientes-GD.csv
# 156   SGL_DJ_12T1 0.488769 0.389246   LSTM     S-Clientes.csv
# 315   PBL_DJ_12B1 0.518959 0.381494   LSTM              S.csv
# 515   ABR_DJ_12B1 0.532231 0.429310    RFR           S-GD.csv
# 1029  SZA_DJ_12B1 0.534548 0.399850    SVR              S.csv
# 1005  PBL_DJ_12B1 0.539311 0.400658    SVR              S.csv
# 339   SZA_DJ_12B1 0.550107 0.426206   LSTM              S.csv
# 860   ABR_DJ_12B1 0.553723 0.450760    SVR           S-GD.csv
# 978   CTR_DJ_12B1 0.566904 0.431480    SVR              S.csv
# 775   ABR_DJ_12B1 0.578495 0.468833    SVR     S-Clientes.csv
# 345   ABR_DJ_12B1 0.584535 0.481702    RFR  S-Clientes-GD.csv
# 430   ABR_DJ_12B1 0.608382 0.508777    RFR     S-Clientes.csv
# 931   SGL_DJ_12T1 0.611360 0.507464    SVR           S-GD.csv
# 227   PBL_DJ_12B1 0.636639 0.486558   LSTM           S-GD.csv
# 142   PBL_DJ_12B1 0.640775 0.491936   LSTM     S-Clientes.csv
# 892   CTR_DJ_12B1 0.647049 0.510462    SVR           S-GD.csv
# 117   CTR_DJ_12B1 0.647422 0.499872   LSTM     S-Clientes.csv
# 202   CTR_DJ_12B1 0.652528 0.501687   LSTM           S-GD.csv
# 993   JTB_DJ_12B1 0.666807 0.492025    SVR              S.csv
# 57    PBL_DJ_12B1 0.682046 0.537606   LSTM  S-Clientes-GD.csv
# 690   ABR_DJ_12B1 0.685124 0.556264    SVR  S-Clientes-GD.csv
# 340   SZA_DJ_12B2 0.691652 0.511720   LSTM              S.csv
# 32    CTR_DJ_12B1 0.692208 0.526113   LSTM  S-Clientes-GD.csv
# 917   PBL_DJ_12B1 0.696667 0.518688    SVR           S-GD.csv
# 1020  SBT_DJ_12B1 0.706918 0.554212    SVR              S.csv
# 250   SZA_DJ_12B2 0.707129 0.524613   LSTM           S-GD.csv
# 308   MGB_DJ_12B2 0.707403 0.445208   LSTM              S.csv
# 80    SZA_DJ_12B2 0.713964 0.525597   LSTM  S-Clientes-GD.csv
# 165   SZA_DJ_12B2 0.716307 0.529926   LSTM     S-Clientes.csv
# 288   CTR_DJ_12B1 0.723228 0.584055   LSTM              S.csv
# 684   SZA_DJ_12B1 0.727840 0.573395    RFR              S.csv
# 164   SZA_DJ_12B1 0.753570 0.607273   LSTM     S-Clientes.csv
# 79    SZA_DJ_12B1 0.764623 0.613349   LSTM  S-Clientes-GD.csv
# 249   SZA_DJ_12B1 0.772351 0.627400   LSTM           S-GD.csv
# 998   MGB_DJ_12B2 0.774044 0.520554    SVR              S.csv
# 135   MGB_DJ_12B2 0.782011 0.562141   LSTM     S-Clientes.csv
# 50    MGB_DJ_12B2 0.792419 0.576349   LSTM  S-Clientes-GD.csv
# 220   MGB_DJ_12B2 0.796852 0.574418   LSTM           S-GD.csv
# 676   SGL_DJ_12T1 0.812187 0.616638    RFR              S.csv
# 1030  SZA_DJ_12B2 0.828302 0.623723    SVR              S.csv
# 807   CTR_DJ_12B1 0.829642 0.653195    SVR     S-Clientes.csv
# 832   PBL_DJ_12B1 0.838391 0.661620    SVR     S-Clientes.csv
# 969   CJZ_DJ_12B1 0.844746 0.638272    SVR              S.csv
# 660   PBL_DJ_12B1 0.870969 0.706329    RFR              S.csv
# 208   GBA_DJ_12B2 0.876670 0.681990   LSTM           S-GD.csv
# 494   PRT_DJ_12B1 0.880987 0.671965    RFR     S-Clientes.csv
# 945   ABR_DJ_12B1 0.896745 0.711847    SVR              S.csv
# 579   PRT_DJ_12B1 0.911774 0.697848    RFR           S-GD.csv
# 409   PRT_DJ_12B1 0.919894 0.714576    RFR  S-Clientes-GD.csv
# 235   PTS_DJ_12B1 0.930791 0.675180   LSTM           S-GD.csv
# 38    GBA_DJ_12B2 0.942008 0.730848   LSTM  S-Clientes-GD.csv
# 123   GBA_DJ_12B2 0.949479 0.745201   LSTM     S-Clientes.csv
# 215   JTB_DJ_12B1 0.950091 0.769801   LSTM           S-GD.csv
# 910   MGB_DJ_12B2 0.951268 0.709728    SVR           S-GD.csv
# 648   JTB_DJ_12B1 0.953465 0.732110    RFR              S.csv
# 939   SZA_DJ_12B1 0.957221 0.755637    SVR           S-GD.csv
# 846   SGL_DJ_12T1 0.961808 0.750167    SVR     S-Clientes.csv
# 65    PTS_DJ_12B1 0.968303 0.747428   LSTM  S-Clientes-GD.csv
# 685   SZA_DJ_12B2 0.975019 0.740306    RFR              S.csv
# 653   MGB_DJ_12B2 0.975026 0.748574    RFR              S.csv
# 150   PTS_DJ_12B1 0.987154 0.768960   LSTM     S-Clientes.csv
# 303   JTB_DJ_12B1 0.998646 0.776981   LSTM              S.csv
# 633   CTR_DJ_12B1 1.002057 0.779616    RFR              S.csv
# 325   PTS_DJ_12B1 1.008527 0.774105   LSTM              S.csv
# 722   CTR_DJ_12B1 1.010635 0.780028    SVR  S-Clientes-GD.csv
# 70    SBT_DJ_12B1 1.021883 0.786366   LSTM  S-Clientes-GD.csv
# 330   SBT_DJ_12B1 1.025888 0.856710   LSTM              S.csv
# 825   MGB_DJ_12B2 1.030373 0.782888    SVR     S-Clientes.csv
# 754   PRT_DJ_12B1 1.035733 0.846819    SVR  S-Clientes-GD.csv
# 924   PRT_DJ_12B1 1.043575 0.844656    SVR           S-GD.csv
# 963   CBD_DJ_12B1 1.048190 0.806181    SVR              S.csv
# 155   SBT_DJ_12B1 1.049619 0.856124   LSTM     S-Clientes.csv
# 23    CJZ_DJ_12B1 1.052893 0.827390   LSTM  S-Clientes-GD.csv
# 130   JTB_DJ_12B1 1.054862 0.892839   LSTM     S-Clientes.csv
# 572   PBL_DJ_12B1 1.055199 0.833045    RFR           S-GD.csv
# 193   CJZ_DJ_12B1 1.056614 0.827513   LSTM           S-GD.csv
# 240   SBT_DJ_12B1 1.061019 0.877570   LSTM           S-GD.csv
# 108   CJZ_DJ_12B1 1.061465 0.834558   LSTM     S-Clientes.csv
# 839   PRT_DJ_12B1 1.061624 0.873655    SVR     S-Clientes.csv
# 930   SBT_DJ_12B1 1.069834 0.811700    SVR           S-GD.csv
# 273   CBD_DJ_12B1 1.081693 0.769327   LSTM              S.csv
# 255   ABR_DJ_12B1 1.097466 0.952425   LSTM              S.csv
# 103   CBD_DJ_12B1 1.110196 0.824312   LSTM     S-Clientes.csv
# 188   CBD_DJ_12B1 1.114346 0.822665   LSTM           S-GD.csv
# 984   GBA_DJ_12B2 1.115895 0.894800    SVR              S.csv
# 618   CBD_DJ_12B1 1.124647 0.891202    RFR              S.csv
# 18    CBD_DJ_12B1 1.141173 0.854346   LSTM  S-Clientes-GD.csv
# 487   PBL_DJ_12B1 1.165531 0.913857    RFR     S-Clientes.csv
# 891   CTL_DJ_12B1 1.180792 0.917767    SVR           S-GD.csv
# 402   PBL_DJ_12B1 1.187207 0.932167    RFR  S-Clientes-GD.csv
# 820   JTB_DJ_12B1 1.191592 0.940368    SVR     S-Clientes.csv
# 595   SZA_DJ_12B2 1.193689 0.981565    RFR           S-GD.csv
# 45    JTB_DJ_12B1 1.200789 1.045383   LSTM  S-Clientes-GD.csv
# 1015  PTS_DJ_12B1 1.222209 0.971872    SVR              S.csv
# 149   PRT_DJ_12B1 1.223500 1.088492   LSTM     S-Clientes.csv
# 533   CBD_DJ_12B1 1.228457 0.958015    RFR           S-GD.csv
# 624   CJZ_DJ_12B1 1.242181 0.996923    RFR              S.csv
# 565   MGB_DJ_12B2 1.262579 1.052923    RFR           S-GD.csv
# 760   SBT_DJ_12B1 1.264593 1.054665    SVR  S-Clientes-GD.csv
# 675   SBT_DJ_12B1 1.271814 1.032900    RFR              S.csv
# 425   SZA_DJ_12B2 1.286010 1.085985    RFR  S-Clientes-GD.csv
# 448   CBD_DJ_12B1 1.286895 1.003360    RFR     S-Clientes.csv
# 735   JTB_DJ_12B1 1.298827 1.077917    SVR  S-Clientes-GD.csv
# 279   CJZ_DJ_12B1 1.303084 1.021518   LSTM              S.csv
# 586   SGL_DJ_12T1 1.320147 1.015883    RFR           S-GD.csv
# 546   CTL_DJ_12B1 1.326064 1.055374    RFR           S-GD.csv
# 363   CBD_DJ_12B1 1.327508 0.974006    RFR  S-Clientes-GD.csv
# 324   PRT_DJ_12B1 1.339530 0.981559   LSTM              S.csv
# 475   JTB_DJ_12B1 1.345380 1.088626    RFR     S-Clientes.csv
# 670   PTS_DJ_12B1 1.345500 1.082724    RFR              S.csv
# 201   CTL_DJ_12B1 1.346985 1.121589   LSTM           S-GD.csv
# 639   GBA_DJ_12B2 1.367235 1.133733    RFR              S.csv
# 560   JTB_DJ_12B1 1.378486 1.119200    RFR           S-GD.csv
# 600   ABR_DJ_12B1 1.379933 1.149840    RFR              S.csv
# 368   CJZ_DJ_12B1 1.386919 1.142146    RFR  S-Clientes-GD.csv
# 31    CTL_DJ_12B1 1.395028 1.201132   LSTM  S-Clientes-GD.csv
# 547   CTR_DJ_12B1 1.397616 1.086236    RFR           S-GD.csv
# 453   CJZ_DJ_12B1 1.400314 1.132185    RFR     S-Clientes.csv
# 390   JTB_DJ_12B1 1.410755 1.133670    RFR  S-Clientes-GD.csv
# 510   SZA_DJ_12B2 1.412217 1.197062    RFR     S-Clientes.csv
# 740   MGB_DJ_12B2 1.418631 1.158028    SVR  S-Clientes-GD.csv
# 116   CTL_DJ_12B1 1.420327 1.240668   LSTM     S-Clientes.csv
# 501   SGL_DJ_12T1 1.423832 1.078687    RFR     S-Clientes.csv
# 747   PBL_DJ_12B1 1.436197 1.200316    SVR  S-Clientes-GD.csv
# 977   CTL_DJ_12B1 1.467406 1.097599    SVR              S.csv
# 480   MGB_DJ_12B2 1.478480 1.236799    RFR     S-Clientes.csv
# 395   MGB_DJ_12B2 1.479919 1.244806    RFR  S-Clientes-GD.csv
# 64    PRT_DJ_12B1 1.482459 1.373006   LSTM  S-Clientes-GD.csv
# 416   SGL_DJ_12T1 1.484900 1.134566    RFR  S-Clientes-GD.csv
# 761   SGL_DJ_12T1 1.499446 1.195709    SVR  S-Clientes-GD.csv
# 462   CTR_DJ_12B1 1.516950 1.179470    RFR     S-Clientes.csv
# 755   PTS_DJ_12B1 1.529258 1.209482    SVR  S-Clientes-GD.csv
# 376   CTL_DJ_12B1 1.532789 1.218108    RFR  S-Clientes-GD.csv
# 905   JTB_DJ_12B1 1.543180 1.273938    SVR           S-GD.csv
# 377   CTR_DJ_12B1 1.549779 1.206394    RFR  S-Clientes-GD.csv
# 234   PRT_DJ_12B1 1.555632 1.451747   LSTM           S-GD.csv
# 461   CTL_DJ_12B1 1.581084 1.305745    RFR     S-Clientes.csv
# 845   SBT_DJ_12B1 1.589164 1.347359    SVR     S-Clientes.csv
# 468   GBA_DJ_12B2 1.603797 1.393101    RFR     S-Clientes.csv
# 383   GBA_DJ_12B2 1.655401 1.430328    RFR  S-Clientes-GD.csv
# 294   GBA_DJ_12B2 1.680567 1.456979   LSTM              S.csv
# 854   SZA_DJ_12B1 1.682851 1.529524    SVR     S-Clientes.csv
# 798   CJZ_DJ_12B1 1.690219 1.342335    SVR     S-Clientes.csv
# 940   SZA_DJ_12B2 1.707887 1.458409    SVR           S-GD.csv
# 898   GBA_DJ_12B2 1.720676 1.509671    SVR           S-GD.csv
# 855   SZA_DJ_12B2 1.727026 1.472205    SVR     S-Clientes.csv
# 580   PTS_DJ_12B1 1.758684 1.432212    RFR           S-GD.csv
# 925   PTS_DJ_12B1 1.763291 1.469774    SVR           S-GD.csv
# 495   PTS_DJ_12B1 1.763773 1.456056    RFR     S-Clientes.csv
# 410   PTS_DJ_12B1 1.779266 1.466303    RFR  S-Clientes-GD.csv
# 553   GBA_DJ_12B2 1.798552 1.559805    RFR           S-GD.csv
# 883   CJZ_DJ_12B1 1.804054 1.490234    SVR           S-GD.csv
# 806   CTL_DJ_12B1 1.808273 1.449282    SVR     S-Clientes.csv
# 585   SBT_DJ_12B1 1.830407 1.482959    RFR           S-GD.csv
# 594   SZA_DJ_12B1 1.832663 1.510375    RFR           S-GD.csv
# 287   CTL_DJ_12B1 1.839126 1.497723   LSTM              S.csv
# 713   CJZ_DJ_12B1 1.866146 1.517968    SVR  S-Clientes-GD.csv
# 632   CTL_DJ_12B1 1.867713 1.490101    RFR              S.csv
# 424   SZA_DJ_12B1 2.016643 1.681316    RFR  S-Clientes-GD.csv
# 509   SZA_DJ_12B1 2.016877 1.703001    RFR     S-Clientes.csv
# 500   SBT_DJ_12B1 2.049223 1.682852    RFR     S-Clientes.csv
# 538   CJZ_DJ_12B1 2.087311 1.619199    RFR           S-GD.csv
# 415   SBT_DJ_12B1 2.119543 1.743130    RFR  S-Clientes-GD.csv
# 878   CBD_DJ_12B1 2.146338 1.802968    SVR           S-GD.csv
# 769   SZA_DJ_12B1 2.170288 2.027476    SVR  S-Clientes-GD.csv
# 840   PTS_DJ_12B1 2.258169 1.968738    SVR     S-Clientes.csv
# 813   GBA_DJ_12B2 2.298619 1.957844    SVR     S-Clientes.csv
# 770   SZA_DJ_12B2 2.349548 2.035440    SVR  S-Clientes-GD.csv
# 1014  PRT_DJ_12B1 2.472324 2.198422    SVR              S.csv
# 728   GBA_DJ_12B2 2.533638 2.265164    SVR  S-Clientes-GD.csv
# 721   CTL_DJ_12B1 2.702451 2.226433    SVR  S-Clientes-GD.csv
# 708   CBD_DJ_12B1 4.105472 3.721002    SVR  S-Clientes-GD.csv
# 793   CBD_DJ_12B1 4.181791 3.765966    SVR     S-Clientes.csv
# 669   PRT_DJ_12B1 5.688786 3.527613    RFR              S.csv
