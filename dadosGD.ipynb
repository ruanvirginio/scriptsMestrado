# %%
import pandas as pd 

url_GD = "https://media.githubusercontent.com/media/ruanvirginio/scriptsMestrado/refs/heads/main/EntrantesGD.csv"
gd = pd.read_csv(url_GD,  sep=';', encoding='latin-1')

max_potencia = gd.groupby("TRAFO")["PotenciaAcumulada"].max().reset_index()

max_potencia.sort_values('PotenciaAcumulada', ascending=False).head(15)
# Out:
#           TRAFO  PotenciaAcumulada
# 65  PTS_DJ_12B1          18.110190
# 45  JTB_DJ_12B1          14.390985
# 32  CTR_DJ_12B1          12.482615
# 23  CJZ_DJ_12B1          11.970245
# 81  SZA_DJ_12B2          11.226030
# 18  CBD_DJ_12B1          10.830130
# 70  SBT_DJ_12B1          10.829460
# 80  SZA_DJ_12B1           9.407430
# 0   ABR_DJ_12B1           8.667350
# 57  PBL_DJ_12B1           8.325460
# 64  PRT_DJ_12B1           8.020820
# 31  CTL_DJ_12B1           8.012270
# 38  GBA_DJ_12B2           7.191860
# 71  SGL_DJ_12T1           7.179260
# 50  MGB_DJ_12B2           7.032455
